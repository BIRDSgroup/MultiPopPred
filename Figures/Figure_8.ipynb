# %%
import warnings
import numpy as np
import pandas as pd
from scipy.stats import norm
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
warnings.filterwarnings("ignore")
import matplotlib.patches as mpatches

# %% [markdown]
# # QT:

# %%
master_data_1K = pd.read_csv('/Figures/Data/QT_1K.csv',\
                             sep=',', header = None)
master_data_2K = pd.read_csv('/Figures/Data/QT_2K.csv',\
                             sep=',', header = None)

# %%
# Height =========================================================================================

test_rows = [3,6,9]

mppV1_R2_Height = np.array(master_data_2K.iloc[test_rows,11], dtype=float)
mppV2_R2_Height = np.array(master_data_2K.iloc[test_rows,12], dtype=float)
mppV3_R2_Height = np.array(master_data_2K.iloc[test_rows,13], dtype=float)
mppV4_R2_Height = np.array(master_data_2K.iloc[test_rows,14], dtype=float)
mppV4B_R2_Height = np.array(master_data_2K.iloc[test_rows,15], dtype=float)

# BMI =========================================================================================

test_rows = [18,21,24]

mppV1_R2_BMI = np.array(master_data_2K.iloc[test_rows,11], dtype=float)
mppV2_R2_BMI = np.array(master_data_2K.iloc[test_rows,12], dtype=float)
mppV3_R2_BMI = np.array(master_data_2K.iloc[test_rows,13], dtype=float)
mppV4_R2_BMI = np.array(master_data_2K.iloc[test_rows,14], dtype=float)
mppV4B_R2_BMI = np.array(master_data_2K.iloc[test_rows,15], dtype=float)

# SBP =========================================================================================

test_rows = [33,36,39]

mppV1_R2_SBP = np.array(master_data_2K.iloc[test_rows,11], dtype=float)
mppV2_R2_SBP = np.array(master_data_2K.iloc[test_rows,12], dtype=float)
mppV3_R2_SBP = np.array(master_data_2K.iloc[test_rows,13], dtype=float)
mppV4_R2_SBP = np.array(master_data_2K.iloc[test_rows,14], dtype=float)
mppV4B_R2_SBP = np.array(master_data_2K.iloc[test_rows,15], dtype=float)

# DBP =========================================================================================

test_rows = [48,51,54]

mppV1_R2_DBP = np.array(master_data_2K.iloc[test_rows,11], dtype=float)
mppV2_R2_DBP = np.array(master_data_2K.iloc[test_rows,12], dtype=float)
mppV3_R2_DBP = np.array(master_data_2K.iloc[test_rows,13], dtype=float)
mppV4_R2_DBP = np.array(master_data_2K.iloc[test_rows,14], dtype=float)
mppV4B_R2_DBP = np.array(master_data_2K.iloc[test_rows,15], dtype=float)

# HDL =========================================================================================

test_rows = [63,66,69]

mppV1_R2_HDL = np.array(master_data_1K.iloc[test_rows,11], dtype=float)
mppV2_R2_HDL = np.array(master_data_1K.iloc[test_rows,12], dtype=float)
mppV3_R2_HDL = np.array(master_data_1K.iloc[test_rows,13], dtype=float)
mppV4_R2_HDL = np.array(master_data_1K.iloc[test_rows,14], dtype=float)
mppV4B_R2_HDL = np.array(master_data_1K.iloc[test_rows,15], dtype=float)

# LDL =========================================================================================

test_rows = [78,81,84]

mppV1_R2_LDL = np.array(master_data_1K.iloc[test_rows,11], dtype=float)
mppV2_R2_LDL = np.array(master_data_1K.iloc[test_rows,12], dtype=float)
mppV3_R2_LDL = np.array(master_data_1K.iloc[test_rows,13], dtype=float)
mppV4_R2_LDL = np.array(master_data_1K.iloc[test_rows,14], dtype=float)
mppV4B_R2_LDL = np.array(master_data_1K.iloc[test_rows,15], dtype=float)

# TC =========================================================================================

test_rows = [93,96,99]

mppV1_R2_TC = np.array(master_data_1K.iloc[test_rows,11], dtype=float)
mppV2_R2_TC = np.array(master_data_1K.iloc[test_rows,12], dtype=float)
mppV3_R2_TC = np.array(master_data_1K.iloc[test_rows,13], dtype=float)
mppV4_R2_TC = np.array(master_data_1K.iloc[test_rows,14], dtype=float)
mppV4B_R2_TC = np.array(master_data_1K.iloc[test_rows,15], dtype=float)

# TG =========================================================================================

test_rows = [108,111,114]

mppV1_R2_TG = np.array(master_data_1K.iloc[test_rows,11], dtype=float)
mppV2_R2_TG = np.array(master_data_1K.iloc[test_rows,12], dtype=float)
mppV3_R2_TG = np.array(master_data_1K.iloc[test_rows,13], dtype=float)
mppV4_R2_TG = np.array(master_data_1K.iloc[test_rows,14], dtype=float)
mppV4B_R2_TG = np.array(master_data_1K.iloc[test_rows,15], dtype=float)

# %%
col_num = 4

# Height =========================================================================================
test_rows = [3,6,9]
prosper_R2_Height = np.array(master_data_2K.iloc[test_rows,col_num], dtype=float)

# BMI =========================================================================================
test_rows = [18,21,24]
prosper_R2_BMI = np.array(master_data_2K.iloc[test_rows,col_num], dtype=float)

# SBP =========================================================================================
test_rows = [33,36,39]
prosper_R2_SBP = np.array(master_data_2K.iloc[test_rows,col_num], dtype=float)

# DBP =========================================================================================
test_rows = [48,51,54]
prosper_R2_DBP = np.array(master_data_2K.iloc[test_rows,col_num], dtype=float)

# HDL =========================================================================================
test_rows = [63,66,69]
prosper_R2_HDL = np.array(master_data_1K.iloc[test_rows,col_num], dtype=float)

# LDL =========================================================================================
test_rows = [78,81,84]
prosper_R2_LDL = np.array(master_data_1K.iloc[test_rows,col_num], dtype=float)

# TC =========================================================================================
test_rows = [93,96,99]
prosper_R2_TC = np.array(master_data_1K.iloc[test_rows,col_num], dtype=float)

# TG =========================================================================================
test_rows = [108,111,114]
prosper_R2_TG = np.array(master_data_1K.iloc[test_rows,col_num], dtype=float)

# %%
col_num = 6

# Height =========================================================================================
test_rows = [3,6,9]
prscsx_R2_Height = np.array(master_data_2K.iloc[test_rows,col_num], dtype=float)

# BMI =========================================================================================
test_rows = [18,21,24]
prscsx_R2_BMI = np.array(master_data_2K.iloc[test_rows,col_num], dtype=float)

# SBP =========================================================================================
test_rows = [33,36,39]
prscsx_R2_SBP = np.array(master_data_2K.iloc[test_rows,col_num], dtype=float)

# DBP =========================================================================================
test_rows = [48,51,54]
prscsx_R2_DBP = np.array(master_data_2K.iloc[test_rows,col_num], dtype=float)

# HDL =========================================================================================
test_rows = [63,66,69]
prscsx_R2_HDL = np.array(master_data_1K.iloc[test_rows,col_num], dtype=float)

# LDL =========================================================================================
test_rows = [78,81,84]
prscsx_R2_LDL = np.array(master_data_1K.iloc[test_rows,col_num], dtype=float)

# TC =========================================================================================
test_rows = [93,96,99]
prscsx_R2_TC = np.array(master_data_1K.iloc[test_rows,col_num], dtype=float)

# TG =========================================================================================
test_rows = [108,111,114]
prscsx_R2_TG = np.array(master_data_1K.iloc[test_rows,col_num], dtype=float)

# %%
col_num = 9

# Height =========================================================================================
test_rows = [3,6,9]
sbrcMulti_R2_Height = np.array(master_data_2K.iloc[test_rows,col_num], dtype=float)

# BMI =========================================================================================
test_rows = [18,21,24]
sbrcMulti_R2_BMI = np.array(master_data_2K.iloc[test_rows,col_num], dtype=float)

# SBP =========================================================================================
test_rows = [33,36,39]
sbrcMulti_R2_SBP = np.array(master_data_2K.iloc[test_rows,col_num], dtype=float)

# DBP =========================================================================================
test_rows = [48,51,54]
sbrcMulti_R2_DBP = np.array(master_data_2K.iloc[test_rows,col_num], dtype=float)

# HDL =========================================================================================
test_rows = [63,66,69]
sbrcMulti_R2_HDL = np.array(master_data_1K.iloc[test_rows,col_num], dtype=float)

# LDL =========================================================================================
test_rows = [78,81,84]
sbrcMulti_R2_LDL = np.array(master_data_1K.iloc[test_rows,col_num], dtype=float)

# TC =========================================================================================
test_rows = [93,96,99]
sbrcMulti_R2_TC = np.array(master_data_1K.iloc[test_rows,col_num], dtype=float)

# TG =========================================================================================
test_rows = [108,111,114]
sbrcMulti_R2_TG = np.array(master_data_1K.iloc[test_rows,col_num], dtype=float)

# %%
col_num = 3

# Height =========================================================================================
test_rows = [3,6,9]
baseline_R2_Height = np.array(master_data_2K.iloc[test_rows,col_num], dtype=float)

# BMI =========================================================================================
test_rows = [18,21,24]
baseline_R2_BMI = np.array(master_data_2K.iloc[test_rows,col_num], dtype=float)

# SBP =========================================================================================
test_rows = [33,36,39]
baseline_R2_SBP = np.array(master_data_2K.iloc[test_rows,col_num], dtype=float)

# DBP =========================================================================================
test_rows = [48,51,54]
baseline_R2_DBP = np.array(master_data_2K.iloc[test_rows,col_num], dtype=float)

# HDL =========================================================================================
test_rows = [63,66,69]
baseline_R2_HDL = np.array(master_data_1K.iloc[test_rows,col_num], dtype=float)

# LDL =========================================================================================
test_rows = [78,81,84]
baseline_R2_LDL = np.array(master_data_1K.iloc[test_rows,col_num], dtype=float)

# TC =========================================================================================
test_rows = [93,96,99]
baseline_R2_TC = np.array(master_data_1K.iloc[test_rows,col_num], dtype=float)

# TG =========================================================================================
test_rows = [108,111,114]
baseline_R2_TG = np.array(master_data_1K.iloc[test_rows,col_num], dtype=float)

# %%
col_num = 5

# Height =========================================================================================
test_rows = [3,6,9]
lassosum2_R2_Height = np.array(master_data_2K.iloc[test_rows,col_num], dtype=float)

# BMI =========================================================================================
test_rows = [18,21,24]
lassosum2_R2_BMI = np.array(master_data_2K.iloc[test_rows,col_num], dtype=float)

# SBP =========================================================================================
test_rows = [33,36,39]
lassosum2_R2_SBP = np.array(master_data_2K.iloc[test_rows,col_num], dtype=float)

# DBP =========================================================================================
test_rows = [48,51,54]
lassosum2_R2_DBP = np.array(master_data_2K.iloc[test_rows,col_num], dtype=float)

# HDL =========================================================================================
test_rows = [63,66,69]
lassosum2_R2_HDL = np.array(master_data_1K.iloc[test_rows,col_num], dtype=float)

# LDL =========================================================================================
test_rows = [78,81,84]
lassosum2_R2_LDL = np.array(master_data_1K.iloc[test_rows,col_num], dtype=float)

# TC =========================================================================================
test_rows = [93,96,99]
lassosum2_R2_TC = np.array(master_data_1K.iloc[test_rows,col_num], dtype=float)

# TG =========================================================================================
test_rows = [108,111,114]
lassosum2_R2_TG = np.array(master_data_1K.iloc[test_rows,col_num], dtype=float)

# %%
col_num = 10

# Height =========================================================================================
test_rows = [3,6,9]
lassosumTLD_R2_Height = np.array(master_data_2K.iloc[test_rows,col_num], dtype=float)

# BMI =========================================================================================
test_rows = [18,21,24]
lassosumTLD_R2_BMI = np.array(master_data_2K.iloc[test_rows,col_num], dtype=float)

# SBP =========================================================================================
test_rows = [33,36,39]
lassosumTLD_R2_SBP = np.array(master_data_2K.iloc[test_rows,col_num], dtype=float)

# DBP =========================================================================================
test_rows = [48,51,54]
lassosumTLD_R2_DBP = np.array(master_data_2K.iloc[test_rows,col_num], dtype=float)

# HDL =========================================================================================
test_rows = [63,66,69]
lassosumTLD_R2_HDL = np.array(master_data_1K.iloc[test_rows,col_num], dtype=float)

# LDL =========================================================================================
test_rows = [78,81,84]
lassosumTLD_R2_LDL = np.array(master_data_1K.iloc[test_rows,col_num], dtype=float)

# TC =========================================================================================
test_rows = [93,96,99]
lassosumTLD_R2_TC = np.array(master_data_1K.iloc[test_rows,col_num], dtype=float)

# TG =========================================================================================
test_rows = [108,111,114]
lassosumTLD_R2_TG = np.array(master_data_1K.iloc[test_rows,col_num], dtype=float)

# %%
mppV1_R2_all = np.concatenate((mppV1_R2_Height, mppV1_R2_BMI, mppV1_R2_SBP, mppV1_R2_DBP,\
                               mppV1_R2_HDL, mppV1_R2_LDL, mppV1_R2_TC, mppV1_R2_TG))
mppV4B_R2_all = np.concatenate((mppV4B_R2_Height, mppV4B_R2_BMI, mppV4B_R2_SBP, mppV4B_R2_DBP,\
                               mppV4B_R2_HDL, mppV4B_R2_LDL, mppV4B_R2_TC, mppV4B_R2_TG))
prosper_R2_all = np.concatenate((prosper_R2_Height, prosper_R2_BMI, prosper_R2_SBP, prosper_R2_DBP,\
                               prosper_R2_HDL, prosper_R2_LDL, prosper_R2_TC, prosper_R2_TG))
prscsx_R2_all = np.concatenate((prscsx_R2_Height, prscsx_R2_BMI, prscsx_R2_SBP, prscsx_R2_DBP,\
                               prscsx_R2_HDL, prscsx_R2_LDL, prscsx_R2_TC, prscsx_R2_TG))
sbrcMulti_R2_all = np.concatenate((sbrcMulti_R2_Height, sbrcMulti_R2_BMI, sbrcMulti_R2_SBP, sbrcMulti_R2_DBP,\
                               sbrcMulti_R2_HDL, sbrcMulti_R2_LDL, sbrcMulti_R2_TC, sbrcMulti_R2_TG))
baseline_R2_all = np.concatenate((baseline_R2_Height, baseline_R2_BMI, baseline_R2_SBP, baseline_R2_DBP,\
                               baseline_R2_HDL, baseline_R2_LDL, baseline_R2_TC, baseline_R2_TG))
lassosum2_R2_all = np.concatenate((lassosum2_R2_Height, lassosum2_R2_BMI, lassosum2_R2_SBP, lassosum2_R2_DBP,\
                               lassosum2_R2_HDL, lassosum2_R2_LDL, lassosum2_R2_TC, lassosum2_R2_TG))
lassosumTLD_R2_all = np.concatenate((lassosumTLD_R2_Height, lassosumTLD_R2_BMI, lassosumTLD_R2_SBP, lassosumTLD_R2_DBP,\
                               lassosumTLD_R2_HDL, lassosumTLD_R2_LDL, lassosumTLD_R2_TC, lassosumTLD_R2_TG))

# %% [markdown]
# # BT:

# %%
master_data = pd.read_csv('/Figures/Data/BT_Log.csv',\
                          sep=',', header = None)

# %%
# UKB2040 =========================================================================================

test_rows = [3,6,9]

mppV1_PR_UKB2040 = np.array(master_data.iloc[test_rows,12], dtype=float)
mppV1_ROC_UKB2040 = np.array(master_data.iloc[test_rows,30], dtype=float)

mppV3_PR_UKB2040 = np.array(master_data.iloc[test_rows,14], dtype=float)
mppV3_ROC_UKB2040 = np.array(master_data.iloc[test_rows,32], dtype=float)

mppV4_PR_UKB2040 = np.array(master_data.iloc[test_rows,15], dtype=float)
mppV4_ROC_UKB2040 = np.array(master_data.iloc[test_rows,33], dtype=float)

mppV4B_PR_UKB2040 = np.array(master_data.iloc[test_rows,16], dtype=float)
mppV4B_ROC_UKB2040 = np.array(master_data.iloc[test_rows,34], dtype=float)

# UKB6138 =========================================================================================

test_rows = [18,21,24]

mppV1_PR_UKB6138 = np.array(master_data.iloc[test_rows,12], dtype=float)
mppV1_ROC_UKB6138 = np.array(master_data.iloc[test_rows,30], dtype=float)

mppV3_PR_UKB6138 = np.array(master_data.iloc[test_rows,14], dtype=float)
mppV3_ROC_UKB6138 = np.array(master_data.iloc[test_rows,32], dtype=float)

mppV4_PR_UKB6138 = np.array(master_data.iloc[test_rows,15], dtype=float)
mppV4_ROC_UKB6138 = np.array(master_data.iloc[test_rows,33], dtype=float)

mppV4B_PR_UKB6138 = np.array(master_data.iloc[test_rows,16], dtype=float)
mppV4B_ROC_UKB6138 = np.array(master_data.iloc[test_rows,34], dtype=float)

# UKB6152 =========================================================================================

test_rows = [33,36,39]

mppV1_PR_UKB6152 = np.array(master_data.iloc[test_rows,12], dtype=float)
mppV1_ROC_UKB6152 = np.array(master_data.iloc[test_rows,30], dtype=float)

mppV3_PR_UKB6152 = np.array(master_data.iloc[test_rows,14], dtype=float)
mppV3_ROC_UKB6152 = np.array(master_data.iloc[test_rows,32], dtype=float)

mppV4_PR_UKB6152 = np.array(master_data.iloc[test_rows,15], dtype=float)
mppV4_ROC_UKB6152 = np.array(master_data.iloc[test_rows,33], dtype=float)

mppV4B_PR_UKB6152 = np.array(master_data.iloc[test_rows,16], dtype=float)
mppV4B_ROC_UKB6152 = np.array(master_data.iloc[test_rows,34], dtype=float)

# UKBanyCVD =========================================================================================

test_rows = [48,51,54]

mppV1_PR_UKBanyCVD = np.array(master_data.iloc[test_rows,12], dtype=float)
mppV1_ROC_UKBanyCVD = np.array(master_data.iloc[test_rows,30], dtype=float)

mppV3_PR_UKBanyCVD = np.array(master_data.iloc[test_rows,14], dtype=float)
mppV3_ROC_UKBanyCVD = np.array(master_data.iloc[test_rows,32], dtype=float)

mppV4_PR_UKBanyCVD = np.array(master_data.iloc[test_rows,15], dtype=float)
mppV4_ROC_UKBanyCVD = np.array(master_data.iloc[test_rows,33], dtype=float)

mppV4B_PR_UKBanyCVD = np.array(master_data.iloc[test_rows,16], dtype=float)
mppV4B_ROC_UKBanyCVD = np.array(master_data.iloc[test_rows,34], dtype=float)

# UKBasthma =========================================================================================

test_rows = [63,66,69]

mppV1_PR_UKBasthma = np.array(master_data.iloc[test_rows,12], dtype=float)
mppV1_ROC_UKBasthma = np.array(master_data.iloc[test_rows,30], dtype=float)

mppV3_PR_UKBasthma = np.array(master_data.iloc[test_rows,14], dtype=float)
mppV3_ROC_UKBasthma = np.array(master_data.iloc[test_rows,32], dtype=float)

mppV4_PR_UKBasthma = np.array(master_data.iloc[test_rows,15], dtype=float)
mppV4_ROC_UKBasthma = np.array(master_data.iloc[test_rows,33], dtype=float)

mppV4B_PR_UKBasthma = np.array(master_data.iloc[test_rows,16], dtype=float)
mppV4B_ROC_UKBasthma = np.array(master_data.iloc[test_rows,34], dtype=float)

# UKBdyslipi =========================================================================================

test_rows = [78,81,84]

mppV1_PR_UKBdyslipi = np.array(master_data.iloc[test_rows,12], dtype=float)
mppV1_ROC_UKBdyslipi = np.array(master_data.iloc[test_rows,30], dtype=float)

mppV3_PR_UKBdyslipi = np.array(master_data.iloc[test_rows,14], dtype=float)
mppV3_ROC_UKBdyslipi = np.array(master_data.iloc[test_rows,32], dtype=float)

mppV4_PR_UKBdyslipi = np.array(master_data.iloc[test_rows,15], dtype=float)
mppV4_ROC_UKBdyslipi = np.array(master_data.iloc[test_rows,33], dtype=float)

mppV4B_PR_UKBdyslipi = np.array(master_data.iloc[test_rows,16], dtype=float)
mppV4B_ROC_UKBdyslipi = np.array(master_data.iloc[test_rows,34], dtype=float)

# UKBmp =========================================================================================

test_rows = [93,96,99]

mppV1_PR_UKBmp = np.array(master_data.iloc[test_rows,12], dtype=float)
mppV1_ROC_UKBmp = np.array(master_data.iloc[test_rows,30], dtype=float)

mppV3_PR_UKBmp = np.array(master_data.iloc[test_rows,14], dtype=float)
mppV3_ROC_UKBmp = np.array(master_data.iloc[test_rows,32], dtype=float)

mppV4_PR_UKBmp = np.array(master_data.iloc[test_rows,15], dtype=float)
mppV4_ROC_UKBmp = np.array(master_data.iloc[test_rows,33], dtype=float)

mppV4B_PR_UKBmp = np.array(master_data.iloc[test_rows,16], dtype=float)
mppV4B_ROC_UKBmp = np.array(master_data.iloc[test_rows,34], dtype=float)

# UKBt2d =========================================================================================

test_rows = [108,111,114]

mppV1_PR_UKBt2d = np.array(master_data.iloc[test_rows,12], dtype=float)
mppV1_ROC_UKBt2d = np.array(master_data.iloc[test_rows,30], dtype=float)

mppV3_PR_UKBt2d = np.array(master_data.iloc[test_rows,14], dtype=float)
mppV3_ROC_UKBt2d = np.array(master_data.iloc[test_rows,32], dtype=float)

mppV4_PR_UKBt2d = np.array(master_data.iloc[test_rows,15], dtype=float)
mppV4_ROC_UKBt2d = np.array(master_data.iloc[test_rows,33], dtype=float)

mppV4B_PR_UKBt2d = np.array(master_data.iloc[test_rows,16], dtype=float)
mppV4B_ROC_UKBt2d = np.array(master_data.iloc[test_rows,34], dtype=float)

# %%
pr_col = 4
roc_col = 22

# UKB2040 =========================================================================================

test_rows = [3,6,9]

prosper_PR_UKB2040 = np.array(master_data.iloc[test_rows,pr_col], dtype=float)
prosper_ROC_UKB2040 = np.array(master_data.iloc[test_rows,roc_col], dtype=float)

# UKB6138 =========================================================================================

test_rows = [18,21,24]

prosper_PR_UKB6138 = np.array(master_data.iloc[test_rows,pr_col], dtype=float)
prosper_ROC_UKB6138 = np.array(master_data.iloc[test_rows,roc_col], dtype=float)

# UKB6152 =========================================================================================

test_rows = [33,36,39]

prosper_PR_UKB6152 = np.array(master_data.iloc[test_rows,pr_col], dtype=float)
prosper_ROC_UKB6152 = np.array(master_data.iloc[test_rows,roc_col], dtype=float)

# UKBanyCVD =========================================================================================

test_rows = [48,51,54]

prosper_PR_UKBanyCVD = np.array(master_data.iloc[test_rows,pr_col], dtype=float)
prosper_ROC_UKBanyCVD = np.array(master_data.iloc[test_rows,roc_col], dtype=float)

# UKBasthma =========================================================================================

test_rows = [63,66,69]

prosper_PR_UKBasthma = np.array(master_data.iloc[test_rows,pr_col], dtype=float)
prosper_ROC_UKBasthma = np.array(master_data.iloc[test_rows,roc_col], dtype=float)

# UKBdyslipi =========================================================================================

test_rows = [78,81,84]

prosper_PR_UKBdyslipi = np.array(master_data.iloc[test_rows,pr_col], dtype=float)
prosper_ROC_UKBdyslipi = np.array(master_data.iloc[test_rows,roc_col], dtype=float)

# UKBmp =========================================================================================

test_rows = [93,96,99]

prosper_PR_UKBmp = np.array(master_data.iloc[test_rows,pr_col], dtype=float)
prosper_ROC_UKBmp = np.array(master_data.iloc[test_rows,roc_col], dtype=float)

# UKBt2d =========================================================================================

test_rows = [108,111,114]

prosper_PR_UKBt2d = np.array(master_data.iloc[test_rows,pr_col], dtype=float)
prosper_ROC_UKBt2d = np.array(master_data.iloc[test_rows,roc_col], dtype=float)

# %%
pr_col = 6
roc_col = 24

# UKB2040 =========================================================================================

test_rows = [3,6,9]

prscsx_PR_UKB2040 = np.array(master_data.iloc[test_rows,pr_col], dtype=float)
prscsx_ROC_UKB2040 = np.array(master_data.iloc[test_rows,roc_col], dtype=float)

# UKB6138 =========================================================================================

test_rows = [18,21,24]

prscsx_PR_UKB6138 = np.array(master_data.iloc[test_rows,pr_col], dtype=float)
prscsx_ROC_UKB6138 = np.array(master_data.iloc[test_rows,roc_col], dtype=float)

# UKB6152 =========================================================================================

test_rows = [33,36,39]

prscsx_PR_UKB6152 = np.array(master_data.iloc[test_rows,pr_col], dtype=float)
prscsx_ROC_UKB6152 = np.array(master_data.iloc[test_rows,roc_col], dtype=float)

# UKBanyCVD =========================================================================================

test_rows = [48,51,54]

prscsx_PR_UKBanyCVD = np.array(master_data.iloc[test_rows,pr_col], dtype=float)
prscsx_ROC_UKBanyCVD = np.array(master_data.iloc[test_rows,roc_col], dtype=float)

# UKBasthma =========================================================================================

test_rows = [63,66,69]

prscsx_PR_UKBasthma = np.array(master_data.iloc[test_rows,pr_col], dtype=float)
prscsx_ROC_UKBasthma = np.array(master_data.iloc[test_rows,roc_col], dtype=float)

# UKBdyslipi =========================================================================================

test_rows = [78,81,84]

prscsx_PR_UKBdyslipi = np.array(master_data.iloc[test_rows,pr_col], dtype=float)
prscsx_ROC_UKBdyslipi = np.array(master_data.iloc[test_rows,roc_col], dtype=float)

# UKBmp =========================================================================================

test_rows = [93,96,99]

prscsx_PR_UKBmp = np.array(master_data.iloc[test_rows,pr_col], dtype=float)
prscsx_ROC_UKBmp = np.array(master_data.iloc[test_rows,roc_col], dtype=float)

# UKBt2d =========================================================================================

test_rows = [108,111,114]

prscsx_PR_UKBt2d = np.array(master_data.iloc[test_rows,pr_col], dtype=float)
prscsx_ROC_UKBt2d = np.array(master_data.iloc[test_rows,roc_col], dtype=float)

# %%
pr_col = 9
roc_col = 27

# UKB2040 =========================================================================================

test_rows = [3,6,9]

sbrcMulti_PR_UKB2040 = np.array(master_data.iloc[test_rows,pr_col], dtype=float)
sbrcMulti_ROC_UKB2040 = np.array(master_data.iloc[test_rows,roc_col], dtype=float)

# UKB6138 =========================================================================================

test_rows = [18,21,24]

sbrcMulti_PR_UKB6138 = np.array(master_data.iloc[test_rows,pr_col], dtype=float)
sbrcMulti_ROC_UKB6138 = np.array(master_data.iloc[test_rows,roc_col], dtype=float)

# UKB6152 =========================================================================================

test_rows = [33,36,39]

sbrcMulti_PR_UKB6152 = np.array(master_data.iloc[test_rows,pr_col], dtype=float)
sbrcMulti_ROC_UKB6152 = np.array(master_data.iloc[test_rows,roc_col], dtype=float)

# UKBanyCVD =========================================================================================

test_rows = [48,51,54]

sbrcMulti_PR_UKBanyCVD = np.array(master_data.iloc[test_rows,pr_col], dtype=float)
sbrcMulti_ROC_UKBanyCVD = np.array(master_data.iloc[test_rows,roc_col], dtype=float)

# UKBasthma =========================================================================================

test_rows = [63,66,69]

sbrcMulti_PR_UKBasthma = np.array(master_data.iloc[test_rows,pr_col], dtype=float)
sbrcMulti_ROC_UKBasthma = np.array(master_data.iloc[test_rows,roc_col], dtype=float)

# UKBdyslipi =========================================================================================

test_rows = [78,81,84]

sbrcMulti_PR_UKBdyslipi = np.array(master_data.iloc[test_rows,pr_col], dtype=float)
sbrcMulti_ROC_UKBdyslipi = np.array(master_data.iloc[test_rows,roc_col], dtype=float)

# UKBmp =========================================================================================

test_rows = [93,96,99]

sbrcMulti_PR_UKBmp = np.array(master_data.iloc[test_rows,pr_col], dtype=float)
sbrcMulti_ROC_UKBmp = np.array(master_data.iloc[test_rows,roc_col], dtype=float)

# UKBt2d =========================================================================================

test_rows = [108,111,114]

sbrcMulti_PR_UKBt2d = np.array(master_data.iloc[test_rows,pr_col], dtype=float)
sbrcMulti_ROC_UKBt2d = np.array(master_data.iloc[test_rows,roc_col], dtype=float)

# %%
pr_col = 3
roc_col = 21

# UKB2040 =========================================================================================

test_rows = [3,6,9]

baseline_PR_UKB2040 = np.array(master_data.iloc[test_rows,pr_col], dtype=float)
baseline_ROC_UKB2040 = np.array(master_data.iloc[test_rows,roc_col], dtype=float)

# UKB6138 =========================================================================================

test_rows = [18,21,24]

baseline_PR_UKB6138 = np.array(master_data.iloc[test_rows,pr_col], dtype=float)
baseline_ROC_UKB6138 = np.array(master_data.iloc[test_rows,roc_col], dtype=float)

# UKB6152 =========================================================================================

test_rows = [33,36,39]

baseline_PR_UKB6152 = np.array(master_data.iloc[test_rows,pr_col], dtype=float)
baseline_ROC_UKB6152 = np.array(master_data.iloc[test_rows,roc_col], dtype=float)

# UKBanyCVD =========================================================================================

test_rows = [48,51,54]

baseline_PR_UKBanyCVD = np.array(master_data.iloc[test_rows,pr_col], dtype=float)
baseline_ROC_UKBanyCVD = np.array(master_data.iloc[test_rows,roc_col], dtype=float)

# UKBasthma =========================================================================================

test_rows = [63,66,69]

baseline_PR_UKBasthma = np.array(master_data.iloc[test_rows,pr_col], dtype=float)
baseline_ROC_UKBasthma = np.array(master_data.iloc[test_rows,roc_col], dtype=float)

# UKBdyslipi =========================================================================================

test_rows = [78,81,84]

baseline_PR_UKBdyslipi = np.array(master_data.iloc[test_rows,pr_col], dtype=float)
baseline_ROC_UKBdyslipi = np.array(master_data.iloc[test_rows,roc_col], dtype=float)

# UKBmp =========================================================================================

test_rows = [93,96,99]

baseline_PR_UKBmp = np.array(master_data.iloc[test_rows,pr_col], dtype=float)
baseline_ROC_UKBmp = np.array(master_data.iloc[test_rows,roc_col], dtype=float)

# UKBt2d =========================================================================================

test_rows = [108,111,114]

baseline_PR_UKBt2d = np.array(master_data.iloc[test_rows,pr_col], dtype=float)
baseline_ROC_UKBt2d = np.array(master_data.iloc[test_rows,roc_col], dtype=float)

# %%
pr_col = 5
roc_col = 23

# UKB2040 =========================================================================================

test_rows = [3,6,9]

lassosum2_PR_UKB2040 = np.array(master_data.iloc[test_rows,pr_col], dtype=float)
lassosum2_ROC_UKB2040 = np.array(master_data.iloc[test_rows,roc_col], dtype=float)

# UKB6138 =========================================================================================

test_rows = [18,21,24]

lassosum2_PR_UKB6138 = np.array(master_data.iloc[test_rows,pr_col], dtype=float)
lassosum2_ROC_UKB6138 = np.array(master_data.iloc[test_rows,roc_col], dtype=float)

# UKB6152 =========================================================================================

test_rows = [33,36,39]

lassosum2_PR_UKB6152 = np.array(master_data.iloc[test_rows,pr_col], dtype=float)
lassosum2_ROC_UKB6152 = np.array(master_data.iloc[test_rows,roc_col], dtype=float)

# UKBanyCVD =========================================================================================

test_rows = [48,51,54]

lassosum2_PR_UKBanyCVD = np.array(master_data.iloc[test_rows,pr_col], dtype=float)
lassosum2_ROC_UKBanyCVD = np.array(master_data.iloc[test_rows,roc_col], dtype=float)

# UKBasthma =========================================================================================

test_rows = [63,66,69]

lassosum2_PR_UKBasthma = np.array(master_data.iloc[test_rows,pr_col], dtype=float)
lassosum2_ROC_UKBasthma = np.array(master_data.iloc[test_rows,roc_col], dtype=float)

# UKBdyslipi =========================================================================================

test_rows = [78,81,84]

lassosum2_PR_UKBdyslipi = np.array(master_data.iloc[test_rows,pr_col], dtype=float)
lassosum2_ROC_UKBdyslipi = np.array(master_data.iloc[test_rows,roc_col], dtype=float)

# UKBmp =========================================================================================

test_rows = [93,96,99]

lassosum2_PR_UKBmp = np.array(master_data.iloc[test_rows,pr_col], dtype=float)
lassosum2_ROC_UKBmp = np.array(master_data.iloc[test_rows,roc_col], dtype=float)

# UKBt2d =========================================================================================

test_rows = [108,111,114]

lassosum2_PR_UKBt2d = np.array(master_data.iloc[test_rows,pr_col], dtype=float)
lassosum2_ROC_UKBt2d = np.array(master_data.iloc[test_rows,roc_col], dtype=float)

# %%
pr_col = 11
roc_col = 29

# UKB2040 =========================================================================================

test_rows = [3,6,9]

lassosumTLD_PR_UKB2040 = np.array(master_data.iloc[test_rows,pr_col], dtype=float)
lassosumTLD_ROC_UKB2040 = np.array(master_data.iloc[test_rows,roc_col], dtype=float)

# UKB6138 =========================================================================================

test_rows = [18,21,24]

lassosumTLD_PR_UKB6138 = np.array(master_data.iloc[test_rows,pr_col], dtype=float)
lassosumTLD_ROC_UKB6138 = np.array(master_data.iloc[test_rows,roc_col], dtype=float)

# UKB6152 =========================================================================================

test_rows = [33,36,39]

lassosumTLD_PR_UKB6152 = np.array(master_data.iloc[test_rows,pr_col], dtype=float)
lassosumTLD_ROC_UKB6152 = np.array(master_data.iloc[test_rows,roc_col], dtype=float)

# UKBanyCVD =========================================================================================

test_rows = [48,51,54]

lassosumTLD_PR_UKBanyCVD = np.array(master_data.iloc[test_rows,pr_col], dtype=float)
lassosumTLD_ROC_UKBanyCVD = np.array(master_data.iloc[test_rows,roc_col], dtype=float)

# UKBasthma =========================================================================================

test_rows = [63,66,69]

lassosumTLD_PR_UKBasthma = np.array(master_data.iloc[test_rows,pr_col], dtype=float)
lassosumTLD_ROC_UKBasthma = np.array(master_data.iloc[test_rows,roc_col], dtype=float)

# UKBdyslipi =========================================================================================

test_rows = [78,81,84]

lassosumTLD_PR_UKBdyslipi = np.array(master_data.iloc[test_rows,pr_col], dtype=float)
lassosumTLD_ROC_UKBdyslipi = np.array(master_data.iloc[test_rows,roc_col], dtype=float)

# UKBmp =========================================================================================

test_rows = [93,96,99]

lassosumTLD_PR_UKBmp = np.array(master_data.iloc[test_rows,pr_col], dtype=float)
lassosumTLD_ROC_UKBmp = np.array(master_data.iloc[test_rows,roc_col], dtype=float)

# UKBt2d =========================================================================================

test_rows = [108,111,114]

lassosumTLD_PR_UKBt2d = np.array(master_data.iloc[test_rows,pr_col], dtype=float)
lassosumTLD_ROC_UKBt2d = np.array(master_data.iloc[test_rows,roc_col], dtype=float)

# %%
mppV1_PR_all = np.concatenate((mppV1_PR_UKB2040, mppV1_PR_UKB6138, mppV1_PR_UKB6152, mppV1_PR_UKBanyCVD,\
                               mppV1_PR_UKBasthma, mppV1_PR_UKBdyslipi, mppV1_PR_UKBmp, mppV1_PR_UKBt2d))
mppV4B_PR_all = np.concatenate((mppV4B_PR_UKB2040, mppV4B_PR_UKB6138, mppV4B_PR_UKB6152, mppV4B_PR_UKBanyCVD,\
                                mppV4B_PR_UKBasthma, mppV4B_PR_UKBdyslipi, mppV4B_PR_UKBmp, mppV4B_PR_UKBt2d))
sbrcMulti_PR_all = np.concatenate((sbrcMulti_PR_UKB2040, sbrcMulti_PR_UKB6138, sbrcMulti_PR_UKB6152, sbrcMulti_PR_UKBanyCVD,\
                               sbrcMulti_PR_UKBasthma, sbrcMulti_PR_UKBdyslipi, sbrcMulti_PR_UKBmp, sbrcMulti_PR_UKBt2d))
prosper_PR_all = np.concatenate((prosper_PR_UKB2040, prosper_PR_UKB6138, prosper_PR_UKB6152, prosper_PR_UKBanyCVD,\
                               prosper_PR_UKBasthma, prosper_PR_UKBdyslipi, prosper_PR_UKBmp, prosper_PR_UKBt2d))
prscsx_PR_all = np.concatenate((prscsx_PR_UKB2040, prscsx_PR_UKB6138, prscsx_PR_UKB6152, prscsx_PR_UKBanyCVD,\
                               prscsx_PR_UKBasthma, prscsx_PR_UKBdyslipi, prscsx_PR_UKBmp, prscsx_PR_UKBt2d))
baseline_PR_all = np.concatenate((baseline_PR_UKB2040, baseline_PR_UKB6138, baseline_PR_UKB6152, baseline_PR_UKBanyCVD,\
                               baseline_PR_UKBasthma, baseline_PR_UKBdyslipi, baseline_PR_UKBmp, baseline_PR_UKBt2d))
lassosum2_PR_all = np.concatenate((lassosum2_PR_UKB2040, lassosum2_PR_UKB6138, lassosum2_PR_UKB6152, lassosum2_PR_UKBanyCVD,\
                               lassosum2_PR_UKBasthma, lassosum2_PR_UKBdyslipi, lassosum2_PR_UKBmp, lassosum2_PR_UKBt2d))
lassosumTLD_PR_all = np.concatenate((lassosumTLD_PR_UKB2040, lassosumTLD_PR_UKB6138, lassosumTLD_PR_UKB6152, lassosumTLD_PR_UKBanyCVD,\
                               lassosumTLD_PR_UKBasthma, lassosumTLD_PR_UKBdyslipi, lassosumTLD_PR_UKBmp, lassosumTLD_PR_UKBt2d))

# %% [markdown]
# # Plot:

# %%
fig, ax = plt.subplots(2, 3, figsize=(15, 10), dpi=300)
fig.tight_layout()
fig.subplots_adjust(left=0.13, bottom=0.05, right=None, top=None, wspace=0.45, hspace=0.15)

fig.suptitle('Overall Performance Comparison on Real World Data\nBest Performers - SOTA vs. MultiPopPred', fontsize=20,\
             bbox=dict(facecolor='#f0f0f0',edgecolor='black',boxstyle='round'), y=1.1)

common_bbox = dict(facecolor='#f0f0f0', edgecolor='black', boxstyle='round', pad=0.5)

fig.text(0.05, 0.75, 'Quantitative Traits', fontsize=18,
         bbox=common_bbox, ha='center', va='center', rotation=90)

fig.text(0.05, 0.25, 'Binary Traits', fontsize=18,
         bbox=common_bbox, ha='center', va='center', rotation=90)

#=====================================================================================================

x = sbrcMulti_R2_all
y = mppV4B_R2_all
ax[0,0].plot(np.arange(min(x)-0.1,max(x)+0.1,0.1), np.arange(min(x)-0.1,max(x)+0.1,0.1), color='black')
ax[0,0].scatter(x,y, alpha = 0.5)
ax[0,0].grid(True, which='both', axis='y', linestyle='--', linewidth=0.7, color='gray', alpha=0.5)
ax[0,0].set_facecolor('#f0f0f0')
ax[0,0].tick_params(axis='x',labelsize=10)
ax[0,0].tick_params(axis='y',labelsize=10)
ax[0,0].set_xlabel('SBayesRC-Multi', fontsize=15)
ax[0,0].set_ylabel('MPP-PRS+', fontsize=15)

x = prosper_R2_all
y = mppV4B_R2_all
ax[0,1].plot(np.arange(min(x)-0.1,max(x)+0.1,0.1), np.arange(min(x)-0.1,max(x)+0.1,0.1), color='black')
ax[0,1].scatter(x,y, alpha = 0.5)
ax[0,1].grid(True, which='both', axis='y', linestyle='--', linewidth=0.7, color='gray', alpha=0.5)
ax[0,1].set_facecolor('#f0f0f0')
ax[0,1].tick_params(axis='x',labelsize=10)
ax[0,1].tick_params(axis='y',labelsize=10)
ax[0,1].set_xlabel('PROSPER', fontsize=15)
ax[0,1].set_ylabel('MPP-PRS+', fontsize=15)

x = prscsx_R2_all
y = mppV4B_R2_all
ax[0,2].plot(np.arange(min(x)-0.1,max(x)+0.1,0.1), np.arange(min(x)-0.1,max(x)+0.1,0.1), color='black')
ax[0,2].scatter(x,y, alpha = 0.5)
ax[0,2].grid(True, which='both', axis='y', linestyle='--', linewidth=0.7, color='gray', alpha=0.5)
ax[0,2].set_facecolor('#f0f0f0')
ax[0,2].tick_params(axis='x',labelsize=10)
ax[0,2].tick_params(axis='y',labelsize=10)
ax[0,2].set_xlabel('PRS-CSx', fontsize=15)
ax[0,2].set_ylabel('MPP-PRS+', fontsize=15)

#=====================================================================================================

x = sbrcMulti_PR_all
y = mppV4B_PR_all
ax[1,0].plot(np.arange(min(x)-0.1,max(x)+0.1,0.1), np.arange(min(x)-0.1,max(x)+0.1,0.1), color='black')
ax[1,0].scatter(x,y, alpha = 0.5)
ax[1,0].grid(True, which='both', axis='y', linestyle='--', linewidth=0.7, color='gray', alpha=0.5)
ax[1,0].set_facecolor('#f0f0f0')
ax[1,0].tick_params(axis='x',labelsize=10)
ax[1,0].tick_params(axis='y',labelsize=10)
ax[1,0].set_xlabel('SBayesRC-Multi', fontsize=15)
ax[1,0].set_ylabel('MPP-PRS+', fontsize=15)

x = prosper_PR_all
y = mppV4B_PR_all
ax[1,1].plot(np.arange(min(x)-0.1,max(x)+0.1,0.1), np.arange(min(x)-0.1,max(x)+0.1,0.1), color='black')
ax[1,1].scatter(x,y, alpha = 0.5)
ax[1,1].grid(True, which='both', axis='y', linestyle='--', linewidth=0.7, color='gray', alpha=0.5)
ax[1,1].set_facecolor('#f0f0f0')
ax[1,1].tick_params(axis='x',labelsize=10)
ax[1,1].tick_params(axis='y',labelsize=10)
ax[1,1].set_xlabel('PROSPER', fontsize=15)
ax[1,1].set_ylabel('MPP-PRS+', fontsize=15)

x = prscsx_PR_all
y = mppV4B_PR_all
ax[1,2].plot(np.arange(min(x)-0.1,max(x)+0.1,0.1), np.arange(min(x)-0.1,max(x)+0.1,0.1), color='black')
ax[1,2].scatter(x,y, alpha = 0.5)
ax[1,2].grid(True, which='both', axis='y', linestyle='--', linewidth=0.7, color='gray', alpha=0.5)
ax[1,2].set_facecolor('#f0f0f0')
ax[1,2].tick_params(axis='x',labelsize=10)
ax[1,2].tick_params(axis='y',labelsize=10)
ax[1,2].set_xlabel('PRS-CSx', fontsize=15)
ax[1,2].set_ylabel('MPP-PRS+', fontsize=15)

#=====================================================================================================

# fig.savefig("/Figures/Plots/Figure_8.pdf",\
#             format='pdf', bbox_inches='tight')
# Out:
# Text(2912.18137254902, 0.5, 'MPP-PRS+')
