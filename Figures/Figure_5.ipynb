# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches

# %%
df = pd.read_csv('/Users/ritwizkamal/BIRDS_server/AA_FinalGithub/Data/CT_analysis.csv', delimiter=',')
std_df = pd.read_csv('/Users/ritwizkamal/BIRDS_server/AA_FinalGithub/Data/CT_analysis_std.csv', delimiter=',')

# %%
fig, ax = plt.subplots(4 , 2, figsize=(35, 25), dpi = 300)
fig.tight_layout()
fig.subplots_adjust(left=None, bottom=0.05, right=None, top=None, wspace=0.15, hspace=0.7)

categories = [5e-8, 5e-7, 5e-6, 5e-5, 5e-4, 5e-3, 5e-2, 5e-1, 1]

fig.suptitle('Clumping and Thresholding vs Baseline GWAS | Real World Data | UKBiobank', fontsize=40,\
             bbox=dict(facecolor='#f0f0f0',edgecolor='black',boxstyle='round'), y=1.07)

ax[0][0].set_title('Height', fontsize=40,\
                   bbox=dict(facecolor='#f0f0f0',edgecolor='black',boxstyle='round'), y=1.05)
baseline = np.array([0.05690255667]*len(categories))
baseline_sd = np.array([0.02197742904]*len(categories))
condition = ((df["p_value"].isin(categories)) & (df["r2"] == 0.5) & (df["kb"] == 100) & (df["ref_data"] == "ukbb"))
ct = np.array(df[condition]['Height_R2'])
ct_sd = np.array(std_df[condition]['Height_R2'])
bar_width = 0.3
x = np.arange(len(categories))  
ax[0][0].bar(x - bar_width, ct, yerr=ct_sd, capsize=5, width=bar_width, label='CT', color='#8B4513', ecolor='red')
ax[0][0].bar(x, baseline, width=bar_width, yerr=baseline_sd, capsize=5,  label='Baseline GWAS', color='#FFB347', ecolor='red')
ax[0][0].grid(True, which='both', axis='y', linestyle='--', linewidth=0.7, color='gray', alpha=0.5)
ax[0][0].text(-0.435, 0.098, 'a)', fontsize=50, fontweight='bold', va='top', ha='right')
ax[0][0].set_facecolor('#f0f0f0')
ax[0][0].set_ylabel('$R^2$', fontsize=40)
ax[0][0].set_xlabel('p-value Thresholds', fontsize=40)
ax[0][0].set_xticks(x-0.17, categories)
ax[0][0].tick_params(axis='y',labelsize=30)
ax[0][0].tick_params(axis='x',labelsize=30)

ax[0][1].set_title('Body Mass Index', fontsize=40,\
                   bbox=dict(facecolor='#f0f0f0',edgecolor='black',boxstyle='round'), y=1.05)
baseline = np.array([0.04017027]*len(categories))
baseline_sd = np.array([0.007459207079]*len(categories))
condition = ((df["p_value"].isin(categories)) & (df["r2"] == 0.01) & (df["kb"] == 500) & (df["ref_data"] == "ukbb"))
ct = np.array(df[condition]['BMI_R2'])
ct_sd = np.array(std_df[condition]['BMI_R2'])
bar_width = 0.3
x = np.arange(len(categories))  
ax[0][1].bar(x - bar_width, ct, yerr=ct_sd, capsize=5, width=bar_width, label='CT', color='#8B4513', ecolor='red')
ax[0][1].bar(x, baseline, width=bar_width, yerr=baseline_sd, capsize=5, label='Baseline GWAS', color='#FFB347', ecolor='red')
ax[0][1].grid(True, which='both', axis='y', linestyle='--', linewidth=0.7, color='gray', alpha=0.5)
ax[0][1].text(-0.435, 0.079, 'b)', fontsize=50, fontweight='bold', va='top', ha='right')
ax[0][1].set_facecolor('#f0f0f0')
ax[0][1].set_ylabel('$R^2$', fontsize=40)
ax[0][1].set_xlabel('p-value Thresholds', fontsize=40)
ax[0][1].set_xticks(x-0.17, categories)
ax[0][1].tick_params(axis='y',labelsize=30)
ax[0][1].tick_params(axis='x',labelsize=30)

ax[1][0].set_title('Systolic Blood Pressure', fontsize=40,\
                   bbox=dict(facecolor='#f0f0f0',edgecolor='black',boxstyle='round'), y=1.05)
baseline = np.array([0.03032532]*len(categories))
baseline_sd = np.array([0.002001953651]*len(categories))
condition = ((df["p_value"].isin(categories)) & (df["r2"] == 0.5) & (df["kb"] == 100) & (df["ref_data"] == "1kg"))
ct = np.array(df[condition]['SBP_R2'])
ct_sd = np.array(std_df[condition]['SBP_R2'])
bar_width = 0.3
x = np.arange(len(categories))  
ax[1][0].bar(x - bar_width, ct, yerr=ct_sd, capsize=5, width=bar_width, label='CT', color='#8B4513', ecolor='red')
ax[1][0].bar(x, baseline, width=bar_width, yerr=baseline_sd, capsize=5, label='Baseline GWAS', color='#FFB347', ecolor='red')
ax[1][0].grid(True, which='both', axis='y', linestyle='--', linewidth=0.7, color='gray', alpha=0.5)
ax[1][0].text(-0.435, 0.052, 'c)', fontsize=50, fontweight='bold', va='top', ha='right')
ax[1][0].set_facecolor('#f0f0f0')
ax[1][0].set_ylabel('$R^2$', fontsize=40)
ax[1][0].set_xlabel('p-value Thresholds', fontsize=40)
ax[1][0].set_xticks(x-0.17, categories)
ax[1][0].tick_params(axis='y',labelsize=30)
ax[1][0].tick_params(axis='x',labelsize=30)

ax[1][1].set_title('Diastolic Blood Pressure', fontsize=40,\
                   bbox=dict(facecolor='#f0f0f0',edgecolor='black',boxstyle='round'), y=1.05)
baseline = np.array([0.02413398333]*len(categories))
baseline_sd = np.array([0.006680744196]*len(categories))
condition = ((df["p_value"].isin(categories)) & (df["r2"] == 0.2) & (df["kb"] == 250) & (df["ref_data"] == "1kg"))
ct = np.array(df[condition]['DBP_R2'])
ct_sd = np.array(std_df[condition]['DBP_R2'])
bar_width = 0.3
x = np.arange(len(categories))  
ax[1][1].bar(x - bar_width, ct, yerr=ct_sd, capsize=5, width=bar_width, label='CT', color='#8B4513', ecolor='red')
ax[1][1].bar(x, baseline, width=bar_width, yerr=baseline_sd, capsize=5, label='Baseline GWAS', color='#FFB347', ecolor='red')
ax[1][1].grid(True, which='both', axis='y', linestyle='--', linewidth=0.7, color='gray', alpha=0.5)
ax[1][1].text(-0.435, 0.042, 'd)', fontsize=50, fontweight='bold', va='top', ha='right')
ax[1][1].set_facecolor('#f0f0f0')
ax[1][1].set_ylabel('$R^2$', fontsize=40)
ax[1][1].set_xlabel('p-value Thresholds', fontsize=40)
ax[1][1].set_xticks(x-0.17, categories)
ax[1][1].tick_params(axis='y',labelsize=30)
ax[1][1].tick_params(axis='x',labelsize=30)

ax[2][0].set_title('High Density Lipoprotein', fontsize=40,\
                   bbox=dict(facecolor='#f0f0f0',edgecolor='black',boxstyle='round'), y=1.05)
baseline = np.array([0.03318275]*len(categories))
baseline_sd = np.array([0.006125114243]*len(categories))
condition = ((df["p_value"].isin(categories)) & (df["r2"] == 0.1) & (df["kb"] == 500) & (df["ref_data"] == "ukbb"))
ct = np.array(df[condition]['HDL_R2'])
ct_sd = np.array(std_df[condition]['HDL_R2'])
bar_width = 0.3
x = np.arange(len(categories))  
ax[2][0].bar(x - bar_width, ct, yerr=ct_sd, capsize=5, width=bar_width, label='CT', color='#8B4513', ecolor='red')
ax[2][0].bar(x, baseline, width=bar_width, yerr=baseline_sd, capsize=5, label='Baseline GWAS', color='#FFB347', ecolor='red')
ax[2][0].grid(True, which='both', axis='y', linestyle='--', linewidth=0.7, color='gray', alpha=0.5)
ax[2][0].text(-0.435, 0.059, 'e)', fontsize=50, fontweight='bold', va='top', ha='right')
ax[2][0].set_facecolor('#f0f0f0')
ax[2][0].set_ylabel('$R^2$', fontsize=40)
ax[2][0].set_xlabel('p-value Thresholds', fontsize=40)
ax[2][0].set_xticks(x-0.17, categories)
ax[2][0].tick_params(axis='y',labelsize=30)
ax[2][0].tick_params(axis='x',labelsize=30)

ax[2][1].set_title('Low Density Lipoprotein', fontsize=40,\
                   bbox=dict(facecolor='#f0f0f0',edgecolor='black',boxstyle='round'), y=1.05)
baseline = np.array([0.03673355667]*len(categories))
baseline_sd = np.array([0.01221683899]*len(categories))
condition = ((df["p_value"].isin(categories)) & (df["r2"] == 0.5) & (df["kb"] == 1000) & (df["ref_data"] == "ukbb"))
ct = np.array(df[condition]['LDL_R2'])
ct_sd = np.array(std_df[condition]['LDL_R2'])
bar_width = 0.3
x = np.arange(len(categories))  
ax[2][1].bar(x - bar_width, ct, yerr=ct_sd, capsize=5, width=bar_width, label='CT', color='#8B4513', ecolor='red')
ax[2][1].bar(x, baseline, width=bar_width, yerr=baseline_sd, capsize=5, label='Baseline GWAS', color='#FFB347', ecolor='red')
ax[2][1].grid(True, which='both', axis='y', linestyle='--', linewidth=0.7, color='gray', alpha=0.5)
ax[2][1].text(-0.435, 0.066, 'f)', fontsize=50, fontweight='bold', va='top', ha='right')
ax[2][1].set_facecolor('#f0f0f0')
ax[2][1].set_ylabel('$R^2$', fontsize=40)
ax[2][1].set_xlabel('p-value Thresholds', fontsize=40)
ax[2][1].set_xticks(x-0.17, categories)
ax[2][1].tick_params(axis='y',labelsize=30)
ax[2][1].tick_params(axis='x',labelsize=30)

ax[3][0].set_title('Total Cholesterol', fontsize=40,\
                   bbox=dict(facecolor='#f0f0f0',edgecolor='black',boxstyle='round'), y=1.05)
baseline = np.array([0.03301616667]*len(categories))
baseline_sd = np.array([0.001477404936]*len(categories))
condition = ((df["p_value"].isin(categories)) & (df["r2"] == 0.01) & (df["kb"] == 50) & (df["ref_data"] == "1kg"))
ct = np.array(df[condition]['TC_R2'])
ct_sd = np.array(std_df[condition]['TC_R2'])
bar_width = 0.3
x = np.arange(len(categories))  
ax[3][0].bar(x - bar_width, ct, yerr=ct_sd, capsize=5, width=bar_width, label='CT', color='#8B4513', ecolor='red')
ax[3][0].bar(x, baseline, width=bar_width, yerr=baseline_sd, capsize=5, label='Baseline GWAS', color='#FFB347', ecolor='red')
ax[3][0].grid(True, which='both', axis='y', linestyle='--', linewidth=0.7, color='gray', alpha=0.5)
ax[3][0].text(-0.435, 0.058, 'g)', fontsize=50, fontweight='bold', va='top', ha='right')
ax[3][0].set_facecolor('#f0f0f0')
ax[3][0].set_ylabel('$R^2$', fontsize=40)
ax[3][0].set_xlabel('p-value Thresholds', fontsize=40)
ax[3][0].set_xticks(x-0.17, categories)
ax[3][0].tick_params(axis='y',labelsize=30)
ax[3][0].tick_params(axis='x',labelsize=30)

ax[3][1].set_title('Triglycerides', fontsize=40,\
                   bbox=dict(facecolor='#f0f0f0',edgecolor='black',boxstyle='round'), y=1.05)
baseline = np.array([0.04080041667]*len(categories))
baseline_sd = np.array([0.005592847697]*len(categories))
condition = ((df["p_value"].isin(categories)) & (df["r2"] == 0.1) & (df["kb"] == 50) & (df["ref_data"] == "1kg"))
ct = np.array(df[condition]['TG_R2'])
ct_sd = np.array(std_df[condition]['TG_R2'])
bar_width = 0.3
x = np.arange(len(categories))  
ax[3][1].bar(x - bar_width, ct, yerr=ct_sd, capsize=5, width=bar_width, label='CT', color='#8B4513', ecolor='red')
ax[3][1].bar(x, baseline, width=bar_width, yerr=baseline_sd, capsize=5, label='Baseline GWAS', color='#FFB347', ecolor='red')
ax[3][1].grid(True, which='both', axis='y', linestyle='--', linewidth=0.7, color='gray', alpha=0.5)
ax[3][1].text(-0.435, 0.081, 'h)', fontsize=50, fontweight='bold', va='top', ha='right')
ax[3][1].set_facecolor('#f0f0f0')
ax[3][1].set_ylabel('$R^2$', fontsize=40)
ax[3][1].set_xlabel('p-value Thresholds', fontsize=40)
ax[3][1].set_xticks(x-0.17, categories)
ax[3][1].tick_params(axis='y',labelsize=30)
ax[3][1].tick_params(axis='x',labelsize=30)

proxy_artists = [
    mpatches.Patch(facecolor='#8B4513', label='Clumping and Thresholding'),
    mpatches.Patch(facecolor='#FFB347', label='Baseline GWAS')
]

# Add the common legend to the figure
fig.legend(handles=proxy_artists, loc='lower center', bbox_to_anchor=(0.5, -0.06), ncol=6, fontsize=35)

fig.savefig("/Users/ritwizkamal/BIRDS_server/AA_FinalGithub/Plots/CTvsBaseline_BarPlots.pdf",\
            format='pdf', bbox_inches='tight')
