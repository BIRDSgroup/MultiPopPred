# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # Load Data:

# %%
data = pd.read_csv('/Figures/Data/SimulBinary.csv',\
                   sep=',', header = None)

# %%
data
# Out:
#                       0                                 1             2   \
# 0    MPP-GWAS\n(AUC-ROC)  #Tar: 100\nBinary Y Log Training           EUR
# 1                    NaN                         SET 1.1.1   0.583679834
# 2                    NaN                         SET 1.1.2   0.554925585
# 3                    NaN                         SET 1.1.3   0.610954263
# 4                    NaN                         SET 1.1.4   0.699819168
# ..                   ...                               ...           ...
# 216                  NaN                         SET 1.1.3  0.4858836815
# 217                  NaN                         SET 1.1.4  0.6133212779
# 218                  NaN                         SET 1.1.5   0.587394412
# 219                  NaN                           AVERAGE  0.5358124873
# 220                  NaN                           STD DEV  0.0607714216
#
#               3              4                  5   \
# ...

# %% [markdown]
# # Arrange Data:

# %%
# e1 <- 1.1.1 to 1.1.5
# e2 <- 1.2.1 to 1.2.5
# e3 <- 1.4.1 to 1.4.5
# e4 <- 1.5.1 to 1.5.5
# e5 <- 1.6.1 to 1.6.5

# g0 <- 0 Aux
# g1 <- Eur
# g2 <- EurEas
# g3 <- EurEasAmr
# g4 <- EurEasAmrAfr

# %%
# Log Model ====================================================
mppV1_log_e1_g1 = np.array(data.iloc[1:6,28], dtype=float)
mppV1_log_e1_g2 = np.array(data.iloc[1:6,29], dtype=float)
mppV1_log_e1_g3 = np.array(data.iloc[1:6,30], dtype=float)
mppV1_log_e1_g4 = np.array(data.iloc[1:6,31], dtype=float)

mppV1_log_e2_g1 = np.array(data.iloc[1:6,33], dtype=float)
mppV1_log_e2_g2 = np.array(data.iloc[1:6,34], dtype=float)
mppV1_log_e2_g3 = np.array(data.iloc[1:6,35], dtype=float)
mppV1_log_e2_g4 = np.array(data.iloc[1:6,36], dtype=float)

mppV1_log_e3_g1 = np.array(data.iloc[1:6,38], dtype=float)
mppV1_log_e3_g2 = np.array(data.iloc[1:6,39], dtype=float)
mppV1_log_e3_g3 = np.array(data.iloc[1:6,40], dtype=float)
mppV1_log_e3_g4 = np.array(data.iloc[1:6,41], dtype=float)

mppV1_log_e4_g1 = np.array(data.iloc[1:6,43], dtype=float)
mppV1_log_e4_g2 = np.array(data.iloc[1:6,44], dtype=float)
mppV1_log_e4_g3 = np.array(data.iloc[1:6,45], dtype=float)
mppV1_log_e4_g4 = np.array(data.iloc[1:6,46], dtype=float)

mppV1_log_e5_g1 = np.array(data.iloc[1:6,48], dtype=float)
mppV1_log_e5_g2 = np.array(data.iloc[1:6,49], dtype=float)
mppV1_log_e5_g3 = np.array(data.iloc[1:6,50], dtype=float)
mppV1_log_e5_g4 = np.array(data.iloc[1:6,51], dtype=float)

# Lin Model - Pheno ====================================================
mppV1_pheno_e1_g1 = np.array(data.iloc[9:14,28], dtype=float)
mppV1_pheno_e1_g2 = np.array(data.iloc[9:14,29], dtype=float)
mppV1_pheno_e1_g3 = np.array(data.iloc[9:14,30], dtype=float)
mppV1_pheno_e1_g4 = np.array(data.iloc[9:14,31], dtype=float)

mppV1_pheno_e2_g1 = np.array(data.iloc[9:14,33], dtype=float)
mppV1_pheno_e2_g2 = np.array(data.iloc[9:14,34], dtype=float)
mppV1_pheno_e2_g3 = np.array(data.iloc[9:14,35], dtype=float)
mppV1_pheno_e2_g4 = np.array(data.iloc[9:14,36], dtype=float)

mppV1_pheno_e3_g1 = np.array(data.iloc[9:14,38], dtype=float)
mppV1_pheno_e3_g2 = np.array(data.iloc[9:14,39], dtype=float)
mppV1_pheno_e3_g3 = np.array(data.iloc[9:14,40], dtype=float)
mppV1_pheno_e3_g4 = np.array(data.iloc[9:14,41], dtype=float)

mppV1_pheno_e4_g1 = np.array(data.iloc[9:14,43], dtype=float)
mppV1_pheno_e4_g2 = np.array(data.iloc[9:14,44], dtype=float)
mppV1_pheno_e4_g3 = np.array(data.iloc[9:14,45], dtype=float)
mppV1_pheno_e4_g4 = np.array(data.iloc[9:14,46], dtype=float)

mppV1_pheno_e5_g1 = np.array(data.iloc[9:14,48], dtype=float)
mppV1_pheno_e5_g2 = np.array(data.iloc[9:14,49], dtype=float)
mppV1_pheno_e5_g3 = np.array(data.iloc[9:14,50], dtype=float)
mppV1_pheno_e5_g4 = np.array(data.iloc[9:14,51], dtype=float)

# Lin Model - Lia ====================================================
mppV1_lia_e1_g1 = np.array(data.iloc[17:22,28], dtype=float)
mppV1_lia_e1_g2 = np.array(data.iloc[17:22,29], dtype=float)
mppV1_lia_e1_g3 = np.array(data.iloc[17:22,30], dtype=float)
mppV1_lia_e1_g4 = np.array(data.iloc[17:22,31], dtype=float)

mppV1_lia_e2_g1 = np.array(data.iloc[17:22,33], dtype=float)
mppV1_lia_e2_g2 = np.array(data.iloc[17:22,34], dtype=float)
mppV1_lia_e2_g3 = np.array(data.iloc[17:22,35], dtype=float)
mppV1_lia_e2_g4 = np.array(data.iloc[17:22,36], dtype=float)

mppV1_lia_e3_g1 = np.array(data.iloc[17:22,38], dtype=float)
mppV1_lia_e3_g2 = np.array(data.iloc[17:22,39], dtype=float)
mppV1_lia_e3_g3 = np.array(data.iloc[17:22,40], dtype=float)
mppV1_lia_e3_g4 = np.array(data.iloc[17:22,41], dtype=float)

mppV1_lia_e4_g1 = np.array(data.iloc[17:22,43], dtype=float)
mppV1_lia_e4_g2 = np.array(data.iloc[17:22,44], dtype=float)
mppV1_lia_e4_g3 = np.array(data.iloc[17:22,45], dtype=float)
mppV1_lia_e4_g4 = np.array(data.iloc[17:22,46], dtype=float)

mppV1_lia_e5_g1 = np.array(data.iloc[17:22,48], dtype=float)
mppV1_lia_e5_g2 = np.array(data.iloc[17:22,49], dtype=float)
mppV1_lia_e5_g3 = np.array(data.iloc[17:22,50], dtype=float)
mppV1_lia_e5_g4 = np.array(data.iloc[17:22,51], dtype=float)

# %%
# Log Model ====================================================
mppV2_log_e1_g1 = np.array([None]*5)
mppV2_log_e1_g2 = np.array([None]*5)
mppV2_log_e1_g3 = np.array([None]*5)
mppV2_log_e1_g4 = np.array([None]*5)

mppV2_log_e2_g1 = np.array([None]*5)
mppV2_log_e2_g2 = np.array([None]*5)
mppV2_log_e2_g3 = np.array([None]*5)
mppV2_log_e2_g4 = np.array([None]*5)

mppV2_log_e3_g1 = np.array([None]*5)
mppV2_log_e3_g2 = np.array([None]*5)
mppV2_log_e3_g3 = np.array([None]*5)
mppV2_log_e3_g4 = np.array([None]*5)

mppV2_log_e4_g1 = np.array([None]*5)
mppV2_log_e4_g2 = np.array([None]*5)
mppV2_log_e4_g3 = np.array([None]*5)
mppV2_log_e4_g4 = np.array([None]*5)

mppV2_log_e5_g1 = np.array([None]*5)
mppV2_log_e5_g2 = np.array([None]*5)
mppV2_log_e5_g3 = np.array([None]*5)
mppV2_log_e5_g4 = np.array([None]*5)

# Lin Model - Pheno ====================================================
mppV2_pheno_e1_g1 = np.array(data.iloc[26:31,28], dtype=float)
mppV2_pheno_e1_g2 = np.array(data.iloc[26:31,29], dtype=float)
mppV2_pheno_e1_g3 = np.array(data.iloc[26:31,30], dtype=float)
mppV2_pheno_e1_g4 = np.array(data.iloc[26:31,31], dtype=float)

mppV2_pheno_e2_g1 = np.array(data.iloc[26:31,33], dtype=float)
mppV2_pheno_e2_g2 = np.array(data.iloc[26:31,34], dtype=float)
mppV2_pheno_e2_g3 = np.array(data.iloc[26:31,35], dtype=float)
mppV2_pheno_e2_g4 = np.array(data.iloc[26:31,36], dtype=float)

mppV2_pheno_e3_g1 = np.array(data.iloc[26:31,38], dtype=float)
mppV2_pheno_e3_g2 = np.array(data.iloc[26:31,39], dtype=float)
mppV2_pheno_e3_g3 = np.array(data.iloc[26:31,40], dtype=float)
mppV2_pheno_e3_g4 = np.array(data.iloc[26:31,41], dtype=float)

mppV2_pheno_e4_g1 = np.array(data.iloc[26:31,43], dtype=float)
mppV2_pheno_e4_g2 = np.array(data.iloc[26:31,44], dtype=float)
mppV2_pheno_e4_g3 = np.array(data.iloc[26:31,45], dtype=float)
mppV2_pheno_e4_g4 = np.array(data.iloc[26:31,46], dtype=float)

mppV2_pheno_e5_g1 = np.array(data.iloc[26:31,48], dtype=float)
mppV2_pheno_e5_g2 = np.array(data.iloc[26:31,49], dtype=float)
mppV2_pheno_e5_g3 = np.array(data.iloc[26:31,50], dtype=float)
mppV2_pheno_e5_g4 = np.array(data.iloc[26:31,51], dtype=float)

# Lin Model - Lia ====================================================
mppV2_lia_e1_g1 = np.array(data.iloc[34:39,28], dtype=float)
mppV2_lia_e1_g2 = np.array(data.iloc[34:39,29], dtype=float)
mppV2_lia_e1_g3 = np.array(data.iloc[34:39,30], dtype=float)
mppV2_lia_e1_g4 = np.array(data.iloc[34:39,31], dtype=float)

mppV2_lia_e2_g1 = np.array(data.iloc[34:39,33], dtype=float)
mppV2_lia_e2_g2 = np.array(data.iloc[34:39,34], dtype=float)
mppV2_lia_e2_g3 = np.array(data.iloc[34:39,35], dtype=float)
mppV2_lia_e2_g4 = np.array(data.iloc[34:39,36], dtype=float)

mppV2_lia_e3_g1 = np.array(data.iloc[34:39,38], dtype=float)
mppV2_lia_e3_g2 = np.array(data.iloc[34:39,39], dtype=float)
mppV2_lia_e3_g3 = np.array(data.iloc[34:39,40], dtype=float)
mppV2_lia_e3_g4 = np.array(data.iloc[34:39,41], dtype=float)

mppV2_lia_e4_g1 = np.array(data.iloc[34:39,43], dtype=float)
mppV2_lia_e4_g2 = np.array(data.iloc[34:39,44], dtype=float)
mppV2_lia_e4_g3 = np.array(data.iloc[34:39,45], dtype=float)
mppV2_lia_e4_g4 = np.array(data.iloc[34:39,46], dtype=float)

mppV2_lia_e5_g1 = np.array(data.iloc[34:39,48], dtype=float)
mppV2_lia_e5_g2 = np.array(data.iloc[34:39,49], dtype=float)
mppV2_lia_e5_g3 = np.array(data.iloc[34:39,50], dtype=float)
mppV2_lia_e5_g4 = np.array(data.iloc[34:39,51], dtype=float)

# %%
# Log Model ====================================================
mppV3_log_e1_g1 = np.array(data.iloc[43:48,28], dtype=float)
mppV3_log_e1_g2 = np.array(data.iloc[43:48,29], dtype=float)
mppV3_log_e1_g3 = np.array(data.iloc[43:48,30], dtype=float)
mppV3_log_e1_g4 = np.array(data.iloc[43:48,31], dtype=float)

mppV3_log_e2_g1 = np.array(data.iloc[43:48,33], dtype=float)
mppV3_log_e2_g2 = np.array(data.iloc[43:48,34], dtype=float)
mppV3_log_e2_g3 = np.array(data.iloc[43:48,35], dtype=float)
mppV3_log_e2_g4 = np.array(data.iloc[43:48,36], dtype=float)

mppV3_log_e3_g1 = np.array(data.iloc[43:48,38], dtype=float)
mppV3_log_e3_g2 = np.array(data.iloc[43:48,39], dtype=float)
mppV3_log_e3_g3 = np.array(data.iloc[43:48,40], dtype=float)
mppV3_log_e3_g4 = np.array(data.iloc[43:48,41], dtype=float)

mppV3_log_e4_g1 = np.array(data.iloc[43:48,43], dtype=float)
mppV3_log_e4_g2 = np.array(data.iloc[43:48,44], dtype=float)
mppV3_log_e4_g3 = np.array(data.iloc[43:48,45], dtype=float)
mppV3_log_e4_g4 = np.array(data.iloc[43:48,46], dtype=float)

mppV3_log_e5_g1 = np.array(data.iloc[43:48,48], dtype=float)
mppV3_log_e5_g2 = np.array(data.iloc[43:48,49], dtype=float)
mppV3_log_e5_g3 = np.array(data.iloc[43:48,50], dtype=float)
mppV3_log_e5_g4 = np.array(data.iloc[43:48,51], dtype=float)

# Lin Model - Pheno ====================================================
mppV3_pheno_e1_g1 = np.array(data.iloc[51:56,28], dtype=float)
mppV3_pheno_e1_g2 = np.array(data.iloc[51:56,29], dtype=float)
mppV3_pheno_e1_g3 = np.array(data.iloc[51:56,30], dtype=float)
mppV3_pheno_e1_g4 = np.array(data.iloc[51:56,31], dtype=float)

mppV3_pheno_e2_g1 = np.array(data.iloc[51:56,33], dtype=float)
mppV3_pheno_e2_g2 = np.array(data.iloc[51:56,34], dtype=float)
mppV3_pheno_e2_g3 = np.array(data.iloc[51:56,35], dtype=float)
mppV3_pheno_e2_g4 = np.array(data.iloc[51:56,36], dtype=float)

mppV3_pheno_e3_g1 = np.array(data.iloc[51:56,38], dtype=float)
mppV3_pheno_e3_g2 = np.array(data.iloc[51:56,39], dtype=float)
mppV3_pheno_e3_g3 = np.array(data.iloc[51:56,40], dtype=float)
mppV3_pheno_e3_g4 = np.array(data.iloc[51:56,41], dtype=float)

mppV3_pheno_e4_g1 = np.array(data.iloc[51:56,43], dtype=float)
mppV3_pheno_e4_g2 = np.array(data.iloc[51:56,44], dtype=float)
mppV3_pheno_e4_g3 = np.array(data.iloc[51:56,45], dtype=float)
mppV3_pheno_e4_g4 = np.array(data.iloc[51:56,46], dtype=float)

mppV3_pheno_e5_g1 = np.array(data.iloc[51:56,48], dtype=float)
mppV3_pheno_e5_g2 = np.array(data.iloc[51:56,49], dtype=float)
mppV3_pheno_e5_g3 = np.array(data.iloc[51:56,50], dtype=float)
mppV3_pheno_e5_g4 = np.array(data.iloc[51:56,51], dtype=float)

# Lin Model - Lia ====================================================
mppV3_lia_e1_g1 = np.array(data.iloc[59:64,28], dtype=float)
mppV3_lia_e1_g2 = np.array(data.iloc[59:64,29], dtype=float)
mppV3_lia_e1_g3 = np.array(data.iloc[59:64,30], dtype=float)
mppV3_lia_e1_g4 = np.array(data.iloc[59:64,31], dtype=float)

mppV3_lia_e2_g1 = np.array(data.iloc[59:64,33], dtype=float)
mppV3_lia_e2_g2 = np.array(data.iloc[59:64,34], dtype=float)
mppV3_lia_e2_g3 = np.array(data.iloc[59:64,35], dtype=float)
mppV3_lia_e2_g4 = np.array(data.iloc[59:64,36], dtype=float)

mppV3_lia_e3_g1 = np.array(data.iloc[59:64,38], dtype=float)
mppV3_lia_e3_g2 = np.array(data.iloc[59:64,39], dtype=float)
mppV3_lia_e3_g3 = np.array(data.iloc[59:64,40], dtype=float)
mppV3_lia_e3_g4 = np.array(data.iloc[59:64,41], dtype=float)

mppV3_lia_e4_g1 = np.array(data.iloc[59:64,43], dtype=float)
mppV3_lia_e4_g2 = np.array(data.iloc[59:64,44], dtype=float)
mppV3_lia_e4_g3 = np.array(data.iloc[59:64,45], dtype=float)
mppV3_lia_e4_g4 = np.array(data.iloc[59:64,46], dtype=float)

mppV3_lia_e5_g1 = np.array(data.iloc[59:64,48], dtype=float)
mppV3_lia_e5_g2 = np.array(data.iloc[59:64,49], dtype=float)
mppV3_lia_e5_g3 = np.array(data.iloc[59:64,50], dtype=float)
mppV3_lia_e5_g4 = np.array(data.iloc[59:64,51], dtype=float)

# %%
# Log Model ====================================================
mppV4_log_e1_g1 = np.array(data.iloc[68:73,28], dtype=float)
mppV4_log_e1_g2 = np.array(data.iloc[68:73,29], dtype=float)
mppV4_log_e1_g3 = np.array(data.iloc[68:73,30], dtype=float)
mppV4_log_e1_g4 = np.array(data.iloc[68:73,31], dtype=float)

mppV4_log_e2_g1 = np.array(data.iloc[68:73,33], dtype=float)
mppV4_log_e2_g2 = np.array(data.iloc[68:73,34], dtype=float)
mppV4_log_e2_g3 = np.array(data.iloc[68:73,35], dtype=float)
mppV4_log_e2_g4 = np.array(data.iloc[68:73,36], dtype=float)

mppV4_log_e3_g1 = np.array(data.iloc[68:73,38], dtype=float)
mppV4_log_e3_g2 = np.array(data.iloc[68:73,39], dtype=float)
mppV4_log_e3_g3 = np.array(data.iloc[68:73,40], dtype=float)
mppV4_log_e3_g4 = np.array(data.iloc[68:73,41], dtype=float)

mppV4_log_e4_g1 = np.array(data.iloc[68:73,43], dtype=float)
mppV4_log_e4_g2 = np.array(data.iloc[68:73,44], dtype=float)
mppV4_log_e4_g3 = np.array(data.iloc[68:73,45], dtype=float)
mppV4_log_e4_g4 = np.array(data.iloc[68:73,46], dtype=float)

mppV4_log_e5_g1 = np.array(data.iloc[68:73,48], dtype=float)
mppV4_log_e5_g2 = np.array(data.iloc[68:73,49], dtype=float)
mppV4_log_e5_g3 = np.array(data.iloc[68:73,50], dtype=float)
mppV4_log_e5_g4 = np.array(data.iloc[68:73,51], dtype=float)

# Lin Model - Pheno ====================================================
mppV4_pheno_e1_g1 = np.array(data.iloc[76:81,28], dtype=float)
mppV4_pheno_e1_g2 = np.array(data.iloc[76:81,29], dtype=float)
mppV4_pheno_e1_g3 = np.array(data.iloc[76:81,30], dtype=float)
mppV4_pheno_e1_g4 = np.array(data.iloc[76:81,31], dtype=float)

mppV4_pheno_e2_g1 = np.array(data.iloc[76:81,33], dtype=float)
mppV4_pheno_e2_g2 = np.array(data.iloc[76:81,34], dtype=float)
mppV4_pheno_e2_g3 = np.array(data.iloc[76:81,35], dtype=float)
mppV4_pheno_e2_g4 = np.array(data.iloc[76:81,36], dtype=float)

mppV4_pheno_e3_g1 = np.array(data.iloc[76:81,38], dtype=float)
mppV4_pheno_e3_g2 = np.array(data.iloc[76:81,39], dtype=float)
mppV4_pheno_e3_g3 = np.array(data.iloc[76:81,40], dtype=float)
mppV4_pheno_e3_g4 = np.array(data.iloc[76:81,41], dtype=float)

mppV4_pheno_e4_g1 = np.array(data.iloc[76:81,43], dtype=float)
mppV4_pheno_e4_g2 = np.array(data.iloc[76:81,44], dtype=float)
mppV4_pheno_e4_g3 = np.array(data.iloc[76:81,45], dtype=float)
mppV4_pheno_e4_g4 = np.array(data.iloc[76:81,46], dtype=float)

mppV4_pheno_e5_g1 = np.array(data.iloc[76:81,48], dtype=float)
mppV4_pheno_e5_g2 = np.array(data.iloc[76:81,49], dtype=float)
mppV4_pheno_e5_g3 = np.array(data.iloc[76:81,50], dtype=float)
mppV4_pheno_e5_g4 = np.array(data.iloc[76:81,51], dtype=float)

# Lin Model - Lia ====================================================
mppV4_lia_e1_g1 = np.array(data.iloc[84:89,28], dtype=float)
mppV4_lia_e1_g2 = np.array(data.iloc[84:89,29], dtype=float)
mppV4_lia_e1_g3 = np.array(data.iloc[84:89,30], dtype=float)
mppV4_lia_e1_g4 = np.array(data.iloc[84:89,31], dtype=float)

mppV4_lia_e2_g1 = np.array(data.iloc[84:89,33], dtype=float)
mppV4_lia_e2_g2 = np.array(data.iloc[84:89,34], dtype=float)
mppV4_lia_e2_g3 = np.array(data.iloc[84:89,35], dtype=float)
mppV4_lia_e2_g4 = np.array(data.iloc[84:89,36], dtype=float)

mppV4_lia_e3_g1 = np.array(data.iloc[84:89,38], dtype=float)
mppV4_lia_e3_g2 = np.array(data.iloc[84:89,39], dtype=float)
mppV4_lia_e3_g3 = np.array(data.iloc[84:89,40], dtype=float)
mppV4_lia_e3_g4 = np.array(data.iloc[84:89,41], dtype=float)

mppV4_lia_e4_g1 = np.array(data.iloc[84:89,43], dtype=float)
mppV4_lia_e4_g2 = np.array(data.iloc[84:89,44], dtype=float)
mppV4_lia_e4_g3 = np.array(data.iloc[84:89,45], dtype=float)
mppV4_lia_e4_g4 = np.array(data.iloc[84:89,46], dtype=float)

mppV4_lia_e5_g1 = np.array(data.iloc[84:89,48], dtype=float)
mppV4_lia_e5_g2 = np.array(data.iloc[84:89,49], dtype=float)
mppV4_lia_e5_g3 = np.array(data.iloc[84:89,50], dtype=float)
mppV4_lia_e5_g4 = np.array(data.iloc[84:89,51], dtype=float)

# %%
# Log Model ====================================================
mppV4B_log_e1_g1 = np.array(data.iloc[93:98,28], dtype=float)
mppV4B_log_e1_g2 = np.array(data.iloc[93:98,29], dtype=float)
mppV4B_log_e1_g3 = np.array(data.iloc[93:98,30], dtype=float)
mppV4B_log_e1_g4 = np.array(data.iloc[93:98,31], dtype=float)

mppV4B_log_e2_g1 = np.array(data.iloc[93:98,33], dtype=float)
mppV4B_log_e2_g2 = np.array(data.iloc[93:98,34], dtype=float)
mppV4B_log_e2_g3 = np.array(data.iloc[93:98,35], dtype=float)
mppV4B_log_e2_g4 = np.array(data.iloc[93:98,36], dtype=float)

mppV4B_log_e3_g1 = np.array(data.iloc[93:98,38], dtype=float)
mppV4B_log_e3_g2 = np.array(data.iloc[93:98,39], dtype=float)
mppV4B_log_e3_g3 = np.array(data.iloc[93:98,40], dtype=float)
mppV4B_log_e3_g4 = np.array(data.iloc[93:98,41], dtype=float)

mppV4B_log_e4_g1 = np.array(data.iloc[93:98,43], dtype=float)
mppV4B_log_e4_g2 = np.array(data.iloc[93:98,44], dtype=float)
mppV4B_log_e4_g3 = np.array(data.iloc[93:98,45], dtype=float)
mppV4B_log_e4_g4 = np.array(data.iloc[93:98,46], dtype=float)

mppV4B_log_e5_g1 = np.array(data.iloc[93:98,48], dtype=float)
mppV4B_log_e5_g2 = np.array(data.iloc[93:98,49], dtype=float)
mppV4B_log_e5_g3 = np.array(data.iloc[93:98,50], dtype=float)
mppV4B_log_e5_g4 = np.array(data.iloc[93:98,51], dtype=float)

# Lin Model - Pheno ====================================================
mppV4B_pheno_e1_g1 = np.array(data.iloc[101:106,28], dtype=float)
mppV4B_pheno_e1_g2 = np.array(data.iloc[101:106,29], dtype=float)
mppV4B_pheno_e1_g3 = np.array(data.iloc[101:106,30], dtype=float)
mppV4B_pheno_e1_g4 = np.array(data.iloc[101:106,31], dtype=float)

mppV4B_pheno_e2_g1 = np.array(data.iloc[101:106,33], dtype=float)
mppV4B_pheno_e2_g2 = np.array(data.iloc[101:106,34], dtype=float)
mppV4B_pheno_e2_g3 = np.array(data.iloc[101:106,35], dtype=float)
mppV4B_pheno_e2_g4 = np.array(data.iloc[101:106,36], dtype=float)

mppV4B_pheno_e3_g1 = np.array(data.iloc[101:106,38], dtype=float)
mppV4B_pheno_e3_g2 = np.array(data.iloc[101:106,39], dtype=float)
mppV4B_pheno_e3_g3 = np.array(data.iloc[101:106,40], dtype=float)
mppV4B_pheno_e3_g4 = np.array(data.iloc[101:106,41], dtype=float)

mppV4B_pheno_e4_g1 = np.array(data.iloc[101:106,43], dtype=float)
mppV4B_pheno_e4_g2 = np.array(data.iloc[101:106,44], dtype=float)
mppV4B_pheno_e4_g3 = np.array(data.iloc[101:106,45], dtype=float)
mppV4B_pheno_e4_g4 = np.array(data.iloc[101:106,46], dtype=float)

mppV4B_pheno_e5_g1 = np.array(data.iloc[101:106,48], dtype=float)
mppV4B_pheno_e5_g2 = np.array(data.iloc[101:106,49], dtype=float)
mppV4B_pheno_e5_g3 = np.array(data.iloc[101:106,50], dtype=float)
mppV4B_pheno_e5_g4 = np.array(data.iloc[101:106,51], dtype=float)

# Lin Model - Lia ====================================================
mppV4B_lia_e1_g1 = np.array(data.iloc[109:114,28], dtype=float)
mppV4B_lia_e1_g2 = np.array(data.iloc[109:114,29], dtype=float)
mppV4B_lia_e1_g3 = np.array(data.iloc[109:114,30], dtype=float)
mppV4B_lia_e1_g4 = np.array(data.iloc[109:114,31], dtype=float)

mppV4B_lia_e2_g1 = np.array(data.iloc[109:114,33], dtype=float)
mppV4B_lia_e2_g2 = np.array(data.iloc[109:114,34], dtype=float)
mppV4B_lia_e2_g3 = np.array(data.iloc[109:114,35], dtype=float)
mppV4B_lia_e2_g4 = np.array(data.iloc[109:114,36], dtype=float)

mppV4B_lia_e3_g1 = np.array(data.iloc[109:114,38], dtype=float)
mppV4B_lia_e3_g2 = np.array(data.iloc[109:114,39], dtype=float)
mppV4B_lia_e3_g3 = np.array(data.iloc[109:114,40], dtype=float)
mppV4B_lia_e3_g4 = np.array(data.iloc[109:114,41], dtype=float)

mppV4B_lia_e4_g1 = np.array(data.iloc[109:114,43], dtype=float)
mppV4B_lia_e4_g2 = np.array(data.iloc[109:114,44], dtype=float)
mppV4B_lia_e4_g3 = np.array(data.iloc[109:114,45], dtype=float)
mppV4B_lia_e4_g4 = np.array(data.iloc[109:114,46], dtype=float)

mppV4B_lia_e5_g1 = np.array(data.iloc[109:114,48], dtype=float)
mppV4B_lia_e5_g2 = np.array(data.iloc[109:114,49], dtype=float)
mppV4B_lia_e5_g3 = np.array(data.iloc[109:114,50], dtype=float)
mppV4B_lia_e5_g4 = np.array(data.iloc[109:114,51], dtype=float)

# %%
# Log Model ====================================================
lassosumTLD_log_e1_g0 = np.array(data.iloc[118:123,28], dtype=float)

lassosumTLD_log_e2_g0 = np.array(data.iloc[118:123,33], dtype=float)

lassosumTLD_log_e3_g0 = np.array(data.iloc[118:123,38], dtype=float)

lassosumTLD_log_e4_g0 = np.array(data.iloc[118:123,43], dtype=float)

lassosumTLD_log_e5_g0 = np.array(data.iloc[118:123,48], dtype=float)

# Lin Model - Pheno ====================================================
lassosumTLD_pheno_e1_g0 = np.array(data.iloc[126:131,28], dtype=float)

lassosumTLD_pheno_e2_g0 = np.array(data.iloc[126:131,33], dtype=float)

lassosumTLD_pheno_e3_g0 = np.array(data.iloc[126:131,38], dtype=float)

lassosumTLD_pheno_e4_g0 = np.array(data.iloc[126:131,43], dtype=float)

lassosumTLD_pheno_e5_g0 = np.array(data.iloc[126:131,48], dtype=float)

# Lin Model - Lia ====================================================
lassosumTLD_lia_e1_g0 = np.array(data.iloc[134:139,28], dtype=float)

lassosumTLD_lia_e2_g0 = np.array(data.iloc[134:139,33], dtype=float)

lassosumTLD_lia_e3_g0 = np.array(data.iloc[134:139,38], dtype=float)

lassosumTLD_lia_e4_g0 = np.array(data.iloc[134:139,43], dtype=float)

lassosumTLD_lia_e5_g0 = np.array(data.iloc[134:139,48], dtype=float)

# %%
# Log Model ====================================================
baseline_log_e1_g0 = np.array(data.iloc[143:148,28], dtype=float)

baseline_log_e2_g0 = np.array(data.iloc[143:148,33], dtype=float)

baseline_log_e3_g0 = np.array(data.iloc[143:148,38], dtype=float)

baseline_log_e4_g0 = np.array(data.iloc[143:148,43], dtype=float)

baseline_log_e5_g0 = np.array(data.iloc[143:148,48], dtype=float)

# Lin Model - Pheno ====================================================
baseline_pheno_e1_g0 = np.array(data.iloc[143:148,28], dtype=float)

baseline_pheno_e2_g0 = np.array(data.iloc[143:148,33], dtype=float)

baseline_pheno_e3_g0 = np.array(data.iloc[143:148,38], dtype=float)

baseline_pheno_e4_g0 = np.array(data.iloc[143:148,43], dtype=float)

baseline_pheno_e5_g0 = np.array(data.iloc[143:148,48], dtype=float)

# Lin Model - Lia ====================================================
baseline_lia_e1_g0 = np.array(data.iloc[151:156,28], dtype=float)

baseline_lia_e2_g0 = np.array(data.iloc[151:156,33], dtype=float)

baseline_lia_e3_g0 = np.array(data.iloc[151:156,38], dtype=float)

baseline_lia_e4_g0 = np.array(data.iloc[151:156,43], dtype=float)

baseline_lia_e5_g0 = np.array(data.iloc[151:156,48], dtype=float)

# %%
# Log Model ====================================================
lassosum2_log_e1_g0 = np.array(data.iloc[160:165,28], dtype=float)

lassosum2_log_e2_g0 = np.array(data.iloc[160:165,33], dtype=float)

lassosum2_log_e3_g0 = np.array(data.iloc[160:165,38], dtype=float)

lassosum2_log_e4_g0 = np.array(data.iloc[160:165,43], dtype=float)

lassosum2_log_e5_g0 = np.array(data.iloc[160:165,48], dtype=float)

# %%
# Log Model ====================================================
prosper_log_e1_g1 = np.array(data.iloc[169:174,28], dtype=float)
prosper_log_e1_g2 = np.array(data.iloc[169:174,29], dtype=float)
prosper_log_e1_g3 = np.array(data.iloc[169:174,30], dtype=float)
prosper_log_e1_g4 = np.array(data.iloc[169:174,31], dtype=float)

prosper_log_e2_g1 = np.array(data.iloc[169:174,33], dtype=float)
prosper_log_e2_g2 = np.array(data.iloc[169:174,34], dtype=float)
prosper_log_e2_g3 = np.array(data.iloc[169:174,35], dtype=float)
prosper_log_e2_g4 = np.array(data.iloc[169:174,36], dtype=float)

prosper_log_e3_g1 = np.array(data.iloc[169:174,38], dtype=float)
prosper_log_e3_g2 = np.array(data.iloc[169:174,39], dtype=float)
prosper_log_e3_g3 = np.array(data.iloc[169:174,40], dtype=float)
prosper_log_e3_g4 = np.array(data.iloc[169:174,41], dtype=float)

prosper_log_e4_g1 = np.array(data.iloc[169:174,43], dtype=float)
prosper_log_e4_g2 = np.array(data.iloc[169:174,44], dtype=float)
prosper_log_e4_g3 = np.array(data.iloc[169:174,45], dtype=float)
prosper_log_e4_g4 = np.array(data.iloc[169:174,46], dtype=float)

prosper_log_e5_g1 = np.array(data.iloc[169:174,48], dtype=float)
prosper_log_e5_g2 = np.array(data.iloc[169:174,49], dtype=float)
prosper_log_e5_g3 = np.array(data.iloc[169:174,50], dtype=float)
prosper_log_e5_g4 = np.array(data.iloc[169:174,51], dtype=float)

# %%
# Log Model ====================================================
prscsx_log_e1_g1 = np.array(data.iloc[178:183,28], dtype=float)
prscsx_log_e1_g2 = np.array(data.iloc[178:183,29], dtype=float)
prscsx_log_e1_g3 = np.array(data.iloc[178:183,30], dtype=float)
prscsx_log_e1_g4 = np.array(data.iloc[178:183,31], dtype=float)

prscsx_log_e2_g1 = np.array(data.iloc[178:183,33], dtype=float)
prscsx_log_e2_g2 = np.array(data.iloc[178:183,34], dtype=float)
prscsx_log_e2_g3 = np.array(data.iloc[178:183,35], dtype=float)
prscsx_log_e2_g4 = np.array(data.iloc[178:183,36], dtype=float)

prscsx_log_e3_g1 = np.array(data.iloc[178:183,38], dtype=float)
prscsx_log_e3_g2 = np.array(data.iloc[178:183,39], dtype=float)
prscsx_log_e3_g3 = np.array(data.iloc[178:183,40], dtype=float)
prscsx_log_e3_g4 = np.array(data.iloc[178:183,41], dtype=float)

prscsx_log_e4_g1 = np.array(data.iloc[178:183,43], dtype=float)
prscsx_log_e4_g2 = np.array(data.iloc[178:183,44], dtype=float)
prscsx_log_e4_g3 = np.array(data.iloc[178:183,45], dtype=float)
prscsx_log_e4_g4 = np.array(data.iloc[178:183,46], dtype=float)

prscsx_log_e5_g1 = np.array(data.iloc[178:183,48], dtype=float)
prscsx_log_e5_g2 = np.array(data.iloc[178:183,49], dtype=float)
prscsx_log_e5_g3 = np.array(data.iloc[178:183,50], dtype=float)
prscsx_log_e5_g4 = np.array(data.iloc[178:183,51], dtype=float)

# %%
# Log Model ====================================================
sbrc_log_e1_g0 = np.array(data.iloc[187:192,28], dtype=float)

sbrc_log_e2_g0 = np.array(data.iloc[187:192,33], dtype=float)

sbrc_log_e3_g0 = np.array(data.iloc[187:192,38], dtype=float)

sbrc_log_e4_g0 = np.array(data.iloc[187:192,43], dtype=float)

sbrc_log_e5_g0 = np.array(data.iloc[187:192,48], dtype=float)

# %%
# Log Model ====================================================
sbrcM_log_e1_g1 = np.array(data.iloc[196:201,28], dtype=float)
sbrcM_log_e1_g2 = np.array(data.iloc[196:201,29], dtype=float)
sbrcM_log_e1_g3 = np.array(data.iloc[196:201,30], dtype=float)
sbrcM_log_e1_g4 = np.array(data.iloc[196:201,31], dtype=float)

sbrcM_log_e2_g1 = np.array(data.iloc[196:201,33], dtype=float)
sbrcM_log_e2_g2 = np.array(data.iloc[196:201,34], dtype=float)
sbrcM_log_e2_g3 = np.array(data.iloc[196:201,35], dtype=float)
sbrcM_log_e2_g4 = np.array(data.iloc[196:201,36], dtype=float)

sbrcM_log_e3_g1 = np.array(data.iloc[196:201,38], dtype=float)
sbrcM_log_e3_g2 = np.array(data.iloc[196:201,39], dtype=float)
sbrcM_log_e3_g3 = np.array(data.iloc[196:201,40], dtype=float)
sbrcM_log_e3_g4 = np.array(data.iloc[196:201,41], dtype=float)

sbrcM_log_e4_g1 = np.array(data.iloc[196:201,43], dtype=float)
sbrcM_log_e4_g2 = np.array(data.iloc[196:201,44], dtype=float)
sbrcM_log_e4_g3 = np.array(data.iloc[196:201,45], dtype=float)
sbrcM_log_e4_g4 = np.array(data.iloc[196:201,46], dtype=float)

sbrcM_log_e5_g1 = np.array(data.iloc[196:201,48], dtype=float)
sbrcM_log_e5_g2 = np.array(data.iloc[196:201,49], dtype=float)
sbrcM_log_e5_g3 = np.array(data.iloc[196:201,50], dtype=float)
sbrcM_log_e5_g4 = np.array(data.iloc[196:201,51], dtype=float)

# %%
# Log Model ====================================================
tlmulti_log_e1_g1 = np.array(data.iloc[205:210,28], dtype=float)

tlmulti_log_e2_g1 = np.array(data.iloc[205:210,33], dtype=float)

tlmulti_log_e3_g1 = np.array(data.iloc[205:210,38], dtype=float)

tlmulti_log_e4_g1 = np.array(data.iloc[205:210,43], dtype=float)

tlmulti_log_e5_g1 = np.array(data.iloc[205:210,48], dtype=float)

# %%
# Log Model ====================================================
random_log_e1_g0 = np.array(data.iloc[214:219,28], dtype=float)

random_log_e2_g0 = np.array(data.iloc[214:219,33], dtype=float)

random_log_e3_g0 = np.array(data.iloc[214:219,38], dtype=float)

random_log_e4_g0 = np.array(data.iloc[214:219,43], dtype=float)

random_log_e5_g0 = np.array(data.iloc[214:219,48], dtype=float)

# %% [markdown]
# # Make Panels:

# %%
panelA_data = {
    'Random Classifier':[np.mean(random_log_e1_g0)]+[None]*4,
    'Baseline GWAS':[np.mean(baseline_log_e1_g0)]+[None]*4,
    'Lassosum2-ExtLD':[np.mean(lassosum2_log_e1_g0)]+[None]*4,
    'Lassosum-TrueLD':[np.mean(lassosumTLD_log_e1_g0)]+[None]*4,
    'SBayesRC(O)':[np.mean(sbrc_log_e1_g0)]+[None]*4,
    'TL-Multi':[None]+[np.mean(tlmulti_log_e1_g1)]+[None]*3,
    'PRS-CSx':[None]+[np.mean(prscsx_log_e1_g1),np.mean(prscsx_log_e1_g2),\
                      np.mean(prscsx_log_e1_g3),np.mean(prscsx_log_e1_g4)],
    'PROSPER':[None]+[np.mean(prosper_log_e1_g1),np.mean(prosper_log_e1_g2),\
                      np.mean(prosper_log_e1_g3),np.mean(prosper_log_e1_g4)],
    'SBayesRC-Multi(O)':[None]+[np.mean(sbrcM_log_e1_g1),np.mean(sbrcM_log_e1_g2),\
                                np.mean(sbrcM_log_e1_g3),np.mean(sbrcM_log_e1_g4)],
    'MPP-GWAS':[None]+[np.mean(mppV1_log_e1_g1),np.mean(mppV1_log_e1_g2),\
                       np.mean(mppV1_log_e1_g3),np.mean(mppV1_log_e1_g4)],
    'MPP-PRS':[None]+[np.mean(mppV4_log_e1_g1),np.mean(mppV4_log_e1_g2),\
                       np.mean(mppV4_log_e1_g3),np.mean(mppV4_log_e1_g4)],
    'MPP-PRS+':[None]+[np.mean(mppV4B_log_e1_g1),np.mean(mppV4B_log_e1_g2),\
                       np.mean(mppV4B_log_e1_g3),np.mean(mppV4B_log_e1_g4)],
    'MPP-GWAS-Admix':[None]+[np.mean(mppV3_log_e1_g1),np.mean(mppV3_log_e1_g2),\
                       np.mean(mppV3_log_e1_g3),np.mean(mppV3_log_e1_g4)],
}

panelA_std = {
    'Random Classifier':[np.std(random_log_e1_g0)]+[None]*4,
    'Baseline GWAS':[np.std(baseline_log_e1_g0)]+[None]*4,
    'Lassosum2-ExtLD':[np.std(lassosum2_log_e1_g0)]+[None]*4,
    'Lassosum-TrueLD':[np.std(lassosumTLD_log_e1_g0)]+[None]*4,
    'SBayesRC(O)':[np.std(sbrc_log_e1_g0)]+[None]*4,
    'TL-Multi':[None]+[np.std(tlmulti_log_e1_g1)]+[None]*3,
    'PRS-CSx':[None]+[np.std(prscsx_log_e1_g1),np.std(prscsx_log_e1_g2),\
                      np.std(prscsx_log_e1_g3),np.std(prscsx_log_e1_g4)],
    'PROSPER':[None]+[np.std(prosper_log_e1_g1),np.std(prosper_log_e1_g2),\
                      np.std(prosper_log_e1_g3),np.std(prosper_log_e1_g4)],
    'SBayesRC-Multi(O)':[None]+[np.std(sbrcM_log_e1_g1),np.std(sbrcM_log_e1_g2),\
                                np.std(sbrcM_log_e1_g3),np.std(sbrcM_log_e1_g4)],
    'MPP-GWAS':[None]+[np.std(mppV1_log_e1_g1),np.std(mppV1_log_e1_g2),\
                       np.std(mppV1_log_e1_g3),np.std(mppV1_log_e1_g4)],
    'MPP-PRS':[None]+[np.std(mppV4_log_e1_g1),np.std(mppV4_log_e1_g2),\
                       np.std(mppV4_log_e1_g3),np.std(mppV4_log_e1_g4)],
    'MPP-PRS+':[None]+[np.std(mppV4B_log_e1_g1),np.std(mppV4B_log_e1_g2),\
                       np.std(mppV4B_log_e1_g3),np.std(mppV4B_log_e1_g4)],
    'MPP-GWAS-Admix':[None]+[np.std(mppV3_log_e1_g1),np.std(mppV3_log_e1_g2),\
                       np.std(mppV3_log_e1_g3),np.std(mppV3_log_e1_g4)],
}

# %%
panelB_data = {
    'Random Classifier':[np.mean(random_log_e2_g0)]+[None]*4,
    'Baseline GWAS':[np.mean(baseline_log_e2_g0)]+[None]*4,
    'Lassosum2-ExtLD':[np.mean(lassosum2_log_e2_g0)]+[None]*4,
    'Lassosum-TrueLD':[np.mean(lassosumTLD_log_e2_g0)]+[None]*4,
    'SBayesRC(O)':[np.mean(sbrc_log_e2_g0)]+[None]*4,
    'TL-Multi':[None]+[np.mean(tlmulti_log_e2_g1)]+[None]*3,
    'PRS-CSx':[None]+[np.mean(prscsx_log_e2_g1),np.mean(prscsx_log_e2_g2),\
                      np.mean(prscsx_log_e2_g3),np.mean(prscsx_log_e2_g4)],
    'PROSPER':[None]+[np.mean(prosper_log_e2_g1),np.mean(prosper_log_e2_g2),\
                      np.mean(prosper_log_e2_g3),np.mean(prosper_log_e2_g4)],
    'SBayesRC-Multi(O)':[None]+[np.mean(sbrcM_log_e2_g1),np.mean(sbrcM_log_e2_g2),\
                                np.mean(sbrcM_log_e2_g3),np.mean(sbrcM_log_e2_g4)],
    'MPP-GWAS':[None]+[np.mean(mppV1_log_e2_g1),np.mean(mppV1_log_e2_g2),\
                       np.mean(mppV1_log_e2_g3),np.mean(mppV1_log_e2_g4)],
    'MPP-PRS':[None]+[np.mean(mppV4_log_e2_g1),np.mean(mppV4_log_e2_g2),\
                       np.mean(mppV4_log_e2_g3),np.mean(mppV4_log_e2_g4)],
    'MPP-PRS+':[None]+[np.mean(mppV4B_log_e2_g1),np.mean(mppV4B_log_e2_g2),\
                       np.mean(mppV4B_log_e2_g3),np.mean(mppV4B_log_e2_g4)],
    'MPP-GWAS-Admix':[None]+[np.mean(mppV3_log_e2_g1),np.mean(mppV3_log_e2_g2),\
                       np.mean(mppV3_log_e2_g3),np.mean(mppV3_log_e2_g4)],
}

panelB_std = {
    'Random Classifier':[np.std(random_log_e2_g0)]+[None]*4,
    'Baseline GWAS':[np.std(baseline_log_e2_g0)]+[None]*4,
    'Lassosum2-ExtLD':[np.std(lassosum2_log_e2_g0)]+[None]*4,
    'Lassosum-TrueLD':[np.std(lassosumTLD_log_e2_g0)]+[None]*4,
    'SBayesRC(O)':[np.std(sbrc_log_e2_g0)]+[None]*4,
    'TL-Multi':[None]+[np.std(tlmulti_log_e2_g1)]+[None]*3,
    'PRS-CSx':[None]+[np.std(prscsx_log_e2_g1),np.std(prscsx_log_e2_g2),\
                      np.std(prscsx_log_e2_g3),np.std(prscsx_log_e2_g4)],
    'PROSPER':[None]+[np.std(prosper_log_e2_g1),np.std(prosper_log_e2_g2),\
                      np.std(prosper_log_e2_g3),np.std(prosper_log_e2_g4)],
    'SBayesRC-Multi(O)':[None]+[np.std(sbrcM_log_e2_g1),np.std(sbrcM_log_e2_g2),\
                                np.std(sbrcM_log_e2_g3),np.std(sbrcM_log_e2_g4)],
    'MPP-GWAS':[None]+[np.std(mppV1_log_e2_g1),np.std(mppV1_log_e2_g2),\
                       np.std(mppV1_log_e2_g3),np.std(mppV1_log_e2_g4)],
    'MPP-PRS':[None]+[np.std(mppV4_log_e2_g1),np.std(mppV4_log_e2_g2),\
                       np.std(mppV4_log_e2_g3),np.std(mppV4_log_e2_g4)],
    'MPP-PRS+':[None]+[np.std(mppV4B_log_e2_g1),np.std(mppV4B_log_e2_g2),\
                       np.std(mppV4B_log_e2_g3),np.std(mppV4B_log_e2_g4)],
    'MPP-GWAS-Admix':[None]+[np.std(mppV3_log_e2_g1),np.std(mppV3_log_e2_g2),\
                       np.std(mppV3_log_e2_g3),np.std(mppV3_log_e2_g4)],
}

# %%
panelC_data = {
    'Random Classifier':[np.mean(random_log_e4_g0)]+[None]*4,
    'Baseline GWAS':[np.mean(baseline_log_e4_g0)]+[None]*4,
    'Lassosum2-ExtLD':[np.mean(lassosum2_log_e4_g0)]+[None]*4,
    'Lassosum-TrueLD':[np.mean(lassosumTLD_log_e4_g0)]+[None]*4,
    'SBayesRC(O)':[np.mean(sbrc_log_e4_g0)]+[None]*4,
    'TL-Multi':[None]+[np.mean(tlmulti_log_e4_g1)]+[None]*3,
    'PRS-CSx':[None]+[np.mean(prscsx_log_e4_g1),np.mean(prscsx_log_e4_g2),\
                      np.mean(prscsx_log_e4_g3),np.mean(prscsx_log_e4_g4)],
    'PROSPER':[None]+[np.mean(prosper_log_e4_g1),np.mean(prosper_log_e4_g2),\
                      np.mean(prosper_log_e4_g3),np.mean(prosper_log_e4_g4)],
    'SBayesRC-Multi(O)':[None]+[np.mean(sbrcM_log_e4_g1),np.mean(sbrcM_log_e4_g2),\
                                np.mean(sbrcM_log_e4_g3),np.mean(sbrcM_log_e4_g4)],
    'MPP-GWAS':[None]+[np.mean(mppV1_log_e4_g1),np.mean(mppV1_log_e4_g2),\
                       np.mean(mppV1_log_e4_g3),np.mean(mppV1_log_e4_g4)],
    'MPP-PRS':[None]+[np.mean(mppV4_log_e4_g1),np.mean(mppV4_log_e4_g2),\
                       np.mean(mppV4_log_e4_g3),np.mean(mppV4_log_e4_g4)],
    'MPP-PRS+':[None]+[np.mean(mppV4B_log_e4_g1),np.mean(mppV4B_log_e4_g2),\
                       np.mean(mppV4B_log_e4_g3),np.mean(mppV4B_log_e4_g4)],
    'MPP-GWAS-Admix':[None]+[np.mean(mppV3_log_e4_g1),np.mean(mppV3_log_e4_g2),\
                       np.mean(mppV3_log_e4_g3),np.mean(mppV3_log_e4_g4)],
}

panelC_std = {
    'Random Classifier':[np.std(random_log_e4_g0)]+[None]*4,
    'Baseline GWAS':[np.std(baseline_log_e4_g0)]+[None]*4,
    'Lassosum2-ExtLD':[np.std(lassosum2_log_e4_g0)]+[None]*4,
    'Lassosum-TrueLD':[np.std(lassosumTLD_log_e4_g0)]+[None]*4,
    'SBayesRC(O)':[np.std(sbrc_log_e4_g0)]+[None]*4,
    'TL-Multi':[None]+[np.std(tlmulti_log_e4_g1)]+[None]*3,
    'PRS-CSx':[None]+[np.std(prscsx_log_e4_g1),np.std(prscsx_log_e4_g2),\
                      np.std(prscsx_log_e4_g3),np.std(prscsx_log_e4_g4)],
    'PROSPER':[None]+[np.std(prosper_log_e4_g1),np.std(prosper_log_e4_g2),\
                      np.std(prosper_log_e4_g3),np.std(prosper_log_e4_g4)],
    'SBayesRC-Multi(O)':[None]+[np.std(sbrcM_log_e4_g1),np.std(sbrcM_log_e4_g2),\
                                np.std(sbrcM_log_e4_g3),np.std(sbrcM_log_e4_g4)],
    'MPP-GWAS':[None]+[np.std(mppV1_log_e4_g1),np.std(mppV1_log_e4_g2),\
                       np.std(mppV1_log_e4_g3),np.std(mppV1_log_e4_g4)],
    'MPP-PRS':[None]+[np.std(mppV4_log_e4_g1),np.std(mppV4_log_e4_g2),\
                       np.std(mppV4_log_e4_g3),np.std(mppV4_log_e4_g4)],
    'MPP-PRS+':[None]+[np.std(mppV4B_log_e4_g1),np.std(mppV4B_log_e4_g2),\
                       np.std(mppV4B_log_e4_g3),np.std(mppV4B_log_e4_g4)],
    'MPP-GWAS-Admix':[None]+[np.std(mppV3_log_e4_g1),np.std(mppV3_log_e4_g2),\
                       np.std(mppV3_log_e4_g3),np.std(mppV3_log_e4_g4)],
}

# %%
panelD_data = {
    'Random Classifier':[np.mean(random_log_e3_g0)]+[None]*4,
    'Baseline GWAS':[np.mean(baseline_log_e3_g0)]+[None]*4,
    'Lassosum2-ExtLD':[np.mean(lassosum2_log_e3_g0)]+[None]*4,
    'Lassosum-TrueLD':[np.mean(lassosumTLD_log_e3_g0)]+[None]*4,
    'SBayesRC(O)':[np.mean(sbrc_log_e3_g0)]+[None]*4,
    'TL-Multi':[None]+[np.mean(tlmulti_log_e3_g1)]+[None]*3,
    'PRS-CSx':[None]+[np.mean(prscsx_log_e3_g1),np.mean(prscsx_log_e3_g2),\
                      np.mean(prscsx_log_e3_g3),np.mean(prscsx_log_e3_g4)],
    'PROSPER':[None]+[np.mean(prosper_log_e3_g1),np.mean(prosper_log_e3_g2),\
                      np.mean(prosper_log_e3_g3),np.mean(prosper_log_e3_g4)],
    'SBayesRC-Multi(O)':[None]+[np.mean(sbrcM_log_e3_g1),np.mean(sbrcM_log_e3_g2),\
                                np.mean(sbrcM_log_e3_g3),np.mean(sbrcM_log_e3_g4)],
    'MPP-GWAS':[None]+[np.mean(mppV1_log_e3_g1),np.mean(mppV1_log_e3_g2),\
                       np.mean(mppV1_log_e3_g3),np.mean(mppV1_log_e3_g4)],
    'MPP-PRS':[None]+[np.mean(mppV4_log_e3_g1),np.mean(mppV4_log_e3_g2),\
                       np.mean(mppV4_log_e3_g3),np.mean(mppV4_log_e3_g4)],
    'MPP-PRS+':[None]+[np.mean(mppV4B_log_e3_g1),np.mean(mppV4B_log_e3_g2),\
                       np.mean(mppV4B_log_e3_g3),np.mean(mppV4B_log_e3_g4)],
    'MPP-GWAS-Admix':[None]+[np.mean(mppV3_log_e3_g1),np.mean(mppV3_log_e3_g2),\
                       np.mean(mppV3_log_e3_g3),np.mean(mppV3_log_e3_g4)],
}

panelD_std = {
    'Random Classifier':[np.std(random_log_e3_g0)]+[None]*4,
    'Baseline GWAS':[np.std(baseline_log_e3_g0)]+[None]*4,
    'Lassosum2-ExtLD':[np.std(lassosum2_log_e3_g0)]+[None]*4,
    'Lassosum-TrueLD':[np.std(lassosumTLD_log_e3_g0)]+[None]*4,
    'SBayesRC(O)':[np.std(sbrc_log_e3_g0)]+[None]*4,
    'TL-Multi':[None]+[np.std(tlmulti_log_e3_g1)]+[None]*3,
    'PRS-CSx':[None]+[np.std(prscsx_log_e3_g1),np.std(prscsx_log_e3_g2),\
                      np.std(prscsx_log_e3_g3),np.std(prscsx_log_e3_g4)],
    'PROSPER':[None]+[np.std(prosper_log_e3_g1),np.std(prosper_log_e3_g2),\
                      np.std(prosper_log_e3_g3),np.std(prosper_log_e3_g4)],
    'SBayesRC-Multi(O)':[None]+[np.std(sbrcM_log_e3_g1),np.std(sbrcM_log_e3_g2),\
                                np.std(sbrcM_log_e3_g3),np.std(sbrcM_log_e3_g4)],
    'MPP-GWAS':[None]+[np.std(mppV1_log_e3_g1),np.std(mppV1_log_e3_g2),\
                       np.std(mppV1_log_e3_g3),np.std(mppV1_log_e3_g4)],
    'MPP-PRS':[None]+[np.std(mppV4_log_e3_g1),np.std(mppV4_log_e3_g2),\
                       np.std(mppV4_log_e3_g3),np.std(mppV4_log_e3_g4)],
    'MPP-PRS+':[None]+[np.std(mppV4B_log_e3_g1),np.std(mppV4B_log_e3_g2),\
                       np.std(mppV4B_log_e3_g3),np.std(mppV4B_log_e3_g4)],
    'MPP-GWAS-Admix':[None]+[np.std(mppV3_log_e3_g1),np.std(mppV3_log_e3_g2),\
                       np.std(mppV3_log_e3_g3),np.std(mppV3_log_e3_g4)],
}

# %%
#Original bar_plot function credit: Camilo Martínez M. 
#https://stackoverflow.com/questions/14270391/how-to-plot-multiple-bars-grouped
#Modified by Ritwiz Kamal

colors_toplot = ['#FDFD96','#FFB347','#D891EF','#D1B3E6','#F4C2C2',\
                 '#9D81BA',\
                 '#77DD77','#A9A9A9','#FFD1DC','#6EA8FF','#8AC4FF','#73C6B6','#7EC8E3']

patterns = [None,None,None,None,None,
            None,None,None,None,None,
            '/','/','/','/','/',\
            '-','-','-','-','-',\
            None,None,None,None,None,
            None,None,None,None,None,
            None,None,None,None,None,
            '/','/','/','/','/',\
            None,None,None,None,None,
            '\\','\\','\\','\\','\\',\
            '/','/','/','/','/',\
            '-','-','-','-','-',\
            '+','+','+','+','+']

pattern_indices = [(0,0),(0,1),(0,2),(0,3),(0,4),\
                   (1,0),(1,1),(1,2),(1,3),(1,4),\
                   (2,0),(2,1),(2,2),(2,3),(2,4),\
                   (3,0),(3,1),(3,2),(3,3),(3,4),\
                   (4,0),(4,1),(4,2),(4,3),(4,4),\
                   (5,0),(5,1),(5,2),(5,3),(5,4),\
                   (6,0),(6,1),(6,2),(6,3),(6,4),\
                   (7,0),(7,1),(7,2),(7,3),(7,4),\
                   (8,0),(8,1),(8,2),(8,3),(8,4),\
                   (9,0),(9,1),(9,2),(9,3),(9,4),\
                   (10,0),(10,1),(10,2),(10,3),(10,4),\
                   (11,0),(11,1),(11,2),(11,3),(11,4),\
                   (12,0),(12,1),(12,2),(12,3),(12,4)]

def bar_plot(ax, data, std_devs=None, colors=None, patterns=None, pattern_indices=None,\
             total_width=0.8, single_width=1, legend=True):
    
    # Check if colors where provided, otherwhise use the default color cycle
    if colors is None:
        colors = plt.rcParams["axes.prop_cycle"].by_key()["color"]

    # Number of bars per group
    n_bars = len(data)

    # The width of a single bar
    bar_width = (total_width / n_bars)*1.4

    # List containing handles for the drawn bars, used for the legend
    bars = []

    # Build a bars_per_x dictionary depending on the number of values that are not None
    bars_per_x = {}
    for _, values_list in data.items():
        for i, value in enumerate(values_list):
            if value is not None:
                if i not in bars_per_x:
                    bars_per_x[i] = 0
                bars_per_x[i] += 1

    # Instead of using i in calculating the offset, we now use the i_per_x[x]
    i_per_x = {}

    # Iterate over all data
    for i, (name, values) in enumerate(data.items()):
        # Draw a bar for every value of that type
        for x, y in enumerate(values):
            if x not in i_per_x:
                i_per_x[x] = 0

            if y is not None:
                    
                # The offset in x direction of that bar
                x_offset = (i_per_x[x] - bars_per_x[x] / 2) * bar_width + bar_width / 2
                
                # Get standard deviation for the current bar if provided
                yerr = None
                if std_devs is not None and name in std_devs and std_devs[name][x] is not None:
                    yerr = std_devs[name][x]
                    
                # Define the error_kw dictionary to customize error bar appearance
                error_kw = {
                    'ecolor': 'red',
                    'capsize': 3.5,                       # Size of the error bar caps
                    'elinewidth': 1.5,                  # Error bar line width
                    'capthick': 1.5                     # Error bar cap thickness
                }
                
                hatch = None
                if patterns and pattern_indices and (i, x) in pattern_indices:
                    hatch = patterns[pattern_indices.index((i, x)) % len(patterns)]
                    
                # Draw the bar with error bars
                bar = ax.bar(
                    x + x_offset, 
                    y, 
                    width=bar_width * single_width, 
                    color=colors[i % len(colors)],
                    yerr=yerr,  # Add error bars
                    error_kw=error_kw,    # Set error bar appearance
                    hatch = hatch
                )
                

                i_per_x[x] += 1

        # Add a handle to the last drawn bar, which we'll need for the legend
        bars.append(bar[0])

    # Draw legend if we need
    if legend:
        fig.legend(bars, data.keys(), loc='lower center', ncol=5, bbox_to_anchor=(0.5, -0.16), fontsize=35)

# %%
fig, ax = plt.subplots(2 , 2, figsize=(35, 20), dpi = 300)
fig.tight_layout()
fig.subplots_adjust(left=None, bottom=0.05, right=None, top=None, wspace=0.07, hspace=0.25)

fig.suptitle('Performance Comparison on Simulated Data | Binary Phenotype', fontsize=40,\
             bbox=dict(facecolor='#f0f0f0',edgecolor='black',boxstyle='round'), y=1.11)

bar_plot(ax[0][0], data=panelA_data, std_devs=panelA_std,\
         colors=colors_toplot, patterns=patterns, pattern_indices=pattern_indices,\
         total_width=0.9, single_width=0.8, legend=True)
ax[0][0].set_title('#AUX:10k | #TAR:100 | $h^2=0.7$', fontsize=40,\
                   bbox=dict(facecolor='#f0f0f0',edgecolor='black',boxstyle='round'), y=1.05)
ax[0][0].text(-0.2, 0.67, 'a)', fontsize=50, fontweight='bold', va='top', ha='right')
ax[0][0].grid(True, which='both', axis='y', linestyle='--', linewidth=0.7, color='gray', alpha=0.7)
ax[0][0].set_facecolor('#f0f0f0')
ax[0][0].set_ylim(0,0.6)
ax[0][0].tick_params(axis='x',bottom=False, labelbottom=False)
ax[0][0].tick_params(axis='y',labelsize=30)
ax[0][0].set_ylabel('PR-AUC', fontsize=40)

bar_plot(ax[0][1], data=panelB_data, std_devs=panelB_std,\
         colors=colors_toplot, patterns=patterns, pattern_indices=pattern_indices,\
         total_width=0.9, single_width=0.8, legend=False)
ax[0][1].set_title('#AUX:10k | #TAR:1000 | $h^2=0.7$', fontsize=40,\
                   bbox=dict(facecolor='#f0f0f0',edgecolor='black',boxstyle='round'), y=1.05)
ax[0][1].text(-0.2, 0.67, 'b)', fontsize=50, fontweight='bold', va='top', ha='right')
ax[0][1].grid(True, which='both', axis='y', linestyle='--', linewidth=0.7, color='gray', alpha=0.7)
ax[0][1].set_facecolor('#f0f0f0')
ax[0][1].set_ylim(0,0.6)
xtick_labels = ['0 AUX','1 AUX\nEUR', '2 AUX\nEUR,EAS', '3 AUX\nEUR,EAS,\nAMR', '4 AUX\nEUR,EAS,\nAMR,AFR']
ax[0][1].set_xticks(range(len(xtick_labels)))
ax[0][1].set_xticklabels(xtick_labels, fontsize=30)
ax[0][1].tick_params(axis='x',bottom=False, labelbottom=False)
ax[0][1].tick_params(axis='y',labelsize=30)

bar_plot(ax[1][0], data=panelC_data, std_devs=panelC_std,\
         colors=colors_toplot, patterns=patterns, pattern_indices=pattern_indices,\
         total_width=0.9, single_width=0.8, legend=False)
ax[1][0].set_title('#AUX:500 | #TAR:1000 | $h^2=0.7$', fontsize=40,\
                   bbox=dict(facecolor='#f0f0f0',edgecolor='black',boxstyle='round'), y=1.05)
ax[1][0].text(-0.2, 0.67, 'c)', fontsize=50, fontweight='bold', va='top', ha='right')
ax[1][0].grid(True, which='both', axis='y', linestyle='--', linewidth=0.7, color='gray', alpha=0.7)
ax[1][0].set_facecolor('#f0f0f0')
ax[1][0].set_ylim(0,0.6)
xtick_labels = ['0 AUX','1 AUX\nEUR', '2 AUX\nEUR,EAS', '3 AUX\nEUR,EAS,\nAMR', '4 AUX\nEUR,EAS,\nAMR,AFR']
ax[1][0].set_xticks(range(len(xtick_labels)))
ax[1][0].set_xticklabels(xtick_labels, fontsize=30)
ax[1][0].tick_params(axis='y',labelsize=30)
ax[1][0].set_ylabel('PR-AUC', fontsize=40)

bar_plot(ax[1][1], data=panelD_data, std_devs=panelD_std,\
         colors=colors_toplot, patterns=patterns, pattern_indices=pattern_indices,\
         total_width=0.9, single_width=0.8, legend=False)
ax[1][1].set_title('#AUX:10k | #TAR:1000 | $h^2=0.3$', fontsize=40,\
                   bbox=dict(facecolor='#f0f0f0',edgecolor='black',boxstyle='round'), y=1.05)
ax[1][1].text(-0.2, 0.67, 'd)', fontsize=50, fontweight='bold', va='top', ha='right')
ax[1][1].grid(True, which='both', axis='y', linestyle='--', linewidth=0.7, color='gray', alpha=0.7)
ax[1][1].set_facecolor('#f0f0f0')
ax[1][1].set_ylim(0,0.6)
xtick_labels = ['0 AUX','1 AUX\nEUR', '2 AUX\nEUR,EAS', '3 AUX\nEUR,EAS,\nAMR', '4 AUX\nEUR,EAS,\nAMR,AFR']
ax[1][1].set_xticks(range(len(xtick_labels)))
ax[1][1].set_xticklabels(xtick_labels, fontsize=30)
ax[1][1].tick_params(axis='y',labelsize=30)
    
plt.show()

# fig.savefig("Figures/Plots/Figure_4.pdf",\
#             format='pdf', bbox_inches='tight')

# %% [markdown]
# # % IMP:

# %%
imp_mppV4B_sbrcM_e1_g1 = (mppV4B_log_e1_g1 - sbrcM_log_e1_g1)/sbrcM_log_e1_g1
imp_mppV4B_sbrcM_e1_g2 = (mppV4B_log_e1_g2 - sbrcM_log_e1_g2)/sbrcM_log_e1_g2
imp_mppV4B_sbrcM_e1_g3 = (mppV4B_log_e1_g3 - sbrcM_log_e1_g3)/sbrcM_log_e1_g3
imp_mppV4B_sbrcM_e1_g4 = (mppV4B_log_e1_g4 - sbrcM_log_e1_g4)/sbrcM_log_e1_g4

imp_mppV4B_sbrc_e1_g1 = (mppV4B_log_e1_g1 - sbrc_log_e1_g0)/sbrc_log_e1_g0
imp_mppV4B_sbrc_e1_g2 = (mppV4B_log_e1_g2 - sbrc_log_e1_g0)/sbrc_log_e1_g0
imp_mppV4B_sbrc_e1_g3 = (mppV4B_log_e1_g3 - sbrc_log_e1_g0)/sbrc_log_e1_g0
imp_mppV4B_sbrc_e1_g4 = (mppV4B_log_e1_g4 - sbrc_log_e1_g0)/sbrc_log_e1_g0

imp_mppV4B_prosper_e1_g1 = (mppV4B_log_e1_g1 - prosper_log_e1_g1)/prosper_log_e1_g1
imp_mppV4B_prosper_e1_g2 = (mppV4B_log_e1_g2 - prosper_log_e1_g2)/prosper_log_e1_g2
imp_mppV4B_prosper_e1_g3 = (mppV4B_log_e1_g3 - prosper_log_e1_g3)/prosper_log_e1_g3
imp_mppV4B_prosper_e1_g4 = (mppV4B_log_e1_g4 - prosper_log_e1_g4)/prosper_log_e1_g4

imp_mppV4B_prscsx_e1_g1 = (mppV4B_log_e1_g1 - prscsx_log_e1_g1)/prscsx_log_e1_g1
imp_mppV4B_prscsx_e1_g2 = (mppV4B_log_e1_g2 - prscsx_log_e1_g2)/prscsx_log_e1_g2
imp_mppV4B_prscsx_e1_g3 = (mppV4B_log_e1_g3 - prscsx_log_e1_g3)/prscsx_log_e1_g3
imp_mppV4B_prscsx_e1_g4 = (mppV4B_log_e1_g4 - prscsx_log_e1_g4)/prscsx_log_e1_g4

imp_mppV4B_lassosum2_e1_g1 = (mppV4B_log_e1_g1 - lassosum2_log_e1_g0)/lassosum2_log_e1_g0
imp_mppV4B_lassosum2_e1_g2 = (mppV4B_log_e1_g2 - lassosum2_log_e1_g0)/lassosum2_log_e1_g0
imp_mppV4B_lassosum2_e1_g3 = (mppV4B_log_e1_g3 - lassosum2_log_e1_g0)/lassosum2_log_e1_g0
imp_mppV4B_lassosum2_e1_g4 = (mppV4B_log_e1_g4 - lassosum2_log_e1_g0)/lassosum2_log_e1_g0

imp_mppV4B_lassosumTLD_e1_g1 = (mppV4B_log_e1_g1 - lassosumTLD_log_e1_g0)/lassosumTLD_log_e1_g0
imp_mppV4B_lassosumTLD_e1_g2 = (mppV4B_log_e1_g2 - lassosumTLD_log_e1_g0)/lassosumTLD_log_e1_g0
imp_mppV4B_lassosumTLD_e1_g3 = (mppV4B_log_e1_g3 - lassosumTLD_log_e1_g0)/lassosumTLD_log_e1_g0
imp_mppV4B_lassosumTLD_e1_g4 = (mppV4B_log_e1_g4 - lassosumTLD_log_e1_g0)/lassosumTLD_log_e1_g0

imp_mppV4B_tlmulti_e1_g1 = (mppV4B_log_e1_g1 - tlmulti_log_e1_g1)/tlmulti_log_e1_g1
imp_mppV4B_tlmulti_e1_g2 = (mppV4B_log_e1_g2 - tlmulti_log_e1_g1)/tlmulti_log_e1_g1
imp_mppV4B_tlmulti_e1_g3 = (mppV4B_log_e1_g3 - tlmulti_log_e1_g1)/tlmulti_log_e1_g1
imp_mppV4B_tlmulti_e1_g4 = (mppV4B_log_e1_g4 - tlmulti_log_e1_g1)/tlmulti_log_e1_g1

imp_mppV4B_baseline_e1_g1 = (mppV4B_log_e1_g1 - baseline_log_e1_g0)/baseline_log_e1_g0
imp_mppV4B_baseline_e1_g2 = (mppV4B_log_e1_g2 - baseline_log_e1_g0)/baseline_log_e1_g0
imp_mppV4B_baseline_e1_g3 = (mppV4B_log_e1_g3 - baseline_log_e1_g0)/baseline_log_e1_g0
imp_mppV4B_baseline_e1_g4 = (mppV4B_log_e1_g4 - baseline_log_e1_g0)/baseline_log_e1_g0

print("MPP-PRS+ vs. SBayesRC-Multi: "+str(np.mean(np.concatenate((imp_mppV4B_sbrcM_e1_g1,imp_mppV4B_sbrcM_e1_g2,\
                                                                 imp_mppV4B_sbrcM_e1_g3,imp_mppV4B_sbrcM_e1_g4)))))
print("MPP-PRS+ vs. SBayesRC: "+str(np.mean(np.concatenate((imp_mppV4B_sbrc_e1_g1,imp_mppV4B_sbrc_e1_g2,\
                                                            imp_mppV4B_sbrc_e1_g3,imp_mppV4B_sbrc_e1_g4)))))
print("MPP-PRS+ vs. PROSPER: "+str(np.mean(np.concatenate((imp_mppV4B_prosper_e1_g1,imp_mppV4B_prosper_e1_g2,\
                                                           imp_mppV4B_prosper_e1_g3,imp_mppV4B_prosper_e1_g4)))))
print("MPP-PRS+ vs. PRS-CSx: "+str(np.mean(np.concatenate((imp_mppV4B_prscsx_e1_g1,imp_mppV4B_prscsx_e1_g2,\
                                                           imp_mppV4B_prscsx_e1_g3,imp_mppV4B_prscsx_e1_g4)))))
print("MPP-PRS+ vs. TL-Multi: "+str(np.mean(np.concatenate((imp_mppV4B_tlmulti_e1_g1,imp_mppV4B_tlmulti_e1_g2,\
                                                           imp_mppV4B_tlmulti_e1_g3,imp_mppV4B_tlmulti_e1_g4)))))
print("MPP-PRS+ vs. Lassosum2: "+str(np.mean(np.concatenate((imp_mppV4B_lassosum2_e1_g1,imp_mppV4B_lassosum2_e1_g2,\
                                                           imp_mppV4B_lassosum2_e1_g3,imp_mppV4B_lassosum2_e1_g4)))))
print("MPP-PRS+ vs. LassosumTLD: "+str(np.mean(np.concatenate((imp_mppV4B_lassosumTLD_e1_g1,imp_mppV4B_lassosumTLD_e1_g2,\
                                                           imp_mppV4B_lassosumTLD_e1_g3,imp_mppV4B_lassosumTLD_e1_g4)))))
print("MPP-PRS+ vs. Baseline: "+str(np.mean(np.concatenate((imp_mppV4B_baseline_e1_g1,imp_mppV4B_baseline_e1_g2,\
                                                           imp_mppV4B_baseline_e1_g3,imp_mppV4B_baseline_e1_g4)))))
# Out:
# MPP-PRS+ vs. SBayesRC-Multi: 0.3102014137176282
# MPP-PRS+ vs. SBayesRC: 0.8813447444639625
# MPP-PRS+ vs. PROSPER: 0.5204378316224251
# MPP-PRS+ vs. PRS-CSx: 0.7169811002579694
# MPP-PRS+ vs. TL-Multi: 0.7755772285927496
# MPP-PRS+ vs. Lassosum2: 0.7289254276504875
# MPP-PRS+ vs. LassosumTLD: 0.26628470972269025
# MPP-PRS+ vs. Baseline: 0.5385565597797917

# %%
imp_mppV4_sbrcM_e1_g1 = (mppV4_log_e1_g1 - sbrcM_log_e1_g1)/sbrcM_log_e1_g1
imp_mppV4_sbrcM_e1_g2 = (mppV4_log_e1_g2 - sbrcM_log_e1_g2)/sbrcM_log_e1_g2
imp_mppV4_sbrcM_e1_g3 = (mppV4_log_e1_g3 - sbrcM_log_e1_g3)/sbrcM_log_e1_g3
imp_mppV4_sbrcM_e1_g4 = (mppV4_log_e1_g4 - sbrcM_log_e1_g4)/sbrcM_log_e1_g4

imp_mppV4_sbrc_e1_g1 = (mppV4_log_e1_g1 - sbrc_log_e1_g0)/sbrc_log_e1_g0
imp_mppV4_sbrc_e1_g2 = (mppV4_log_e1_g2 - sbrc_log_e1_g0)/sbrc_log_e1_g0
imp_mppV4_sbrc_e1_g3 = (mppV4_log_e1_g3 - sbrc_log_e1_g0)/sbrc_log_e1_g0
imp_mppV4_sbrc_e1_g4 = (mppV4_log_e1_g4 - sbrc_log_e1_g0)/sbrc_log_e1_g0

imp_mppV4_prosper_e1_g1 = (mppV4_log_e1_g1 - prosper_log_e1_g1)/prosper_log_e1_g1
imp_mppV4_prosper_e1_g2 = (mppV4_log_e1_g2 - prosper_log_e1_g2)/prosper_log_e1_g2
imp_mppV4_prosper_e1_g3 = (mppV4_log_e1_g3 - prosper_log_e1_g3)/prosper_log_e1_g3
imp_mppV4_prosper_e1_g4 = (mppV4_log_e1_g4 - prosper_log_e1_g4)/prosper_log_e1_g4

imp_mppV4_prscsx_e1_g1 = (mppV4_log_e1_g1 - prscsx_log_e1_g1)/prscsx_log_e1_g1
imp_mppV4_prscsx_e1_g2 = (mppV4_log_e1_g2 - prscsx_log_e1_g2)/prscsx_log_e1_g2
imp_mppV4_prscsx_e1_g3 = (mppV4_log_e1_g3 - prscsx_log_e1_g3)/prscsx_log_e1_g3
imp_mppV4_prscsx_e1_g4 = (mppV4_log_e1_g4 - prscsx_log_e1_g4)/prscsx_log_e1_g4

imp_mppV4_lassosum2_e1_g1 = (mppV4_log_e1_g1 - lassosum2_log_e1_g0)/lassosum2_log_e1_g0
imp_mppV4_lassosum2_e1_g2 = (mppV4_log_e1_g2 - lassosum2_log_e1_g0)/lassosum2_log_e1_g0
imp_mppV4_lassosum2_e1_g3 = (mppV4_log_e1_g3 - lassosum2_log_e1_g0)/lassosum2_log_e1_g0
imp_mppV4_lassosum2_e1_g4 = (mppV4_log_e1_g4 - lassosum2_log_e1_g0)/lassosum2_log_e1_g0

imp_mppV4_lassosumTLD_e1_g1 = (mppV4_log_e1_g1 - lassosumTLD_log_e1_g0)/lassosumTLD_log_e1_g0
imp_mppV4_lassosumTLD_e1_g2 = (mppV4_log_e1_g2 - lassosumTLD_log_e1_g0)/lassosumTLD_log_e1_g0
imp_mppV4_lassosumTLD_e1_g3 = (mppV4_log_e1_g3 - lassosumTLD_log_e1_g0)/lassosumTLD_log_e1_g0
imp_mppV4_lassosumTLD_e1_g4 = (mppV4_log_e1_g4 - lassosumTLD_log_e1_g0)/lassosumTLD_log_e1_g0

imp_mppV4_tlmulti_e1_g1 = (mppV4_log_e1_g1 - tlmulti_log_e1_g1)/tlmulti_log_e1_g1
imp_mppV4_tlmulti_e1_g2 = (mppV4_log_e1_g2 - tlmulti_log_e1_g1)/tlmulti_log_e1_g1
imp_mppV4_tlmulti_e1_g3 = (mppV4_log_e1_g3 - tlmulti_log_e1_g1)/tlmulti_log_e1_g1
imp_mppV4_tlmulti_e1_g4 = (mppV4_log_e1_g4 - tlmulti_log_e1_g1)/tlmulti_log_e1_g1

imp_mppV4_baseline_e1_g1 = (mppV4_log_e1_g1 - baseline_log_e1_g0)/baseline_log_e1_g0
imp_mppV4_baseline_e1_g2 = (mppV4_log_e1_g2 - baseline_log_e1_g0)/baseline_log_e1_g0
imp_mppV4_baseline_e1_g3 = (mppV4_log_e1_g3 - baseline_log_e1_g0)/baseline_log_e1_g0
imp_mppV4_baseline_e1_g4 = (mppV4_log_e1_g4 - baseline_log_e1_g0)/baseline_log_e1_g0

print("MPP-PRS vs. SBayesRC-Multi: "+str(np.mean(np.concatenate((imp_mppV4_sbrcM_e1_g1,imp_mppV4_sbrcM_e1_g2,\
                                                                 imp_mppV4_sbrcM_e1_g3,imp_mppV4_sbrcM_e1_g4)))))
print("MPP-PRS vs. SBayesRC: "+str(np.mean(np.concatenate((imp_mppV4_sbrc_e1_g1,imp_mppV4_sbrc_e1_g2,\
                                                            imp_mppV4_sbrc_e1_g3,imp_mppV4_sbrc_e1_g4)))))
print("MPP-PRS vs. PROSPER: "+str(np.mean(np.concatenate((imp_mppV4_prosper_e1_g1,imp_mppV4_prosper_e1_g2,\
                                                           imp_mppV4_prosper_e1_g3,imp_mppV4_prosper_e1_g4)))))
print("MPP-PRS vs. PRS-CSx: "+str(np.mean(np.concatenate((imp_mppV4_prscsx_e1_g1,imp_mppV4_prscsx_e1_g2,\
                                                           imp_mppV4_prscsx_e1_g3,imp_mppV4_prscsx_e1_g4)))))
print("MPP-PRS vs. TL-Multi: "+str(np.mean(np.concatenate((imp_mppV4_tlmulti_e1_g1,imp_mppV4_tlmulti_e1_g2,\
                                                           imp_mppV4_tlmulti_e1_g3,imp_mppV4_tlmulti_e1_g4)))))
print("MPP-PRS vs. Lassosum2: "+str(np.mean(np.concatenate((imp_mppV4_lassosum2_e1_g1,imp_mppV4_lassosum2_e1_g2,\
                                                           imp_mppV4_lassosum2_e1_g3,imp_mppV4_lassosum2_e1_g4)))))
print("MPP-PRS vs. LassosumTLD: "+str(np.mean(np.concatenate((imp_mppV4_lassosumTLD_e1_g1,imp_mppV4_lassosumTLD_e1_g2,\
                                                           imp_mppV4_lassosumTLD_e1_g3,imp_mppV4_lassosumTLD_e1_g4)))))
print("MPP-PRS vs. Baseline: "+str(np.mean(np.concatenate((imp_mppV4_baseline_e1_g1,imp_mppV4_baseline_e1_g2,\
                                                           imp_mppV4_baseline_e1_g3,imp_mppV4_baseline_e1_g4)))))
# Out:
# MPP-PRS vs. SBayesRC-Multi: -0.1500110488579411
# MPP-PRS vs. SBayesRC: 0.17054201592040416
# MPP-PRS vs. PROSPER: -0.034503420762931114
# MPP-PRS vs. PRS-CSx: 0.08065551717295474
# MPP-PRS vs. TL-Multi: 0.11729588000154326
# MPP-PRS vs. Lassosum2: 0.09174572851737986
# MPP-PRS vs. LassosumTLD: -0.18272912194696683
# MPP-PRS vs. Baseline: -0.020527168949501517

# %%
imp_mppV1_sbrcM_e1_g1 = (mppV1_log_e1_g1 - sbrcM_log_e1_g1)/sbrcM_log_e1_g1
imp_mppV1_sbrcM_e1_g2 = (mppV1_log_e1_g2 - sbrcM_log_e1_g2)/sbrcM_log_e1_g2
imp_mppV1_sbrcM_e1_g3 = (mppV1_log_e1_g3 - sbrcM_log_e1_g3)/sbrcM_log_e1_g3
imp_mppV1_sbrcM_e1_g4 = (mppV1_log_e1_g4 - sbrcM_log_e1_g4)/sbrcM_log_e1_g4

imp_mppV1_sbrc_e1_g1 = (mppV1_log_e1_g1 - sbrc_log_e1_g0)/sbrc_log_e1_g0
imp_mppV1_sbrc_e1_g2 = (mppV1_log_e1_g2 - sbrc_log_e1_g0)/sbrc_log_e1_g0
imp_mppV1_sbrc_e1_g3 = (mppV1_log_e1_g3 - sbrc_log_e1_g0)/sbrc_log_e1_g0
imp_mppV1_sbrc_e1_g4 = (mppV1_log_e1_g4 - sbrc_log_e1_g0)/sbrc_log_e1_g0

imp_mppV1_prosper_e1_g1 = (mppV1_log_e1_g1 - prosper_log_e1_g1)/prosper_log_e1_g1
imp_mppV1_prosper_e1_g2 = (mppV1_log_e1_g2 - prosper_log_e1_g2)/prosper_log_e1_g2
imp_mppV1_prosper_e1_g3 = (mppV1_log_e1_g3 - prosper_log_e1_g3)/prosper_log_e1_g3
imp_mppV1_prosper_e1_g4 = (mppV1_log_e1_g4 - prosper_log_e1_g4)/prosper_log_e1_g4

imp_mppV1_prscsx_e1_g1 = (mppV1_log_e1_g1 - prscsx_log_e1_g1)/prscsx_log_e1_g1
imp_mppV1_prscsx_e1_g2 = (mppV1_log_e1_g2 - prscsx_log_e1_g2)/prscsx_log_e1_g2
imp_mppV1_prscsx_e1_g3 = (mppV1_log_e1_g3 - prscsx_log_e1_g3)/prscsx_log_e1_g3
imp_mppV1_prscsx_e1_g4 = (mppV1_log_e1_g4 - prscsx_log_e1_g4)/prscsx_log_e1_g4

imp_mppV1_lassosum2_e1_g1 = (mppV1_log_e1_g1 - lassosum2_log_e1_g0)/lassosum2_log_e1_g0
imp_mppV1_lassosum2_e1_g2 = (mppV1_log_e1_g2 - lassosum2_log_e1_g0)/lassosum2_log_e1_g0
imp_mppV1_lassosum2_e1_g3 = (mppV1_log_e1_g3 - lassosum2_log_e1_g0)/lassosum2_log_e1_g0
imp_mppV1_lassosum2_e1_g4 = (mppV1_log_e1_g4 - lassosum2_log_e1_g0)/lassosum2_log_e1_g0

imp_mppV1_lassosumTLD_e1_g1 = (mppV1_log_e1_g1 - lassosumTLD_log_e1_g0)/lassosumTLD_log_e1_g0
imp_mppV1_lassosumTLD_e1_g2 = (mppV1_log_e1_g2 - lassosumTLD_log_e1_g0)/lassosumTLD_log_e1_g0
imp_mppV1_lassosumTLD_e1_g3 = (mppV1_log_e1_g3 - lassosumTLD_log_e1_g0)/lassosumTLD_log_e1_g0
imp_mppV1_lassosumTLD_e1_g4 = (mppV1_log_e1_g4 - lassosumTLD_log_e1_g0)/lassosumTLD_log_e1_g0

imp_mppV1_tlmulti_e1_g1 = (mppV1_log_e1_g1 - tlmulti_log_e1_g1)/tlmulti_log_e1_g1
imp_mppV1_tlmulti_e1_g2 = (mppV1_log_e1_g2 - tlmulti_log_e1_g1)/tlmulti_log_e1_g1
imp_mppV1_tlmulti_e1_g3 = (mppV1_log_e1_g3 - tlmulti_log_e1_g1)/tlmulti_log_e1_g1
imp_mppV1_tlmulti_e1_g4 = (mppV1_log_e1_g4 - tlmulti_log_e1_g1)/tlmulti_log_e1_g1

imp_mppV1_baseline_e1_g1 = (mppV1_log_e1_g1 - baseline_log_e1_g0)/baseline_log_e1_g0
imp_mppV1_baseline_e1_g2 = (mppV1_log_e1_g2 - baseline_log_e1_g0)/baseline_log_e1_g0
imp_mppV1_baseline_e1_g3 = (mppV1_log_e1_g3 - baseline_log_e1_g0)/baseline_log_e1_g0
imp_mppV1_baseline_e1_g4 = (mppV1_log_e1_g4 - baseline_log_e1_g0)/baseline_log_e1_g0

print("MPP-GWAS vs. SBayesRC-Multi: "+str(np.mean(np.concatenate((imp_mppV1_sbrcM_e1_g1,imp_mppV1_sbrcM_e1_g2,\
                                                                 imp_mppV1_sbrcM_e1_g3,imp_mppV1_sbrcM_e1_g4)))))
print("MPP-GWAS vs. SBayesRC: "+str(np.mean(np.concatenate((imp_mppV1_sbrc_e1_g1,imp_mppV1_sbrc_e1_g2,\
                                                            imp_mppV1_sbrc_e1_g3,imp_mppV1_sbrc_e1_g4)))))
print("MPP-GWAS vs. PROSPER: "+str(np.mean(np.concatenate((imp_mppV1_prosper_e1_g1,imp_mppV1_prosper_e1_g2,\
                                                           imp_mppV1_prosper_e1_g3,imp_mppV1_prosper_e1_g4)))))
print("MPP-GWAS vs. PRS-CSx: "+str(np.mean(np.concatenate((imp_mppV1_prscsx_e1_g1,imp_mppV1_prscsx_e1_g2,\
                                                           imp_mppV1_prscsx_e1_g3,imp_mppV1_prscsx_e1_g4)))))
print("MPP-GWAS vs. TL-Multi: "+str(np.mean(np.concatenate((imp_mppV1_tlmulti_e1_g1,imp_mppV1_tlmulti_e1_g2,\
                                                           imp_mppV1_tlmulti_e1_g3,imp_mppV1_tlmulti_e1_g4)))))
print("MPP-GWAS vs. Lassosum2: "+str(np.mean(np.concatenate((imp_mppV1_lassosum2_e1_g1,imp_mppV1_lassosum2_e1_g2,\
                                                           imp_mppV1_lassosum2_e1_g3,imp_mppV1_lassosum2_e1_g4)))))
print("MPP-GWAS vs. LassosumTLD: "+str(np.mean(np.concatenate((imp_mppV1_lassosumTLD_e1_g1,imp_mppV1_lassosumTLD_e1_g2,\
                                                           imp_mppV1_lassosumTLD_e1_g3,imp_mppV1_lassosumTLD_e1_g4)))))
print("MPP-GWAS vs. Baseline: "+str(np.mean(np.concatenate((imp_mppV1_baseline_e1_g1,imp_mppV1_baseline_e1_g2,\
                                                           imp_mppV1_baseline_e1_g3,imp_mppV1_baseline_e1_g4)))))
# Out:
# MPP-GWAS vs. SBayesRC-Multi: 0.09265868614813573
# MPP-GWAS vs. SBayesRC: 0.6077936721109711
# MPP-GWAS vs. PROSPER: 0.29032842191655517
# MPP-GWAS vs. PRS-CSx: 0.45707542866171263
# MPP-GWAS vs. TL-Multi: 0.4970796116227067
# MPP-GWAS vs. Lassosum2: 0.46780422096575414
# MPP-GWAS vs. LassosumTLD: 0.07596827478227663
# MPP-GWAS vs. Baseline: 0.3001238596662004

# %%
imp_mppV3_sbrcM_e1_g1 = (mppV3_log_e1_g1 - sbrcM_log_e1_g1)/sbrcM_log_e1_g1
imp_mppV3_sbrcM_e1_g2 = (mppV3_log_e1_g2 - sbrcM_log_e1_g2)/sbrcM_log_e1_g2
imp_mppV3_sbrcM_e1_g3 = (mppV3_log_e1_g3 - sbrcM_log_e1_g3)/sbrcM_log_e1_g3
imp_mppV3_sbrcM_e1_g4 = (mppV3_log_e1_g4 - sbrcM_log_e1_g4)/sbrcM_log_e1_g4

imp_mppV3_sbrc_e1_g1 = (mppV3_log_e1_g1 - sbrc_log_e1_g0)/sbrc_log_e1_g0
imp_mppV3_sbrc_e1_g2 = (mppV3_log_e1_g2 - sbrc_log_e1_g0)/sbrc_log_e1_g0
imp_mppV3_sbrc_e1_g3 = (mppV3_log_e1_g3 - sbrc_log_e1_g0)/sbrc_log_e1_g0
imp_mppV3_sbrc_e1_g4 = (mppV3_log_e1_g4 - sbrc_log_e1_g0)/sbrc_log_e1_g0

imp_mppV3_prosper_e1_g1 = (mppV3_log_e1_g1 - prosper_log_e1_g1)/prosper_log_e1_g1
imp_mppV3_prosper_e1_g2 = (mppV3_log_e1_g2 - prosper_log_e1_g2)/prosper_log_e1_g2
imp_mppV3_prosper_e1_g3 = (mppV3_log_e1_g3 - prosper_log_e1_g3)/prosper_log_e1_g3
imp_mppV3_prosper_e1_g4 = (mppV3_log_e1_g4 - prosper_log_e1_g4)/prosper_log_e1_g4

imp_mppV3_prscsx_e1_g1 = (mppV3_log_e1_g1 - prscsx_log_e1_g1)/prscsx_log_e1_g1
imp_mppV3_prscsx_e1_g2 = (mppV3_log_e1_g2 - prscsx_log_e1_g2)/prscsx_log_e1_g2
imp_mppV3_prscsx_e1_g3 = (mppV3_log_e1_g3 - prscsx_log_e1_g3)/prscsx_log_e1_g3
imp_mppV3_prscsx_e1_g4 = (mppV3_log_e1_g4 - prscsx_log_e1_g4)/prscsx_log_e1_g4

imp_mppV3_lassosum2_e1_g1 = (mppV3_log_e1_g1 - lassosum2_log_e1_g0)/lassosum2_log_e1_g0
imp_mppV3_lassosum2_e1_g2 = (mppV3_log_e1_g2 - lassosum2_log_e1_g0)/lassosum2_log_e1_g0
imp_mppV3_lassosum2_e1_g3 = (mppV3_log_e1_g3 - lassosum2_log_e1_g0)/lassosum2_log_e1_g0
imp_mppV3_lassosum2_e1_g4 = (mppV3_log_e1_g4 - lassosum2_log_e1_g0)/lassosum2_log_e1_g0

imp_mppV3_lassosumTLD_e1_g1 = (mppV3_log_e1_g1 - lassosumTLD_log_e1_g0)/lassosumTLD_log_e1_g0
imp_mppV3_lassosumTLD_e1_g2 = (mppV3_log_e1_g2 - lassosumTLD_log_e1_g0)/lassosumTLD_log_e1_g0
imp_mppV3_lassosumTLD_e1_g3 = (mppV3_log_e1_g3 - lassosumTLD_log_e1_g0)/lassosumTLD_log_e1_g0
imp_mppV3_lassosumTLD_e1_g4 = (mppV3_log_e1_g4 - lassosumTLD_log_e1_g0)/lassosumTLD_log_e1_g0

imp_mppV3_tlmulti_e1_g1 = (mppV3_log_e1_g1 - tlmulti_log_e1_g1)/tlmulti_log_e1_g1
imp_mppV3_tlmulti_e1_g2 = (mppV3_log_e1_g2 - tlmulti_log_e1_g1)/tlmulti_log_e1_g1
imp_mppV3_tlmulti_e1_g3 = (mppV3_log_e1_g3 - tlmulti_log_e1_g1)/tlmulti_log_e1_g1
imp_mppV3_tlmulti_e1_g4 = (mppV3_log_e1_g4 - tlmulti_log_e1_g1)/tlmulti_log_e1_g1

imp_mppV3_baseline_e1_g1 = (mppV3_log_e1_g1 - baseline_log_e1_g0)/baseline_log_e1_g0
imp_mppV3_baseline_e1_g2 = (mppV3_log_e1_g2 - baseline_log_e1_g0)/baseline_log_e1_g0
imp_mppV3_baseline_e1_g3 = (mppV3_log_e1_g3 - baseline_log_e1_g0)/baseline_log_e1_g0
imp_mppV3_baseline_e1_g4 = (mppV3_log_e1_g4 - baseline_log_e1_g0)/baseline_log_e1_g0

print("MPP-GWAS-Admix vs. SBayesRC-Multi: "+str(np.mean(np.concatenate((imp_mppV3_sbrcM_e1_g1,imp_mppV3_sbrcM_e1_g2,\
                                                                 imp_mppV3_sbrcM_e1_g3,imp_mppV3_sbrcM_e1_g4)))))
print("MPP-GWAS-Admix vs. SBayesRC: "+str(np.mean(np.concatenate((imp_mppV3_sbrc_e1_g1,imp_mppV3_sbrc_e1_g2,\
                                                            imp_mppV3_sbrc_e1_g3,imp_mppV3_sbrc_e1_g4)))))
print("MPP-GWAS-Admix vs. PROSPER: "+str(np.mean(np.concatenate((imp_mppV3_prosper_e1_g1,imp_mppV3_prosper_e1_g2,\
                                                           imp_mppV3_prosper_e1_g3,imp_mppV3_prosper_e1_g4)))))
print("MPP-GWAS-Admix vs. PRS-CSx: "+str(np.mean(np.concatenate((imp_mppV3_prscsx_e1_g1,imp_mppV3_prscsx_e1_g2,\
                                                           imp_mppV3_prscsx_e1_g3,imp_mppV3_prscsx_e1_g4)))))
print("MPP-GWAS-Admix vs. TL-Multi: "+str(np.mean(np.concatenate((imp_mppV3_tlmulti_e1_g1,imp_mppV3_tlmulti_e1_g2,\
                                                           imp_mppV3_tlmulti_e1_g3,imp_mppV3_tlmulti_e1_g4)))))
print("MPP-GWAS-Admix vs. Lassosum2: "+str(np.mean(np.concatenate((imp_mppV3_lassosum2_e1_g1,imp_mppV3_lassosum2_e1_g2,\
                                                           imp_mppV3_lassosum2_e1_g3,imp_mppV3_lassosum2_e1_g4)))))
print("MPP-GWAS-Admix vs. LassosumTLD: "+str(np.mean(np.concatenate((imp_mppV3_lassosumTLD_e1_g1,imp_mppV3_lassosumTLD_e1_g2,\
                                                           imp_mppV3_lassosumTLD_e1_g3,imp_mppV3_lassosumTLD_e1_g4)))))
print("MPP-GWAS-Admix vs. Baseline: "+str(np.mean(np.concatenate((imp_mppV3_baseline_e1_g1,imp_mppV3_baseline_e1_g2,\
                                                           imp_mppV3_baseline_e1_g3,imp_mppV3_baseline_e1_g4)))))
# Out:
# MPP-GWAS-Admix vs. SBayesRC-Multi: 0.17201416850101706
# MPP-GWAS-Admix vs. SBayesRC: 0.6908125409792321
# MPP-GWAS-Admix vs. PROSPER: 0.3696663715573427
# MPP-GWAS-Admix vs. PRS-CSx: 0.5418084126437284
# MPP-GWAS-Admix vs. TL-Multi: 0.5911692104545319
# MPP-GWAS-Admix vs. Lassosum2: 0.5494423280873073
# MPP-GWAS-Admix vs. LassosumTLD: 0.1348567743603118
# MPP-GWAS-Admix vs. Baseline: 0.3795501786496128

# %%
imp_mppV4B_sbrcM_e2_g1 = (mppV4B_log_e2_g1 - sbrcM_log_e2_g1)/sbrcM_log_e2_g1
imp_mppV4B_sbrcM_e2_g2 = (mppV4B_log_e2_g2 - sbrcM_log_e2_g2)/sbrcM_log_e2_g2
imp_mppV4B_sbrcM_e2_g3 = (mppV4B_log_e2_g3 - sbrcM_log_e2_g3)/sbrcM_log_e2_g3
imp_mppV4B_sbrcM_e2_g4 = (mppV4B_log_e2_g4 - sbrcM_log_e2_g4)/sbrcM_log_e2_g4

imp_mppV4B_sbrc_e2_g1 = (mppV4B_log_e2_g1 - sbrc_log_e2_g0)/sbrc_log_e2_g0
imp_mppV4B_sbrc_e2_g2 = (mppV4B_log_e2_g2 - sbrc_log_e2_g0)/sbrc_log_e2_g0
imp_mppV4B_sbrc_e2_g3 = (mppV4B_log_e2_g3 - sbrc_log_e2_g0)/sbrc_log_e2_g0
imp_mppV4B_sbrc_e2_g4 = (mppV4B_log_e2_g4 - sbrc_log_e2_g0)/sbrc_log_e2_g0

imp_mppV4B_prosper_e2_g1 = (mppV4B_log_e2_g1 - prosper_log_e2_g1)/prosper_log_e2_g1
imp_mppV4B_prosper_e2_g2 = (mppV4B_log_e2_g2 - prosper_log_e2_g2)/prosper_log_e2_g2
imp_mppV4B_prosper_e2_g3 = (mppV4B_log_e2_g3 - prosper_log_e2_g3)/prosper_log_e2_g3
imp_mppV4B_prosper_e2_g4 = (mppV4B_log_e2_g4 - prosper_log_e2_g4)/prosper_log_e2_g4

imp_mppV4B_prscsx_e2_g1 = (mppV4B_log_e2_g1 - prscsx_log_e2_g1)/prscsx_log_e2_g1
imp_mppV4B_prscsx_e2_g2 = (mppV4B_log_e2_g2 - prscsx_log_e2_g2)/prscsx_log_e2_g2
imp_mppV4B_prscsx_e2_g3 = (mppV4B_log_e2_g3 - prscsx_log_e2_g3)/prscsx_log_e2_g3
imp_mppV4B_prscsx_e2_g4 = (mppV4B_log_e2_g4 - prscsx_log_e2_g4)/prscsx_log_e2_g4

imp_mppV4B_lassosum2_e2_g1 = (mppV4B_log_e2_g1 - lassosum2_log_e2_g0)/lassosum2_log_e2_g0
imp_mppV4B_lassosum2_e2_g2 = (mppV4B_log_e2_g2 - lassosum2_log_e2_g0)/lassosum2_log_e2_g0
imp_mppV4B_lassosum2_e2_g3 = (mppV4B_log_e2_g3 - lassosum2_log_e2_g0)/lassosum2_log_e2_g0
imp_mppV4B_lassosum2_e2_g4 = (mppV4B_log_e2_g4 - lassosum2_log_e2_g0)/lassosum2_log_e2_g0

imp_mppV4B_lassosumTLD_e2_g1 = (mppV4B_log_e2_g1 - lassosumTLD_log_e2_g0)/lassosumTLD_log_e2_g0
imp_mppV4B_lassosumTLD_e2_g2 = (mppV4B_log_e2_g2 - lassosumTLD_log_e2_g0)/lassosumTLD_log_e2_g0
imp_mppV4B_lassosumTLD_e2_g3 = (mppV4B_log_e2_g3 - lassosumTLD_log_e2_g0)/lassosumTLD_log_e2_g0
imp_mppV4B_lassosumTLD_e2_g4 = (mppV4B_log_e2_g4 - lassosumTLD_log_e2_g0)/lassosumTLD_log_e2_g0

imp_mppV4B_tlmulti_e2_g1 = (mppV4B_log_e2_g1 - tlmulti_log_e2_g1)/tlmulti_log_e2_g1
imp_mppV4B_tlmulti_e2_g2 = (mppV4B_log_e2_g2 - tlmulti_log_e2_g1)/tlmulti_log_e2_g1
imp_mppV4B_tlmulti_e2_g3 = (mppV4B_log_e2_g3 - tlmulti_log_e2_g1)/tlmulti_log_e2_g1
imp_mppV4B_tlmulti_e2_g4 = (mppV4B_log_e2_g4 - tlmulti_log_e2_g1)/tlmulti_log_e2_g1

imp_mppV4B_baseline_e2_g1 = (mppV4B_log_e2_g1 - baseline_log_e2_g0)/baseline_log_e2_g0
imp_mppV4B_baseline_e2_g2 = (mppV4B_log_e2_g2 - baseline_log_e2_g0)/baseline_log_e2_g0
imp_mppV4B_baseline_e2_g3 = (mppV4B_log_e2_g3 - baseline_log_e2_g0)/baseline_log_e2_g0
imp_mppV4B_baseline_e2_g4 = (mppV4B_log_e2_g4 - baseline_log_e2_g0)/baseline_log_e2_g0

imp_mppV4B_sbrcM_e3_g1 = (mppV4B_log_e3_g1 - sbrcM_log_e3_g1)/sbrcM_log_e3_g1
imp_mppV4B_sbrcM_e3_g2 = (mppV4B_log_e3_g2 - sbrcM_log_e3_g2)/sbrcM_log_e3_g2
imp_mppV4B_sbrcM_e3_g3 = (mppV4B_log_e3_g3 - sbrcM_log_e3_g3)/sbrcM_log_e3_g3
imp_mppV4B_sbrcM_e3_g4 = (mppV4B_log_e3_g4 - sbrcM_log_e3_g4)/sbrcM_log_e3_g4

imp_mppV4B_sbrc_e3_g1 = (mppV4B_log_e3_g1 - sbrc_log_e3_g0)/sbrc_log_e3_g0
imp_mppV4B_sbrc_e3_g2 = (mppV4B_log_e3_g2 - sbrc_log_e3_g0)/sbrc_log_e3_g0
imp_mppV4B_sbrc_e3_g3 = (mppV4B_log_e3_g3 - sbrc_log_e3_g0)/sbrc_log_e3_g0
imp_mppV4B_sbrc_e3_g4 = (mppV4B_log_e3_g4 - sbrc_log_e3_g0)/sbrc_log_e3_g0

imp_mppV4B_prosper_e3_g1 = (mppV4B_log_e3_g1 - prosper_log_e3_g1)/prosper_log_e3_g1
imp_mppV4B_prosper_e3_g2 = (mppV4B_log_e3_g2 - prosper_log_e3_g2)/prosper_log_e3_g2
imp_mppV4B_prosper_e3_g3 = (mppV4B_log_e3_g3 - prosper_log_e3_g3)/prosper_log_e3_g3
imp_mppV4B_prosper_e3_g4 = (mppV4B_log_e3_g4 - prosper_log_e3_g4)/prosper_log_e3_g4

imp_mppV4B_prscsx_e3_g1 = (mppV4B_log_e3_g1 - prscsx_log_e3_g1)/prscsx_log_e3_g1
imp_mppV4B_prscsx_e3_g2 = (mppV4B_log_e3_g2 - prscsx_log_e3_g2)/prscsx_log_e3_g2
imp_mppV4B_prscsx_e3_g3 = (mppV4B_log_e3_g3 - prscsx_log_e3_g3)/prscsx_log_e3_g3
imp_mppV4B_prscsx_e3_g4 = (mppV4B_log_e3_g4 - prscsx_log_e3_g4)/prscsx_log_e3_g4

imp_mppV4B_lassosum2_e3_g1 = (mppV4B_log_e3_g1 - lassosum2_log_e3_g0)/lassosum2_log_e3_g0
imp_mppV4B_lassosum2_e3_g2 = (mppV4B_log_e3_g2 - lassosum2_log_e3_g0)/lassosum2_log_e3_g0
imp_mppV4B_lassosum2_e3_g3 = (mppV4B_log_e3_g3 - lassosum2_log_e3_g0)/lassosum2_log_e3_g0
imp_mppV4B_lassosum2_e3_g4 = (mppV4B_log_e3_g4 - lassosum2_log_e3_g0)/lassosum2_log_e3_g0

imp_mppV4B_lassosumTLD_e3_g1 = (mppV4B_log_e3_g1 - lassosumTLD_log_e3_g0)/lassosumTLD_log_e3_g0
imp_mppV4B_lassosumTLD_e3_g2 = (mppV4B_log_e3_g2 - lassosumTLD_log_e3_g0)/lassosumTLD_log_e3_g0
imp_mppV4B_lassosumTLD_e3_g3 = (mppV4B_log_e3_g3 - lassosumTLD_log_e3_g0)/lassosumTLD_log_e3_g0
imp_mppV4B_lassosumTLD_e3_g4 = (mppV4B_log_e3_g4 - lassosumTLD_log_e3_g0)/lassosumTLD_log_e3_g0

imp_mppV4B_tlmulti_e3_g1 = (mppV4B_log_e3_g1 - tlmulti_log_e3_g1)/tlmulti_log_e3_g1
imp_mppV4B_tlmulti_e3_g2 = (mppV4B_log_e3_g2 - tlmulti_log_e3_g1)/tlmulti_log_e3_g1
imp_mppV4B_tlmulti_e3_g3 = (mppV4B_log_e3_g3 - tlmulti_log_e3_g1)/tlmulti_log_e3_g1
imp_mppV4B_tlmulti_e3_g4 = (mppV4B_log_e3_g4 - tlmulti_log_e3_g1)/tlmulti_log_e3_g1

imp_mppV4B_baseline_e3_g1 = (mppV4B_log_e3_g1 - baseline_log_e3_g0)/baseline_log_e3_g0
imp_mppV4B_baseline_e3_g2 = (mppV4B_log_e3_g2 - baseline_log_e3_g0)/baseline_log_e3_g0
imp_mppV4B_baseline_e3_g3 = (mppV4B_log_e3_g3 - baseline_log_e3_g0)/baseline_log_e3_g0
imp_mppV4B_baseline_e3_g4 = (mppV4B_log_e3_g4 - baseline_log_e3_g0)/baseline_log_e3_g0

imp_mppV4B_sbrcM_e4_g1 = (mppV4B_log_e4_g1 - sbrcM_log_e4_g1)/sbrcM_log_e4_g1
imp_mppV4B_sbrcM_e4_g2 = (mppV4B_log_e4_g2 - sbrcM_log_e4_g2)/sbrcM_log_e4_g2
imp_mppV4B_sbrcM_e4_g3 = (mppV4B_log_e4_g3 - sbrcM_log_e4_g3)/sbrcM_log_e4_g3
imp_mppV4B_sbrcM_e4_g4 = (mppV4B_log_e4_g4 - sbrcM_log_e4_g4)/sbrcM_log_e4_g4

imp_mppV4B_sbrc_e4_g1 = (mppV4B_log_e4_g1 - sbrc_log_e4_g0)/sbrc_log_e4_g0
imp_mppV4B_sbrc_e4_g2 = (mppV4B_log_e4_g2 - sbrc_log_e4_g0)/sbrc_log_e4_g0
imp_mppV4B_sbrc_e4_g3 = (mppV4B_log_e4_g3 - sbrc_log_e4_g0)/sbrc_log_e4_g0
imp_mppV4B_sbrc_e4_g4 = (mppV4B_log_e4_g4 - sbrc_log_e4_g0)/sbrc_log_e4_g0

imp_mppV4B_prosper_e4_g1 = (mppV4B_log_e4_g1 - prosper_log_e4_g1)/prosper_log_e4_g1
imp_mppV4B_prosper_e4_g2 = (mppV4B_log_e4_g2 - prosper_log_e4_g2)/prosper_log_e4_g2
imp_mppV4B_prosper_e4_g3 = (mppV4B_log_e4_g3 - prosper_log_e4_g3)/prosper_log_e4_g3
imp_mppV4B_prosper_e4_g4 = (mppV4B_log_e4_g4 - prosper_log_e4_g4)/prosper_log_e4_g4

imp_mppV4B_prscsx_e4_g1 = (mppV4B_log_e4_g1 - prscsx_log_e4_g1)/prscsx_log_e4_g1
imp_mppV4B_prscsx_e4_g2 = (mppV4B_log_e4_g2 - prscsx_log_e4_g2)/prscsx_log_e4_g2
imp_mppV4B_prscsx_e4_g3 = (mppV4B_log_e4_g3 - prscsx_log_e4_g3)/prscsx_log_e4_g3
imp_mppV4B_prscsx_e4_g4 = (mppV4B_log_e4_g4 - prscsx_log_e4_g4)/prscsx_log_e4_g4

imp_mppV4B_lassosum2_e4_g1 = (mppV4B_log_e4_g1 - lassosum2_log_e4_g0)/lassosum2_log_e4_g0
imp_mppV4B_lassosum2_e4_g2 = (mppV4B_log_e4_g2 - lassosum2_log_e4_g0)/lassosum2_log_e4_g0
imp_mppV4B_lassosum2_e4_g3 = (mppV4B_log_e4_g3 - lassosum2_log_e4_g0)/lassosum2_log_e4_g0
imp_mppV4B_lassosum2_e4_g4 = (mppV4B_log_e4_g4 - lassosum2_log_e4_g0)/lassosum2_log_e4_g0

imp_mppV4B_lassosumTLD_e4_g1 = (mppV4B_log_e4_g1 - lassosumTLD_log_e4_g0)/lassosumTLD_log_e4_g0
imp_mppV4B_lassosumTLD_e4_g2 = (mppV4B_log_e4_g2 - lassosumTLD_log_e4_g0)/lassosumTLD_log_e4_g0
imp_mppV4B_lassosumTLD_e4_g3 = (mppV4B_log_e4_g3 - lassosumTLD_log_e4_g0)/lassosumTLD_log_e4_g0
imp_mppV4B_lassosumTLD_e4_g4 = (mppV4B_log_e4_g4 - lassosumTLD_log_e4_g0)/lassosumTLD_log_e4_g0

imp_mppV4B_tlmulti_e4_g1 = (mppV4B_log_e4_g1 - tlmulti_log_e4_g1)/tlmulti_log_e4_g1
imp_mppV4B_tlmulti_e4_g2 = (mppV4B_log_e4_g2 - tlmulti_log_e4_g1)/tlmulti_log_e4_g1
imp_mppV4B_tlmulti_e4_g3 = (mppV4B_log_e4_g3 - tlmulti_log_e4_g1)/tlmulti_log_e4_g1
imp_mppV4B_tlmulti_e4_g4 = (mppV4B_log_e4_g4 - tlmulti_log_e4_g1)/tlmulti_log_e4_g1

imp_mppV4B_baseline_e4_g1 = (mppV4B_log_e4_g1 - baseline_log_e4_g0)/baseline_log_e4_g0
imp_mppV4B_baseline_e4_g2 = (mppV4B_log_e4_g2 - baseline_log_e4_g0)/baseline_log_e4_g0
imp_mppV4B_baseline_e4_g3 = (mppV4B_log_e4_g3 - baseline_log_e4_g0)/baseline_log_e4_g0
imp_mppV4B_baseline_e4_g4 = (mppV4B_log_e4_g4 - baseline_log_e4_g0)/baseline_log_e4_g0

imp_mppV4B_sbrcM_e5_g1 = (mppV4B_log_e5_g1 - sbrcM_log_e5_g1)/sbrcM_log_e5_g1
imp_mppV4B_sbrcM_e5_g2 = (mppV4B_log_e5_g2 - sbrcM_log_e5_g2)/sbrcM_log_e5_g2
imp_mppV4B_sbrcM_e5_g3 = (mppV4B_log_e5_g3 - sbrcM_log_e5_g3)/sbrcM_log_e5_g3
imp_mppV4B_sbrcM_e5_g4 = (mppV4B_log_e5_g4 - sbrcM_log_e5_g4)/sbrcM_log_e5_g4

imp_mppV4B_sbrc_e5_g1 = (mppV4B_log_e5_g1 - sbrc_log_e5_g0)/sbrc_log_e5_g0
imp_mppV4B_sbrc_e5_g2 = (mppV4B_log_e5_g2 - sbrc_log_e5_g0)/sbrc_log_e5_g0
imp_mppV4B_sbrc_e5_g3 = (mppV4B_log_e5_g3 - sbrc_log_e5_g0)/sbrc_log_e5_g0
imp_mppV4B_sbrc_e5_g4 = (mppV4B_log_e5_g4 - sbrc_log_e5_g0)/sbrc_log_e5_g0

imp_mppV4B_prosper_e5_g1 = (mppV4B_log_e5_g1 - prosper_log_e5_g1)/prosper_log_e5_g1
imp_mppV4B_prosper_e5_g2 = (mppV4B_log_e5_g2 - prosper_log_e5_g2)/prosper_log_e5_g2
imp_mppV4B_prosper_e5_g3 = (mppV4B_log_e5_g3 - prosper_log_e5_g3)/prosper_log_e5_g3
imp_mppV4B_prosper_e5_g4 = (mppV4B_log_e5_g4 - prosper_log_e5_g4)/prosper_log_e5_g4

imp_mppV4B_prscsx_e5_g1 = (mppV4B_log_e5_g1 - prscsx_log_e5_g1)/prscsx_log_e5_g1
imp_mppV4B_prscsx_e5_g2 = (mppV4B_log_e5_g2 - prscsx_log_e5_g2)/prscsx_log_e5_g2
imp_mppV4B_prscsx_e5_g3 = (mppV4B_log_e5_g3 - prscsx_log_e5_g3)/prscsx_log_e5_g3
imp_mppV4B_prscsx_e5_g4 = (mppV4B_log_e5_g4 - prscsx_log_e5_g4)/prscsx_log_e5_g4

imp_mppV4B_lassosum2_e5_g1 = (mppV4B_log_e5_g1 - lassosum2_log_e5_g0)/lassosum2_log_e5_g0
imp_mppV4B_lassosum2_e5_g2 = (mppV4B_log_e5_g2 - lassosum2_log_e5_g0)/lassosum2_log_e5_g0
imp_mppV4B_lassosum2_e5_g3 = (mppV4B_log_e5_g3 - lassosum2_log_e5_g0)/lassosum2_log_e5_g0
imp_mppV4B_lassosum2_e5_g4 = (mppV4B_log_e5_g4 - lassosum2_log_e5_g0)/lassosum2_log_e5_g0

imp_mppV4B_lassosumTLD_e5_g1 = (mppV4B_log_e5_g1 - lassosumTLD_log_e5_g0)/lassosumTLD_log_e5_g0
imp_mppV4B_lassosumTLD_e5_g2 = (mppV4B_log_e5_g2 - lassosumTLD_log_e5_g0)/lassosumTLD_log_e5_g0
imp_mppV4B_lassosumTLD_e5_g3 = (mppV4B_log_e5_g3 - lassosumTLD_log_e5_g0)/lassosumTLD_log_e5_g0
imp_mppV4B_lassosumTLD_e5_g4 = (mppV4B_log_e5_g4 - lassosumTLD_log_e5_g0)/lassosumTLD_log_e5_g0

imp_mppV4B_tlmulti_e5_g1 = (mppV4B_log_e5_g1 - tlmulti_log_e5_g1)/tlmulti_log_e5_g1
imp_mppV4B_tlmulti_e5_g2 = (mppV4B_log_e5_g2 - tlmulti_log_e5_g1)/tlmulti_log_e5_g1
imp_mppV4B_tlmulti_e5_g3 = (mppV4B_log_e5_g3 - tlmulti_log_e5_g1)/tlmulti_log_e5_g1
imp_mppV4B_tlmulti_e5_g4 = (mppV4B_log_e5_g4 - tlmulti_log_e5_g1)/tlmulti_log_e5_g1

imp_mppV4B_baseline_e5_g1 = (mppV4B_log_e5_g1 - baseline_log_e5_g0)/baseline_log_e5_g0
imp_mppV4B_baseline_e5_g2 = (mppV4B_log_e5_g2 - baseline_log_e5_g0)/baseline_log_e5_g0
imp_mppV4B_baseline_e5_g3 = (mppV4B_log_e5_g3 - baseline_log_e5_g0)/baseline_log_e5_g0
imp_mppV4B_baseline_e5_g4 = (mppV4B_log_e5_g4 - baseline_log_e5_g0)/baseline_log_e5_g0

# %%
imp_mppV4_sbrcM_e2_g1 = (mppV4_log_e2_g1 - sbrcM_log_e2_g1)/sbrcM_log_e2_g1
imp_mppV4_sbrcM_e2_g2 = (mppV4_log_e2_g2 - sbrcM_log_e2_g2)/sbrcM_log_e2_g2
imp_mppV4_sbrcM_e2_g3 = (mppV4_log_e2_g3 - sbrcM_log_e2_g3)/sbrcM_log_e2_g3
imp_mppV4_sbrcM_e2_g4 = (mppV4_log_e2_g4 - sbrcM_log_e2_g4)/sbrcM_log_e2_g4

imp_mppV4_sbrc_e2_g1 = (mppV4_log_e2_g1 - sbrc_log_e2_g0)/sbrc_log_e2_g0
imp_mppV4_sbrc_e2_g2 = (mppV4_log_e2_g2 - sbrc_log_e2_g0)/sbrc_log_e2_g0
imp_mppV4_sbrc_e2_g3 = (mppV4_log_e2_g3 - sbrc_log_e2_g0)/sbrc_log_e2_g0
imp_mppV4_sbrc_e2_g4 = (mppV4_log_e2_g4 - sbrc_log_e2_g0)/sbrc_log_e2_g0

imp_mppV4_prosper_e2_g1 = (mppV4_log_e2_g1 - prosper_log_e2_g1)/prosper_log_e2_g1
imp_mppV4_prosper_e2_g2 = (mppV4_log_e2_g2 - prosper_log_e2_g2)/prosper_log_e2_g2
imp_mppV4_prosper_e2_g3 = (mppV4_log_e2_g3 - prosper_log_e2_g3)/prosper_log_e2_g3
imp_mppV4_prosper_e2_g4 = (mppV4_log_e2_g4 - prosper_log_e2_g4)/prosper_log_e2_g4

imp_mppV4_prscsx_e2_g1 = (mppV4_log_e2_g1 - prscsx_log_e2_g1)/prscsx_log_e2_g1
imp_mppV4_prscsx_e2_g2 = (mppV4_log_e2_g2 - prscsx_log_e2_g2)/prscsx_log_e2_g2
imp_mppV4_prscsx_e2_g3 = (mppV4_log_e2_g3 - prscsx_log_e2_g3)/prscsx_log_e2_g3
imp_mppV4_prscsx_e2_g4 = (mppV4_log_e2_g4 - prscsx_log_e2_g4)/prscsx_log_e2_g4

imp_mppV4_lassosum2_e2_g1 = (mppV4_log_e2_g1 - lassosum2_log_e2_g0)/lassosum2_log_e2_g0
imp_mppV4_lassosum2_e2_g2 = (mppV4_log_e2_g2 - lassosum2_log_e2_g0)/lassosum2_log_e2_g0
imp_mppV4_lassosum2_e2_g3 = (mppV4_log_e2_g3 - lassosum2_log_e2_g0)/lassosum2_log_e2_g0
imp_mppV4_lassosum2_e2_g4 = (mppV4_log_e2_g4 - lassosum2_log_e2_g0)/lassosum2_log_e2_g0

imp_mppV4_lassosumTLD_e2_g1 = (mppV4_log_e2_g1 - lassosumTLD_log_e2_g0)/lassosumTLD_log_e2_g0
imp_mppV4_lassosumTLD_e2_g2 = (mppV4_log_e2_g2 - lassosumTLD_log_e2_g0)/lassosumTLD_log_e2_g0
imp_mppV4_lassosumTLD_e2_g3 = (mppV4_log_e2_g3 - lassosumTLD_log_e2_g0)/lassosumTLD_log_e2_g0
imp_mppV4_lassosumTLD_e2_g4 = (mppV4_log_e2_g4 - lassosumTLD_log_e2_g0)/lassosumTLD_log_e2_g0

imp_mppV4_tlmulti_e2_g1 = (mppV4_log_e2_g1 - tlmulti_log_e2_g1)/tlmulti_log_e2_g1
imp_mppV4_tlmulti_e2_g2 = (mppV4_log_e2_g2 - tlmulti_log_e2_g1)/tlmulti_log_e2_g1
imp_mppV4_tlmulti_e2_g3 = (mppV4_log_e2_g3 - tlmulti_log_e2_g1)/tlmulti_log_e2_g1
imp_mppV4_tlmulti_e2_g4 = (mppV4_log_e2_g4 - tlmulti_log_e2_g1)/tlmulti_log_e2_g1

imp_mppV4_baseline_e2_g1 = (mppV4_log_e2_g1 - baseline_log_e2_g0)/baseline_log_e2_g0
imp_mppV4_baseline_e2_g2 = (mppV4_log_e2_g2 - baseline_log_e2_g0)/baseline_log_e2_g0
imp_mppV4_baseline_e2_g3 = (mppV4_log_e2_g3 - baseline_log_e2_g0)/baseline_log_e2_g0
imp_mppV4_baseline_e2_g4 = (mppV4_log_e2_g4 - baseline_log_e2_g0)/baseline_log_e2_g0

imp_mppV4_sbrcM_e3_g1 = (mppV4_log_e3_g1 - sbrcM_log_e3_g1)/sbrcM_log_e3_g1
imp_mppV4_sbrcM_e3_g2 = (mppV4_log_e3_g2 - sbrcM_log_e3_g2)/sbrcM_log_e3_g2
imp_mppV4_sbrcM_e3_g3 = (mppV4_log_e3_g3 - sbrcM_log_e3_g3)/sbrcM_log_e3_g3
imp_mppV4_sbrcM_e3_g4 = (mppV4_log_e3_g4 - sbrcM_log_e3_g4)/sbrcM_log_e3_g4

imp_mppV4_sbrc_e3_g1 = (mppV4_log_e3_g1 - sbrc_log_e3_g0)/sbrc_log_e3_g0
imp_mppV4_sbrc_e3_g2 = (mppV4_log_e3_g2 - sbrc_log_e3_g0)/sbrc_log_e3_g0
imp_mppV4_sbrc_e3_g3 = (mppV4_log_e3_g3 - sbrc_log_e3_g0)/sbrc_log_e3_g0
imp_mppV4_sbrc_e3_g4 = (mppV4_log_e3_g4 - sbrc_log_e3_g0)/sbrc_log_e3_g0

imp_mppV4_prosper_e3_g1 = (mppV4_log_e3_g1 - prosper_log_e3_g1)/prosper_log_e3_g1
imp_mppV4_prosper_e3_g2 = (mppV4_log_e3_g2 - prosper_log_e3_g2)/prosper_log_e3_g2
imp_mppV4_prosper_e3_g3 = (mppV4_log_e3_g3 - prosper_log_e3_g3)/prosper_log_e3_g3
imp_mppV4_prosper_e3_g4 = (mppV4_log_e3_g4 - prosper_log_e3_g4)/prosper_log_e3_g4

imp_mppV4_prscsx_e3_g1 = (mppV4_log_e3_g1 - prscsx_log_e3_g1)/prscsx_log_e3_g1
imp_mppV4_prscsx_e3_g2 = (mppV4_log_e3_g2 - prscsx_log_e3_g2)/prscsx_log_e3_g2
imp_mppV4_prscsx_e3_g3 = (mppV4_log_e3_g3 - prscsx_log_e3_g3)/prscsx_log_e3_g3
imp_mppV4_prscsx_e3_g4 = (mppV4_log_e3_g4 - prscsx_log_e3_g4)/prscsx_log_e3_g4

imp_mppV4_lassosum2_e3_g1 = (mppV4_log_e3_g1 - lassosum2_log_e3_g0)/lassosum2_log_e3_g0
imp_mppV4_lassosum2_e3_g2 = (mppV4_log_e3_g2 - lassosum2_log_e3_g0)/lassosum2_log_e3_g0
imp_mppV4_lassosum2_e3_g3 = (mppV4_log_e3_g3 - lassosum2_log_e3_g0)/lassosum2_log_e3_g0
imp_mppV4_lassosum2_e3_g4 = (mppV4_log_e3_g4 - lassosum2_log_e3_g0)/lassosum2_log_e3_g0

imp_mppV4_lassosumTLD_e3_g1 = (mppV4_log_e3_g1 - lassosumTLD_log_e3_g0)/lassosumTLD_log_e3_g0
imp_mppV4_lassosumTLD_e3_g2 = (mppV4_log_e3_g2 - lassosumTLD_log_e3_g0)/lassosumTLD_log_e3_g0
imp_mppV4_lassosumTLD_e3_g3 = (mppV4_log_e3_g3 - lassosumTLD_log_e3_g0)/lassosumTLD_log_e3_g0
imp_mppV4_lassosumTLD_e3_g4 = (mppV4_log_e3_g4 - lassosumTLD_log_e3_g0)/lassosumTLD_log_e3_g0

imp_mppV4_tlmulti_e3_g1 = (mppV4_log_e3_g1 - tlmulti_log_e3_g1)/tlmulti_log_e3_g1
imp_mppV4_tlmulti_e3_g2 = (mppV4_log_e3_g2 - tlmulti_log_e3_g1)/tlmulti_log_e3_g1
imp_mppV4_tlmulti_e3_g3 = (mppV4_log_e3_g3 - tlmulti_log_e3_g1)/tlmulti_log_e3_g1
imp_mppV4_tlmulti_e3_g4 = (mppV4_log_e3_g4 - tlmulti_log_e3_g1)/tlmulti_log_e3_g1

imp_mppV4_baseline_e3_g1 = (mppV4_log_e3_g1 - baseline_log_e3_g0)/baseline_log_e3_g0
imp_mppV4_baseline_e3_g2 = (mppV4_log_e3_g2 - baseline_log_e3_g0)/baseline_log_e3_g0
imp_mppV4_baseline_e3_g3 = (mppV4_log_e3_g3 - baseline_log_e3_g0)/baseline_log_e3_g0
imp_mppV4_baseline_e3_g4 = (mppV4_log_e3_g4 - baseline_log_e3_g0)/baseline_log_e3_g0

imp_mppV4_sbrcM_e4_g1 = (mppV4_log_e4_g1 - sbrcM_log_e4_g1)/sbrcM_log_e4_g1
imp_mppV4_sbrcM_e4_g2 = (mppV4_log_e4_g2 - sbrcM_log_e4_g2)/sbrcM_log_e4_g2
imp_mppV4_sbrcM_e4_g3 = (mppV4_log_e4_g3 - sbrcM_log_e4_g3)/sbrcM_log_e4_g3
imp_mppV4_sbrcM_e4_g4 = (mppV4_log_e4_g4 - sbrcM_log_e4_g4)/sbrcM_log_e4_g4

imp_mppV4_sbrc_e4_g1 = (mppV4_log_e4_g1 - sbrc_log_e4_g0)/sbrc_log_e4_g0
imp_mppV4_sbrc_e4_g2 = (mppV4_log_e4_g2 - sbrc_log_e4_g0)/sbrc_log_e4_g0
imp_mppV4_sbrc_e4_g3 = (mppV4_log_e4_g3 - sbrc_log_e4_g0)/sbrc_log_e4_g0
imp_mppV4_sbrc_e4_g4 = (mppV4_log_e4_g4 - sbrc_log_e4_g0)/sbrc_log_e4_g0

imp_mppV4_prosper_e4_g1 = (mppV4_log_e4_g1 - prosper_log_e4_g1)/prosper_log_e4_g1
imp_mppV4_prosper_e4_g2 = (mppV4_log_e4_g2 - prosper_log_e4_g2)/prosper_log_e4_g2
imp_mppV4_prosper_e4_g3 = (mppV4_log_e4_g3 - prosper_log_e4_g3)/prosper_log_e4_g3
imp_mppV4_prosper_e4_g4 = (mppV4_log_e4_g4 - prosper_log_e4_g4)/prosper_log_e4_g4

imp_mppV4_prscsx_e4_g1 = (mppV4_log_e4_g1 - prscsx_log_e4_g1)/prscsx_log_e4_g1
imp_mppV4_prscsx_e4_g2 = (mppV4_log_e4_g2 - prscsx_log_e4_g2)/prscsx_log_e4_g2
imp_mppV4_prscsx_e4_g3 = (mppV4_log_e4_g3 - prscsx_log_e4_g3)/prscsx_log_e4_g3
imp_mppV4_prscsx_e4_g4 = (mppV4_log_e4_g4 - prscsx_log_e4_g4)/prscsx_log_e4_g4

imp_mppV4_lassosum2_e4_g1 = (mppV4_log_e4_g1 - lassosum2_log_e4_g0)/lassosum2_log_e4_g0
imp_mppV4_lassosum2_e4_g2 = (mppV4_log_e4_g2 - lassosum2_log_e4_g0)/lassosum2_log_e4_g0
imp_mppV4_lassosum2_e4_g3 = (mppV4_log_e4_g3 - lassosum2_log_e4_g0)/lassosum2_log_e4_g0
imp_mppV4_lassosum2_e4_g4 = (mppV4_log_e4_g4 - lassosum2_log_e4_g0)/lassosum2_log_e4_g0

imp_mppV4_lassosumTLD_e4_g1 = (mppV4_log_e4_g1 - lassosumTLD_log_e4_g0)/lassosumTLD_log_e4_g0
imp_mppV4_lassosumTLD_e4_g2 = (mppV4_log_e4_g2 - lassosumTLD_log_e4_g0)/lassosumTLD_log_e4_g0
imp_mppV4_lassosumTLD_e4_g3 = (mppV4_log_e4_g3 - lassosumTLD_log_e4_g0)/lassosumTLD_log_e4_g0
imp_mppV4_lassosumTLD_e4_g4 = (mppV4_log_e4_g4 - lassosumTLD_log_e4_g0)/lassosumTLD_log_e4_g0

imp_mppV4_tlmulti_e4_g1 = (mppV4_log_e4_g1 - tlmulti_log_e4_g1)/tlmulti_log_e4_g1
imp_mppV4_tlmulti_e4_g2 = (mppV4_log_e4_g2 - tlmulti_log_e4_g1)/tlmulti_log_e4_g1
imp_mppV4_tlmulti_e4_g3 = (mppV4_log_e4_g3 - tlmulti_log_e4_g1)/tlmulti_log_e4_g1
imp_mppV4_tlmulti_e4_g4 = (mppV4_log_e4_g4 - tlmulti_log_e4_g1)/tlmulti_log_e4_g1

imp_mppV4_baseline_e4_g1 = (mppV4_log_e4_g1 - baseline_log_e4_g0)/baseline_log_e4_g0
imp_mppV4_baseline_e4_g2 = (mppV4_log_e4_g2 - baseline_log_e4_g0)/baseline_log_e4_g0
imp_mppV4_baseline_e4_g3 = (mppV4_log_e4_g3 - baseline_log_e4_g0)/baseline_log_e4_g0
imp_mppV4_baseline_e4_g4 = (mppV4_log_e4_g4 - baseline_log_e4_g0)/baseline_log_e4_g0

imp_mppV4_sbrcM_e5_g1 = (mppV4_log_e5_g1 - sbrcM_log_e5_g1)/sbrcM_log_e5_g1
imp_mppV4_sbrcM_e5_g2 = (mppV4_log_e5_g2 - sbrcM_log_e5_g2)/sbrcM_log_e5_g2
imp_mppV4_sbrcM_e5_g3 = (mppV4_log_e5_g3 - sbrcM_log_e5_g3)/sbrcM_log_e5_g3
imp_mppV4_sbrcM_e5_g4 = (mppV4_log_e5_g4 - sbrcM_log_e5_g4)/sbrcM_log_e5_g4

imp_mppV4_sbrc_e5_g1 = (mppV4_log_e5_g1 - sbrc_log_e5_g0)/sbrc_log_e5_g0
imp_mppV4_sbrc_e5_g2 = (mppV4_log_e5_g2 - sbrc_log_e5_g0)/sbrc_log_e5_g0
imp_mppV4_sbrc_e5_g3 = (mppV4_log_e5_g3 - sbrc_log_e5_g0)/sbrc_log_e5_g0
imp_mppV4_sbrc_e5_g4 = (mppV4_log_e5_g4 - sbrc_log_e5_g0)/sbrc_log_e5_g0

imp_mppV4_prosper_e5_g1 = (mppV4_log_e5_g1 - prosper_log_e5_g1)/prosper_log_e5_g1
imp_mppV4_prosper_e5_g2 = (mppV4_log_e5_g2 - prosper_log_e5_g2)/prosper_log_e5_g2
imp_mppV4_prosper_e5_g3 = (mppV4_log_e5_g3 - prosper_log_e5_g3)/prosper_log_e5_g3
imp_mppV4_prosper_e5_g4 = (mppV4_log_e5_g4 - prosper_log_e5_g4)/prosper_log_e5_g4

imp_mppV4_prscsx_e5_g1 = (mppV4_log_e5_g1 - prscsx_log_e5_g1)/prscsx_log_e5_g1
imp_mppV4_prscsx_e5_g2 = (mppV4_log_e5_g2 - prscsx_log_e5_g2)/prscsx_log_e5_g2
imp_mppV4_prscsx_e5_g3 = (mppV4_log_e5_g3 - prscsx_log_e5_g3)/prscsx_log_e5_g3
imp_mppV4_prscsx_e5_g4 = (mppV4_log_e5_g4 - prscsx_log_e5_g4)/prscsx_log_e5_g4

imp_mppV4_lassosum2_e5_g1 = (mppV4_log_e5_g1 - lassosum2_log_e5_g0)/lassosum2_log_e5_g0
imp_mppV4_lassosum2_e5_g2 = (mppV4_log_e5_g2 - lassosum2_log_e5_g0)/lassosum2_log_e5_g0
imp_mppV4_lassosum2_e5_g3 = (mppV4_log_e5_g3 - lassosum2_log_e5_g0)/lassosum2_log_e5_g0
imp_mppV4_lassosum2_e5_g4 = (mppV4_log_e5_g4 - lassosum2_log_e5_g0)/lassosum2_log_e5_g0

imp_mppV4_lassosumTLD_e5_g1 = (mppV4_log_e5_g1 - lassosumTLD_log_e5_g0)/lassosumTLD_log_e5_g0
imp_mppV4_lassosumTLD_e5_g2 = (mppV4_log_e5_g2 - lassosumTLD_log_e5_g0)/lassosumTLD_log_e5_g0
imp_mppV4_lassosumTLD_e5_g3 = (mppV4_log_e5_g3 - lassosumTLD_log_e5_g0)/lassosumTLD_log_e5_g0
imp_mppV4_lassosumTLD_e5_g4 = (mppV4_log_e5_g4 - lassosumTLD_log_e5_g0)/lassosumTLD_log_e5_g0

imp_mppV4_tlmulti_e5_g1 = (mppV4_log_e5_g1 - tlmulti_log_e5_g1)/tlmulti_log_e5_g1
imp_mppV4_tlmulti_e5_g2 = (mppV4_log_e5_g2 - tlmulti_log_e5_g1)/tlmulti_log_e5_g1
imp_mppV4_tlmulti_e5_g3 = (mppV4_log_e5_g3 - tlmulti_log_e5_g1)/tlmulti_log_e5_g1
imp_mppV4_tlmulti_e5_g4 = (mppV4_log_e5_g4 - tlmulti_log_e5_g1)/tlmulti_log_e5_g1

imp_mppV4_baseline_e5_g1 = (mppV4_log_e5_g1 - baseline_log_e5_g0)/baseline_log_e5_g0
imp_mppV4_baseline_e5_g2 = (mppV4_log_e5_g2 - baseline_log_e5_g0)/baseline_log_e5_g0
imp_mppV4_baseline_e5_g3 = (mppV4_log_e5_g3 - baseline_log_e5_g0)/baseline_log_e5_g0
imp_mppV4_baseline_e5_g4 = (mppV4_log_e5_g4 - baseline_log_e5_g0)/baseline_log_e5_g0

# %%
imp_mppV1_sbrcM_e2_g1 = (mppV1_log_e2_g1 - sbrcM_log_e2_g1)/sbrcM_log_e2_g1
imp_mppV1_sbrcM_e2_g2 = (mppV1_log_e2_g2 - sbrcM_log_e2_g2)/sbrcM_log_e2_g2
imp_mppV1_sbrcM_e2_g3 = (mppV1_log_e2_g3 - sbrcM_log_e2_g3)/sbrcM_log_e2_g3
imp_mppV1_sbrcM_e2_g4 = (mppV1_log_e2_g4 - sbrcM_log_e2_g4)/sbrcM_log_e2_g4

imp_mppV1_sbrc_e2_g1 = (mppV1_log_e2_g1 - sbrc_log_e2_g0)/sbrc_log_e2_g0
imp_mppV1_sbrc_e2_g2 = (mppV1_log_e2_g2 - sbrc_log_e2_g0)/sbrc_log_e2_g0
imp_mppV1_sbrc_e2_g3 = (mppV1_log_e2_g3 - sbrc_log_e2_g0)/sbrc_log_e2_g0
imp_mppV1_sbrc_e2_g4 = (mppV1_log_e2_g4 - sbrc_log_e2_g0)/sbrc_log_e2_g0

imp_mppV1_prosper_e2_g1 = (mppV1_log_e2_g1 - prosper_log_e2_g1)/prosper_log_e2_g1
imp_mppV1_prosper_e2_g2 = (mppV1_log_e2_g2 - prosper_log_e2_g2)/prosper_log_e2_g2
imp_mppV1_prosper_e2_g3 = (mppV1_log_e2_g3 - prosper_log_e2_g3)/prosper_log_e2_g3
imp_mppV1_prosper_e2_g4 = (mppV1_log_e2_g4 - prosper_log_e2_g4)/prosper_log_e2_g4

imp_mppV1_prscsx_e2_g1 = (mppV1_log_e2_g1 - prscsx_log_e2_g1)/prscsx_log_e2_g1
imp_mppV1_prscsx_e2_g2 = (mppV1_log_e2_g2 - prscsx_log_e2_g2)/prscsx_log_e2_g2
imp_mppV1_prscsx_e2_g3 = (mppV1_log_e2_g3 - prscsx_log_e2_g3)/prscsx_log_e2_g3
imp_mppV1_prscsx_e2_g4 = (mppV1_log_e2_g4 - prscsx_log_e2_g4)/prscsx_log_e2_g4

imp_mppV1_lassosum2_e2_g1 = (mppV1_log_e2_g1 - lassosum2_log_e2_g0)/lassosum2_log_e2_g0
imp_mppV1_lassosum2_e2_g2 = (mppV1_log_e2_g2 - lassosum2_log_e2_g0)/lassosum2_log_e2_g0
imp_mppV1_lassosum2_e2_g3 = (mppV1_log_e2_g3 - lassosum2_log_e2_g0)/lassosum2_log_e2_g0
imp_mppV1_lassosum2_e2_g4 = (mppV1_log_e2_g4 - lassosum2_log_e2_g0)/lassosum2_log_e2_g0

imp_mppV1_lassosumTLD_e2_g1 = (mppV1_log_e2_g1 - lassosumTLD_log_e2_g0)/lassosumTLD_log_e2_g0
imp_mppV1_lassosumTLD_e2_g2 = (mppV1_log_e2_g2 - lassosumTLD_log_e2_g0)/lassosumTLD_log_e2_g0
imp_mppV1_lassosumTLD_e2_g3 = (mppV1_log_e2_g3 - lassosumTLD_log_e2_g0)/lassosumTLD_log_e2_g0
imp_mppV1_lassosumTLD_e2_g4 = (mppV1_log_e2_g4 - lassosumTLD_log_e2_g0)/lassosumTLD_log_e2_g0

imp_mppV1_tlmulti_e2_g1 = (mppV1_log_e2_g1 - tlmulti_log_e2_g1)/tlmulti_log_e2_g1
imp_mppV1_tlmulti_e2_g2 = (mppV1_log_e2_g2 - tlmulti_log_e2_g1)/tlmulti_log_e2_g1
imp_mppV1_tlmulti_e2_g3 = (mppV1_log_e2_g3 - tlmulti_log_e2_g1)/tlmulti_log_e2_g1
imp_mppV1_tlmulti_e2_g4 = (mppV1_log_e2_g4 - tlmulti_log_e2_g1)/tlmulti_log_e2_g1

imp_mppV1_baseline_e2_g1 = (mppV1_log_e2_g1 - baseline_log_e2_g0)/baseline_log_e2_g0
imp_mppV1_baseline_e2_g2 = (mppV1_log_e2_g2 - baseline_log_e2_g0)/baseline_log_e2_g0
imp_mppV1_baseline_e2_g3 = (mppV1_log_e2_g3 - baseline_log_e2_g0)/baseline_log_e2_g0
imp_mppV1_baseline_e2_g4 = (mppV1_log_e2_g4 - baseline_log_e2_g0)/baseline_log_e2_g0

imp_mppV1_sbrcM_e3_g1 = (mppV1_log_e3_g1 - sbrcM_log_e3_g1)/sbrcM_log_e3_g1
imp_mppV1_sbrcM_e3_g2 = (mppV1_log_e3_g2 - sbrcM_log_e3_g2)/sbrcM_log_e3_g2
imp_mppV1_sbrcM_e3_g3 = (mppV1_log_e3_g3 - sbrcM_log_e3_g3)/sbrcM_log_e3_g3
imp_mppV1_sbrcM_e3_g4 = (mppV1_log_e3_g4 - sbrcM_log_e3_g4)/sbrcM_log_e3_g4

imp_mppV1_sbrc_e3_g1 = (mppV1_log_e3_g1 - sbrc_log_e3_g0)/sbrc_log_e3_g0
imp_mppV1_sbrc_e3_g2 = (mppV1_log_e3_g2 - sbrc_log_e3_g0)/sbrc_log_e3_g0
imp_mppV1_sbrc_e3_g3 = (mppV1_log_e3_g3 - sbrc_log_e3_g0)/sbrc_log_e3_g0
imp_mppV1_sbrc_e3_g4 = (mppV1_log_e3_g4 - sbrc_log_e3_g0)/sbrc_log_e3_g0

imp_mppV1_prosper_e3_g1 = (mppV1_log_e3_g1 - prosper_log_e3_g1)/prosper_log_e3_g1
imp_mppV1_prosper_e3_g2 = (mppV1_log_e3_g2 - prosper_log_e3_g2)/prosper_log_e3_g2
imp_mppV1_prosper_e3_g3 = (mppV1_log_e3_g3 - prosper_log_e3_g3)/prosper_log_e3_g3
imp_mppV1_prosper_e3_g4 = (mppV1_log_e3_g4 - prosper_log_e3_g4)/prosper_log_e3_g4

imp_mppV1_prscsx_e3_g1 = (mppV1_log_e3_g1 - prscsx_log_e3_g1)/prscsx_log_e3_g1
imp_mppV1_prscsx_e3_g2 = (mppV1_log_e3_g2 - prscsx_log_e3_g2)/prscsx_log_e3_g2
imp_mppV1_prscsx_e3_g3 = (mppV1_log_e3_g3 - prscsx_log_e3_g3)/prscsx_log_e3_g3
imp_mppV1_prscsx_e3_g4 = (mppV1_log_e3_g4 - prscsx_log_e3_g4)/prscsx_log_e3_g4

imp_mppV1_lassosum2_e3_g1 = (mppV1_log_e3_g1 - lassosum2_log_e3_g0)/lassosum2_log_e3_g0
imp_mppV1_lassosum2_e3_g2 = (mppV1_log_e3_g2 - lassosum2_log_e3_g0)/lassosum2_log_e3_g0
imp_mppV1_lassosum2_e3_g3 = (mppV1_log_e3_g3 - lassosum2_log_e3_g0)/lassosum2_log_e3_g0
imp_mppV1_lassosum2_e3_g4 = (mppV1_log_e3_g4 - lassosum2_log_e3_g0)/lassosum2_log_e3_g0

imp_mppV1_lassosumTLD_e3_g1 = (mppV1_log_e3_g1 - lassosumTLD_log_e3_g0)/lassosumTLD_log_e3_g0
imp_mppV1_lassosumTLD_e3_g2 = (mppV1_log_e3_g2 - lassosumTLD_log_e3_g0)/lassosumTLD_log_e3_g0
imp_mppV1_lassosumTLD_e3_g3 = (mppV1_log_e3_g3 - lassosumTLD_log_e3_g0)/lassosumTLD_log_e3_g0
imp_mppV1_lassosumTLD_e3_g4 = (mppV1_log_e3_g4 - lassosumTLD_log_e3_g0)/lassosumTLD_log_e3_g0

imp_mppV1_tlmulti_e3_g1 = (mppV1_log_e3_g1 - tlmulti_log_e3_g1)/tlmulti_log_e3_g1
imp_mppV1_tlmulti_e3_g2 = (mppV1_log_e3_g2 - tlmulti_log_e3_g1)/tlmulti_log_e3_g1
imp_mppV1_tlmulti_e3_g3 = (mppV1_log_e3_g3 - tlmulti_log_e3_g1)/tlmulti_log_e3_g1
imp_mppV1_tlmulti_e3_g4 = (mppV1_log_e3_g4 - tlmulti_log_e3_g1)/tlmulti_log_e3_g1

imp_mppV1_baseline_e3_g1 = (mppV1_log_e3_g1 - baseline_log_e3_g0)/baseline_log_e3_g0
imp_mppV1_baseline_e3_g2 = (mppV1_log_e3_g2 - baseline_log_e3_g0)/baseline_log_e3_g0
imp_mppV1_baseline_e3_g3 = (mppV1_log_e3_g3 - baseline_log_e3_g0)/baseline_log_e3_g0
imp_mppV1_baseline_e3_g4 = (mppV1_log_e3_g4 - baseline_log_e3_g0)/baseline_log_e3_g0

imp_mppV1_sbrcM_e4_g1 = (mppV1_log_e4_g1 - sbrcM_log_e4_g1)/sbrcM_log_e4_g1
imp_mppV1_sbrcM_e4_g2 = (mppV1_log_e4_g2 - sbrcM_log_e4_g2)/sbrcM_log_e4_g2
imp_mppV1_sbrcM_e4_g3 = (mppV1_log_e4_g3 - sbrcM_log_e4_g3)/sbrcM_log_e4_g3
imp_mppV1_sbrcM_e4_g4 = (mppV1_log_e4_g4 - sbrcM_log_e4_g4)/sbrcM_log_e4_g4

imp_mppV1_sbrc_e4_g1 = (mppV1_log_e4_g1 - sbrc_log_e4_g0)/sbrc_log_e4_g0
imp_mppV1_sbrc_e4_g2 = (mppV1_log_e4_g2 - sbrc_log_e4_g0)/sbrc_log_e4_g0
imp_mppV1_sbrc_e4_g3 = (mppV1_log_e4_g3 - sbrc_log_e4_g0)/sbrc_log_e4_g0
imp_mppV1_sbrc_e4_g4 = (mppV1_log_e4_g4 - sbrc_log_e4_g0)/sbrc_log_e4_g0

imp_mppV1_prosper_e4_g1 = (mppV1_log_e4_g1 - prosper_log_e4_g1)/prosper_log_e4_g1
imp_mppV1_prosper_e4_g2 = (mppV1_log_e4_g2 - prosper_log_e4_g2)/prosper_log_e4_g2
imp_mppV1_prosper_e4_g3 = (mppV1_log_e4_g3 - prosper_log_e4_g3)/prosper_log_e4_g3
imp_mppV1_prosper_e4_g4 = (mppV1_log_e4_g4 - prosper_log_e4_g4)/prosper_log_e4_g4

imp_mppV1_prscsx_e4_g1 = (mppV1_log_e4_g1 - prscsx_log_e4_g1)/prscsx_log_e4_g1
imp_mppV1_prscsx_e4_g2 = (mppV1_log_e4_g2 - prscsx_log_e4_g2)/prscsx_log_e4_g2
imp_mppV1_prscsx_e4_g3 = (mppV1_log_e4_g3 - prscsx_log_e4_g3)/prscsx_log_e4_g3
imp_mppV1_prscsx_e4_g4 = (mppV1_log_e4_g4 - prscsx_log_e4_g4)/prscsx_log_e4_g4

imp_mppV1_lassosum2_e4_g1 = (mppV1_log_e4_g1 - lassosum2_log_e4_g0)/lassosum2_log_e4_g0
imp_mppV1_lassosum2_e4_g2 = (mppV1_log_e4_g2 - lassosum2_log_e4_g0)/lassosum2_log_e4_g0
imp_mppV1_lassosum2_e4_g3 = (mppV1_log_e4_g3 - lassosum2_log_e4_g0)/lassosum2_log_e4_g0
imp_mppV1_lassosum2_e4_g4 = (mppV1_log_e4_g4 - lassosum2_log_e4_g0)/lassosum2_log_e4_g0

imp_mppV1_lassosumTLD_e4_g1 = (mppV1_log_e4_g1 - lassosumTLD_log_e4_g0)/lassosumTLD_log_e4_g0
imp_mppV1_lassosumTLD_e4_g2 = (mppV1_log_e4_g2 - lassosumTLD_log_e4_g0)/lassosumTLD_log_e4_g0
imp_mppV1_lassosumTLD_e4_g3 = (mppV1_log_e4_g3 - lassosumTLD_log_e4_g0)/lassosumTLD_log_e4_g0
imp_mppV1_lassosumTLD_e4_g4 = (mppV1_log_e4_g4 - lassosumTLD_log_e4_g0)/lassosumTLD_log_e4_g0

imp_mppV1_tlmulti_e4_g1 = (mppV1_log_e4_g1 - tlmulti_log_e4_g1)/tlmulti_log_e4_g1
imp_mppV1_tlmulti_e4_g2 = (mppV1_log_e4_g2 - tlmulti_log_e4_g1)/tlmulti_log_e4_g1
imp_mppV1_tlmulti_e4_g3 = (mppV1_log_e4_g3 - tlmulti_log_e4_g1)/tlmulti_log_e4_g1
imp_mppV1_tlmulti_e4_g4 = (mppV1_log_e4_g4 - tlmulti_log_e4_g1)/tlmulti_log_e4_g1

imp_mppV1_baseline_e4_g1 = (mppV1_log_e4_g1 - baseline_log_e4_g0)/baseline_log_e4_g0
imp_mppV1_baseline_e4_g2 = (mppV1_log_e4_g2 - baseline_log_e4_g0)/baseline_log_e4_g0
imp_mppV1_baseline_e4_g3 = (mppV1_log_e4_g3 - baseline_log_e4_g0)/baseline_log_e4_g0
imp_mppV1_baseline_e4_g4 = (mppV1_log_e4_g4 - baseline_log_e4_g0)/baseline_log_e4_g0

imp_mppV1_sbrcM_e5_g1 = (mppV1_log_e5_g1 - sbrcM_log_e5_g1)/sbrcM_log_e5_g1
imp_mppV1_sbrcM_e5_g2 = (mppV1_log_e5_g2 - sbrcM_log_e5_g2)/sbrcM_log_e5_g2
imp_mppV1_sbrcM_e5_g3 = (mppV1_log_e5_g3 - sbrcM_log_e5_g3)/sbrcM_log_e5_g3
imp_mppV1_sbrcM_e5_g4 = (mppV1_log_e5_g4 - sbrcM_log_e5_g4)/sbrcM_log_e5_g4

imp_mppV1_sbrc_e5_g1 = (mppV1_log_e5_g1 - sbrc_log_e5_g0)/sbrc_log_e5_g0
imp_mppV1_sbrc_e5_g2 = (mppV1_log_e5_g2 - sbrc_log_e5_g0)/sbrc_log_e5_g0
imp_mppV1_sbrc_e5_g3 = (mppV1_log_e5_g3 - sbrc_log_e5_g0)/sbrc_log_e5_g0
imp_mppV1_sbrc_e5_g4 = (mppV1_log_e5_g4 - sbrc_log_e5_g0)/sbrc_log_e5_g0

imp_mppV1_prosper_e5_g1 = (mppV1_log_e5_g1 - prosper_log_e5_g1)/prosper_log_e5_g1
imp_mppV1_prosper_e5_g2 = (mppV1_log_e5_g2 - prosper_log_e5_g2)/prosper_log_e5_g2
imp_mppV1_prosper_e5_g3 = (mppV1_log_e5_g3 - prosper_log_e5_g3)/prosper_log_e5_g3
imp_mppV1_prosper_e5_g4 = (mppV1_log_e5_g4 - prosper_log_e5_g4)/prosper_log_e5_g4

imp_mppV1_prscsx_e5_g1 = (mppV1_log_e5_g1 - prscsx_log_e5_g1)/prscsx_log_e5_g1
imp_mppV1_prscsx_e5_g2 = (mppV1_log_e5_g2 - prscsx_log_e5_g2)/prscsx_log_e5_g2
imp_mppV1_prscsx_e5_g3 = (mppV1_log_e5_g3 - prscsx_log_e5_g3)/prscsx_log_e5_g3
imp_mppV1_prscsx_e5_g4 = (mppV1_log_e5_g4 - prscsx_log_e5_g4)/prscsx_log_e5_g4

imp_mppV1_lassosum2_e5_g1 = (mppV1_log_e5_g1 - lassosum2_log_e5_g0)/lassosum2_log_e5_g0
imp_mppV1_lassosum2_e5_g2 = (mppV1_log_e5_g2 - lassosum2_log_e5_g0)/lassosum2_log_e5_g0
imp_mppV1_lassosum2_e5_g3 = (mppV1_log_e5_g3 - lassosum2_log_e5_g0)/lassosum2_log_e5_g0
imp_mppV1_lassosum2_e5_g4 = (mppV1_log_e5_g4 - lassosum2_log_e5_g0)/lassosum2_log_e5_g0

imp_mppV1_lassosumTLD_e5_g1 = (mppV1_log_e5_g1 - lassosumTLD_log_e5_g0)/lassosumTLD_log_e5_g0
imp_mppV1_lassosumTLD_e5_g2 = (mppV1_log_e5_g2 - lassosumTLD_log_e5_g0)/lassosumTLD_log_e5_g0
imp_mppV1_lassosumTLD_e5_g3 = (mppV1_log_e5_g3 - lassosumTLD_log_e5_g0)/lassosumTLD_log_e5_g0
imp_mppV1_lassosumTLD_e5_g4 = (mppV1_log_e5_g4 - lassosumTLD_log_e5_g0)/lassosumTLD_log_e5_g0

imp_mppV1_tlmulti_e5_g1 = (mppV1_log_e5_g1 - tlmulti_log_e5_g1)/tlmulti_log_e5_g1
imp_mppV1_tlmulti_e5_g2 = (mppV1_log_e5_g2 - tlmulti_log_e5_g1)/tlmulti_log_e5_g1
imp_mppV1_tlmulti_e5_g3 = (mppV1_log_e5_g3 - tlmulti_log_e5_g1)/tlmulti_log_e5_g1
imp_mppV1_tlmulti_e5_g4 = (mppV1_log_e5_g4 - tlmulti_log_e5_g1)/tlmulti_log_e5_g1

imp_mppV1_baseline_e5_g1 = (mppV1_log_e5_g1 - baseline_log_e5_g0)/baseline_log_e5_g0
imp_mppV1_baseline_e5_g2 = (mppV1_log_e5_g2 - baseline_log_e5_g0)/baseline_log_e5_g0
imp_mppV1_baseline_e5_g3 = (mppV1_log_e5_g3 - baseline_log_e5_g0)/baseline_log_e5_g0
imp_mppV1_baseline_e5_g4 = (mppV1_log_e5_g4 - baseline_log_e5_g0)/baseline_log_e5_g0

# %%
imp_mppV3_sbrcM_e2_g1 = (mppV3_log_e2_g1 - sbrcM_log_e2_g1)/sbrcM_log_e2_g1
imp_mppV3_sbrcM_e2_g2 = (mppV3_log_e2_g2 - sbrcM_log_e2_g2)/sbrcM_log_e2_g2
imp_mppV3_sbrcM_e2_g3 = (mppV3_log_e2_g3 - sbrcM_log_e2_g3)/sbrcM_log_e2_g3
imp_mppV3_sbrcM_e2_g4 = (mppV3_log_e2_g4 - sbrcM_log_e2_g4)/sbrcM_log_e2_g4

imp_mppV3_sbrc_e2_g1 = (mppV3_log_e2_g1 - sbrc_log_e2_g0)/sbrc_log_e2_g0
imp_mppV3_sbrc_e2_g2 = (mppV3_log_e2_g2 - sbrc_log_e2_g0)/sbrc_log_e2_g0
imp_mppV3_sbrc_e2_g3 = (mppV3_log_e2_g3 - sbrc_log_e2_g0)/sbrc_log_e2_g0
imp_mppV3_sbrc_e2_g4 = (mppV3_log_e2_g4 - sbrc_log_e2_g0)/sbrc_log_e2_g0

imp_mppV3_prosper_e2_g1 = (mppV3_log_e2_g1 - prosper_log_e2_g1)/prosper_log_e2_g1
imp_mppV3_prosper_e2_g2 = (mppV3_log_e2_g2 - prosper_log_e2_g2)/prosper_log_e2_g2
imp_mppV3_prosper_e2_g3 = (mppV3_log_e2_g3 - prosper_log_e2_g3)/prosper_log_e2_g3
imp_mppV3_prosper_e2_g4 = (mppV3_log_e2_g4 - prosper_log_e2_g4)/prosper_log_e2_g4

imp_mppV3_prscsx_e2_g1 = (mppV3_log_e2_g1 - prscsx_log_e2_g1)/prscsx_log_e2_g1
imp_mppV3_prscsx_e2_g2 = (mppV3_log_e2_g2 - prscsx_log_e2_g2)/prscsx_log_e2_g2
imp_mppV3_prscsx_e2_g3 = (mppV3_log_e2_g3 - prscsx_log_e2_g3)/prscsx_log_e2_g3
imp_mppV3_prscsx_e2_g4 = (mppV3_log_e2_g4 - prscsx_log_e2_g4)/prscsx_log_e2_g4

imp_mppV3_lassosum2_e2_g1 = (mppV3_log_e2_g1 - lassosum2_log_e2_g0)/lassosum2_log_e2_g0
imp_mppV3_lassosum2_e2_g2 = (mppV3_log_e2_g2 - lassosum2_log_e2_g0)/lassosum2_log_e2_g0
imp_mppV3_lassosum2_e2_g3 = (mppV3_log_e2_g3 - lassosum2_log_e2_g0)/lassosum2_log_e2_g0
imp_mppV3_lassosum2_e2_g4 = (mppV3_log_e2_g4 - lassosum2_log_e2_g0)/lassosum2_log_e2_g0

imp_mppV3_lassosumTLD_e2_g1 = (mppV3_log_e2_g1 - lassosumTLD_log_e2_g0)/lassosumTLD_log_e2_g0
imp_mppV3_lassosumTLD_e2_g2 = (mppV3_log_e2_g2 - lassosumTLD_log_e2_g0)/lassosumTLD_log_e2_g0
imp_mppV3_lassosumTLD_e2_g3 = (mppV3_log_e2_g3 - lassosumTLD_log_e2_g0)/lassosumTLD_log_e2_g0
imp_mppV3_lassosumTLD_e2_g4 = (mppV3_log_e2_g4 - lassosumTLD_log_e2_g0)/lassosumTLD_log_e2_g0

imp_mppV3_tlmulti_e2_g1 = (mppV3_log_e2_g1 - tlmulti_log_e2_g1)/tlmulti_log_e2_g1
imp_mppV3_tlmulti_e2_g2 = (mppV3_log_e2_g2 - tlmulti_log_e2_g1)/tlmulti_log_e2_g1
imp_mppV3_tlmulti_e2_g3 = (mppV3_log_e2_g3 - tlmulti_log_e2_g1)/tlmulti_log_e2_g1
imp_mppV3_tlmulti_e2_g4 = (mppV3_log_e2_g4 - tlmulti_log_e2_g1)/tlmulti_log_e2_g1

imp_mppV3_baseline_e2_g1 = (mppV3_log_e2_g1 - baseline_log_e2_g0)/baseline_log_e2_g0
imp_mppV3_baseline_e2_g2 = (mppV3_log_e2_g2 - baseline_log_e2_g0)/baseline_log_e2_g0
imp_mppV3_baseline_e2_g3 = (mppV3_log_e2_g3 - baseline_log_e2_g0)/baseline_log_e2_g0
imp_mppV3_baseline_e2_g4 = (mppV3_log_e2_g4 - baseline_log_e2_g0)/baseline_log_e2_g0

imp_mppV3_sbrcM_e3_g1 = (mppV3_log_e3_g1 - sbrcM_log_e3_g1)/sbrcM_log_e3_g1
imp_mppV3_sbrcM_e3_g2 = (mppV3_log_e3_g2 - sbrcM_log_e3_g2)/sbrcM_log_e3_g2
imp_mppV3_sbrcM_e3_g3 = (mppV3_log_e3_g3 - sbrcM_log_e3_g3)/sbrcM_log_e3_g3
imp_mppV3_sbrcM_e3_g4 = (mppV3_log_e3_g4 - sbrcM_log_e3_g4)/sbrcM_log_e3_g4

imp_mppV3_sbrc_e3_g1 = (mppV3_log_e3_g1 - sbrc_log_e3_g0)/sbrc_log_e3_g0
imp_mppV3_sbrc_e3_g2 = (mppV3_log_e3_g2 - sbrc_log_e3_g0)/sbrc_log_e3_g0
imp_mppV3_sbrc_e3_g3 = (mppV3_log_e3_g3 - sbrc_log_e3_g0)/sbrc_log_e3_g0
imp_mppV3_sbrc_e3_g4 = (mppV3_log_e3_g4 - sbrc_log_e3_g0)/sbrc_log_e3_g0

imp_mppV3_prosper_e3_g1 = (mppV3_log_e3_g1 - prosper_log_e3_g1)/prosper_log_e3_g1
imp_mppV3_prosper_e3_g2 = (mppV3_log_e3_g2 - prosper_log_e3_g2)/prosper_log_e3_g2
imp_mppV3_prosper_e3_g3 = (mppV3_log_e3_g3 - prosper_log_e3_g3)/prosper_log_e3_g3
imp_mppV3_prosper_e3_g4 = (mppV3_log_e3_g4 - prosper_log_e3_g4)/prosper_log_e3_g4

imp_mppV3_prscsx_e3_g1 = (mppV3_log_e3_g1 - prscsx_log_e3_g1)/prscsx_log_e3_g1
imp_mppV3_prscsx_e3_g2 = (mppV3_log_e3_g2 - prscsx_log_e3_g2)/prscsx_log_e3_g2
imp_mppV3_prscsx_e3_g3 = (mppV3_log_e3_g3 - prscsx_log_e3_g3)/prscsx_log_e3_g3
imp_mppV3_prscsx_e3_g4 = (mppV3_log_e3_g4 - prscsx_log_e3_g4)/prscsx_log_e3_g4

imp_mppV3_lassosum2_e3_g1 = (mppV3_log_e3_g1 - lassosum2_log_e3_g0)/lassosum2_log_e3_g0
imp_mppV3_lassosum2_e3_g2 = (mppV3_log_e3_g2 - lassosum2_log_e3_g0)/lassosum2_log_e3_g0
imp_mppV3_lassosum2_e3_g3 = (mppV3_log_e3_g3 - lassosum2_log_e3_g0)/lassosum2_log_e3_g0
imp_mppV3_lassosum2_e3_g4 = (mppV3_log_e3_g4 - lassosum2_log_e3_g0)/lassosum2_log_e3_g0

imp_mppV3_lassosumTLD_e3_g1 = (mppV3_log_e3_g1 - lassosumTLD_log_e3_g0)/lassosumTLD_log_e3_g0
imp_mppV3_lassosumTLD_e3_g2 = (mppV3_log_e3_g2 - lassosumTLD_log_e3_g0)/lassosumTLD_log_e3_g0
imp_mppV3_lassosumTLD_e3_g3 = (mppV3_log_e3_g3 - lassosumTLD_log_e3_g0)/lassosumTLD_log_e3_g0
imp_mppV3_lassosumTLD_e3_g4 = (mppV3_log_e3_g4 - lassosumTLD_log_e3_g0)/lassosumTLD_log_e3_g0

imp_mppV3_tlmulti_e3_g1 = (mppV3_log_e3_g1 - tlmulti_log_e3_g1)/tlmulti_log_e3_g1
imp_mppV3_tlmulti_e3_g2 = (mppV3_log_e3_g2 - tlmulti_log_e3_g1)/tlmulti_log_e3_g1
imp_mppV3_tlmulti_e3_g3 = (mppV3_log_e3_g3 - tlmulti_log_e3_g1)/tlmulti_log_e3_g1
imp_mppV3_tlmulti_e3_g4 = (mppV3_log_e3_g4 - tlmulti_log_e3_g1)/tlmulti_log_e3_g1

imp_mppV3_baseline_e3_g1 = (mppV3_log_e3_g1 - baseline_log_e3_g0)/baseline_log_e3_g0
imp_mppV3_baseline_e3_g2 = (mppV3_log_e3_g2 - baseline_log_e3_g0)/baseline_log_e3_g0
imp_mppV3_baseline_e3_g3 = (mppV3_log_e3_g3 - baseline_log_e3_g0)/baseline_log_e3_g0
imp_mppV3_baseline_e3_g4 = (mppV3_log_e3_g4 - baseline_log_e3_g0)/baseline_log_e3_g0

imp_mppV3_sbrcM_e4_g1 = (mppV3_log_e4_g1 - sbrcM_log_e4_g1)/sbrcM_log_e4_g1
imp_mppV3_sbrcM_e4_g2 = (mppV3_log_e4_g2 - sbrcM_log_e4_g2)/sbrcM_log_e4_g2
imp_mppV3_sbrcM_e4_g3 = (mppV3_log_e4_g3 - sbrcM_log_e4_g3)/sbrcM_log_e4_g3
imp_mppV3_sbrcM_e4_g4 = (mppV3_log_e4_g4 - sbrcM_log_e4_g4)/sbrcM_log_e4_g4

imp_mppV3_sbrc_e4_g1 = (mppV3_log_e4_g1 - sbrc_log_e4_g0)/sbrc_log_e4_g0
imp_mppV3_sbrc_e4_g2 = (mppV3_log_e4_g2 - sbrc_log_e4_g0)/sbrc_log_e4_g0
imp_mppV3_sbrc_e4_g3 = (mppV3_log_e4_g3 - sbrc_log_e4_g0)/sbrc_log_e4_g0
imp_mppV3_sbrc_e4_g4 = (mppV3_log_e4_g4 - sbrc_log_e4_g0)/sbrc_log_e4_g0

imp_mppV3_prosper_e4_g1 = (mppV3_log_e4_g1 - prosper_log_e4_g1)/prosper_log_e4_g1
imp_mppV3_prosper_e4_g2 = (mppV3_log_e4_g2 - prosper_log_e4_g2)/prosper_log_e4_g2
imp_mppV3_prosper_e4_g3 = (mppV3_log_e4_g3 - prosper_log_e4_g3)/prosper_log_e4_g3
imp_mppV3_prosper_e4_g4 = (mppV3_log_e4_g4 - prosper_log_e4_g4)/prosper_log_e4_g4

imp_mppV3_prscsx_e4_g1 = (mppV3_log_e4_g1 - prscsx_log_e4_g1)/prscsx_log_e4_g1
imp_mppV3_prscsx_e4_g2 = (mppV3_log_e4_g2 - prscsx_log_e4_g2)/prscsx_log_e4_g2
imp_mppV3_prscsx_e4_g3 = (mppV3_log_e4_g3 - prscsx_log_e4_g3)/prscsx_log_e4_g3
imp_mppV3_prscsx_e4_g4 = (mppV3_log_e4_g4 - prscsx_log_e4_g4)/prscsx_log_e4_g4

imp_mppV3_lassosum2_e4_g1 = (mppV3_log_e4_g1 - lassosum2_log_e4_g0)/lassosum2_log_e4_g0
imp_mppV3_lassosum2_e4_g2 = (mppV3_log_e4_g2 - lassosum2_log_e4_g0)/lassosum2_log_e4_g0
imp_mppV3_lassosum2_e4_g3 = (mppV3_log_e4_g3 - lassosum2_log_e4_g0)/lassosum2_log_e4_g0
imp_mppV3_lassosum2_e4_g4 = (mppV3_log_e4_g4 - lassosum2_log_e4_g0)/lassosum2_log_e4_g0

imp_mppV3_lassosumTLD_e4_g1 = (mppV3_log_e4_g1 - lassosumTLD_log_e4_g0)/lassosumTLD_log_e4_g0
imp_mppV3_lassosumTLD_e4_g2 = (mppV3_log_e4_g2 - lassosumTLD_log_e4_g0)/lassosumTLD_log_e4_g0
imp_mppV3_lassosumTLD_e4_g3 = (mppV3_log_e4_g3 - lassosumTLD_log_e4_g0)/lassosumTLD_log_e4_g0
imp_mppV3_lassosumTLD_e4_g4 = (mppV3_log_e4_g4 - lassosumTLD_log_e4_g0)/lassosumTLD_log_e4_g0

imp_mppV3_tlmulti_e4_g1 = (mppV3_log_e4_g1 - tlmulti_log_e4_g1)/tlmulti_log_e4_g1
imp_mppV3_tlmulti_e4_g2 = (mppV3_log_e4_g2 - tlmulti_log_e4_g1)/tlmulti_log_e4_g1
imp_mppV3_tlmulti_e4_g3 = (mppV3_log_e4_g3 - tlmulti_log_e4_g1)/tlmulti_log_e4_g1
imp_mppV3_tlmulti_e4_g4 = (mppV3_log_e4_g4 - tlmulti_log_e4_g1)/tlmulti_log_e4_g1

imp_mppV3_baseline_e4_g1 = (mppV3_log_e4_g1 - baseline_log_e4_g0)/baseline_log_e4_g0
imp_mppV3_baseline_e4_g2 = (mppV3_log_e4_g2 - baseline_log_e4_g0)/baseline_log_e4_g0
imp_mppV3_baseline_e4_g3 = (mppV3_log_e4_g3 - baseline_log_e4_g0)/baseline_log_e4_g0
imp_mppV3_baseline_e4_g4 = (mppV3_log_e4_g4 - baseline_log_e4_g0)/baseline_log_e4_g0

imp_mppV3_sbrcM_e5_g1 = (mppV3_log_e5_g1 - sbrcM_log_e5_g1)/sbrcM_log_e5_g1
imp_mppV3_sbrcM_e5_g2 = (mppV3_log_e5_g2 - sbrcM_log_e5_g2)/sbrcM_log_e5_g2
imp_mppV3_sbrcM_e5_g3 = (mppV3_log_e5_g3 - sbrcM_log_e5_g3)/sbrcM_log_e5_g3
imp_mppV3_sbrcM_e5_g4 = (mppV3_log_e5_g4 - sbrcM_log_e5_g4)/sbrcM_log_e5_g4

imp_mppV3_sbrc_e5_g1 = (mppV3_log_e5_g1 - sbrc_log_e5_g0)/sbrc_log_e5_g0
imp_mppV3_sbrc_e5_g2 = (mppV3_log_e5_g2 - sbrc_log_e5_g0)/sbrc_log_e5_g0
imp_mppV3_sbrc_e5_g3 = (mppV3_log_e5_g3 - sbrc_log_e5_g0)/sbrc_log_e5_g0
imp_mppV3_sbrc_e5_g4 = (mppV3_log_e5_g4 - sbrc_log_e5_g0)/sbrc_log_e5_g0

imp_mppV3_prosper_e5_g1 = (mppV3_log_e5_g1 - prosper_log_e5_g1)/prosper_log_e5_g1
imp_mppV3_prosper_e5_g2 = (mppV3_log_e5_g2 - prosper_log_e5_g2)/prosper_log_e5_g2
imp_mppV3_prosper_e5_g3 = (mppV3_log_e5_g3 - prosper_log_e5_g3)/prosper_log_e5_g3
imp_mppV3_prosper_e5_g4 = (mppV3_log_e5_g4 - prosper_log_e5_g4)/prosper_log_e5_g4

imp_mppV3_prscsx_e5_g1 = (mppV3_log_e5_g1 - prscsx_log_e5_g1)/prscsx_log_e5_g1
imp_mppV3_prscsx_e5_g2 = (mppV3_log_e5_g2 - prscsx_log_e5_g2)/prscsx_log_e5_g2
imp_mppV3_prscsx_e5_g3 = (mppV3_log_e5_g3 - prscsx_log_e5_g3)/prscsx_log_e5_g3
imp_mppV3_prscsx_e5_g4 = (mppV3_log_e5_g4 - prscsx_log_e5_g4)/prscsx_log_e5_g4

imp_mppV3_lassosum2_e5_g1 = (mppV3_log_e5_g1 - lassosum2_log_e5_g0)/lassosum2_log_e5_g0
imp_mppV3_lassosum2_e5_g2 = (mppV3_log_e5_g2 - lassosum2_log_e5_g0)/lassosum2_log_e5_g0
imp_mppV3_lassosum2_e5_g3 = (mppV3_log_e5_g3 - lassosum2_log_e5_g0)/lassosum2_log_e5_g0
imp_mppV3_lassosum2_e5_g4 = (mppV3_log_e5_g4 - lassosum2_log_e5_g0)/lassosum2_log_e5_g0

imp_mppV3_lassosumTLD_e5_g1 = (mppV3_log_e5_g1 - lassosumTLD_log_e5_g0)/lassosumTLD_log_e5_g0
imp_mppV3_lassosumTLD_e5_g2 = (mppV3_log_e5_g2 - lassosumTLD_log_e5_g0)/lassosumTLD_log_e5_g0
imp_mppV3_lassosumTLD_e5_g3 = (mppV3_log_e5_g3 - lassosumTLD_log_e5_g0)/lassosumTLD_log_e5_g0
imp_mppV3_lassosumTLD_e5_g4 = (mppV3_log_e5_g4 - lassosumTLD_log_e5_g0)/lassosumTLD_log_e5_g0

imp_mppV3_tlmulti_e5_g1 = (mppV3_log_e5_g1 - tlmulti_log_e5_g1)/tlmulti_log_e5_g1
imp_mppV3_tlmulti_e5_g2 = (mppV3_log_e5_g2 - tlmulti_log_e5_g1)/tlmulti_log_e5_g1
imp_mppV3_tlmulti_e5_g3 = (mppV3_log_e5_g3 - tlmulti_log_e5_g1)/tlmulti_log_e5_g1
imp_mppV3_tlmulti_e5_g4 = (mppV3_log_e5_g4 - tlmulti_log_e5_g1)/tlmulti_log_e5_g1

imp_mppV3_baseline_e5_g1 = (mppV3_log_e5_g1 - baseline_log_e5_g0)/baseline_log_e5_g0
imp_mppV3_baseline_e5_g2 = (mppV3_log_e5_g2 - baseline_log_e5_g0)/baseline_log_e5_g0
imp_mppV3_baseline_e5_g3 = (mppV3_log_e5_g3 - baseline_log_e5_g0)/baseline_log_e5_g0
imp_mppV3_baseline_e5_g4 = (mppV3_log_e5_g4 - baseline_log_e5_g0)/baseline_log_e5_g0

# %%
imp_mppV4B_sbrcM_all = np.mean(np.concatenate((imp_mppV4B_sbrcM_e1_g1, imp_mppV4B_sbrcM_e1_g2, imp_mppV4B_sbrcM_e1_g3, imp_mppV4B_sbrcM_e1_g4,\
                                               imp_mppV4B_sbrcM_e2_g1, imp_mppV4B_sbrcM_e2_g2, imp_mppV4B_sbrcM_e2_g3, imp_mppV4B_sbrcM_e2_g4,\
                                               imp_mppV4B_sbrcM_e3_g1, imp_mppV4B_sbrcM_e3_g2, imp_mppV4B_sbrcM_e3_g3, imp_mppV4B_sbrcM_e3_g4,\
                                               imp_mppV4B_sbrcM_e4_g1, imp_mppV4B_sbrcM_e4_g2, imp_mppV4B_sbrcM_e4_g3, imp_mppV4B_sbrcM_e4_g4,\
                                               imp_mppV4B_sbrcM_e5_g1, imp_mppV4B_sbrcM_e5_g2, imp_mppV4B_sbrcM_e5_g3, imp_mppV4B_sbrcM_e5_g4)))

imp_mppV4B_sbrc_all = np.mean(np.concatenate((imp_mppV4B_sbrc_e1_g1, imp_mppV4B_sbrc_e1_g2, imp_mppV4B_sbrc_e1_g3, imp_mppV4B_sbrc_e1_g4,\
                                               imp_mppV4B_sbrc_e2_g1, imp_mppV4B_sbrc_e2_g2, imp_mppV4B_sbrc_e2_g3, imp_mppV4B_sbrc_e2_g4,\
                                               imp_mppV4B_sbrc_e3_g1, imp_mppV4B_sbrc_e3_g2, imp_mppV4B_sbrc_e3_g3, imp_mppV4B_sbrc_e3_g4,\
                                               imp_mppV4B_sbrc_e4_g1, imp_mppV4B_sbrc_e4_g2, imp_mppV4B_sbrc_e4_g3, imp_mppV4B_sbrc_e4_g4,\
                                               imp_mppV4B_sbrc_e5_g1, imp_mppV4B_sbrc_e5_g2, imp_mppV4B_sbrc_e5_g3, imp_mppV4B_sbrc_e5_g4)))

imp_mppV4B_prosper_all = np.mean(np.concatenate((imp_mppV4B_prosper_e1_g1, imp_mppV4B_prosper_e1_g2, imp_mppV4B_prosper_e1_g3, imp_mppV4B_prosper_e1_g4,\
                                               imp_mppV4B_prosper_e2_g1, imp_mppV4B_prosper_e2_g2, imp_mppV4B_prosper_e2_g3, imp_mppV4B_prosper_e2_g4,\
                                               imp_mppV4B_prosper_e3_g1, imp_mppV4B_prosper_e3_g2, imp_mppV4B_prosper_e3_g3, imp_mppV4B_prosper_e3_g4,\
                                               imp_mppV4B_prosper_e4_g1, imp_mppV4B_prosper_e4_g2, imp_mppV4B_prosper_e4_g3, imp_mppV4B_prosper_e4_g4,\
                                               imp_mppV4B_prosper_e5_g1, imp_mppV4B_prosper_e5_g2, imp_mppV4B_prosper_e5_g3, imp_mppV4B_prosper_e5_g4)))

imp_mppV4B_prscsx_all = np.mean(np.concatenate((imp_mppV4B_prscsx_e1_g1, imp_mppV4B_prscsx_e1_g2, imp_mppV4B_prscsx_e1_g3, imp_mppV4B_prscsx_e1_g4,\
                                               imp_mppV4B_prscsx_e2_g1, imp_mppV4B_prscsx_e2_g2, imp_mppV4B_prscsx_e2_g3, imp_mppV4B_prscsx_e2_g4,\
                                               imp_mppV4B_prscsx_e3_g1, imp_mppV4B_prscsx_e3_g2, imp_mppV4B_prscsx_e3_g3, imp_mppV4B_prscsx_e3_g4,\
                                               imp_mppV4B_prscsx_e4_g1, imp_mppV4B_prscsx_e4_g2, imp_mppV4B_prscsx_e4_g3, imp_mppV4B_prscsx_e4_g4,\
                                               imp_mppV4B_prscsx_e5_g1, imp_mppV4B_prscsx_e5_g2, imp_mppV4B_prscsx_e5_g3, imp_mppV4B_prscsx_e5_g4)))

imp_mppV4B_tlmulti_all = np.mean(np.concatenate((imp_mppV4B_tlmulti_e1_g1, imp_mppV4B_tlmulti_e1_g2, imp_mppV4B_tlmulti_e1_g3, imp_mppV4B_tlmulti_e1_g4,\
                                               imp_mppV4B_tlmulti_e2_g1, imp_mppV4B_tlmulti_e2_g2, imp_mppV4B_tlmulti_e2_g3, imp_mppV4B_tlmulti_e2_g4,\
                                               imp_mppV4B_tlmulti_e3_g1, imp_mppV4B_tlmulti_e3_g2, imp_mppV4B_tlmulti_e3_g3, imp_mppV4B_tlmulti_e3_g4,\
                                               imp_mppV4B_tlmulti_e4_g1, imp_mppV4B_tlmulti_e4_g2, imp_mppV4B_tlmulti_e4_g3, imp_mppV4B_tlmulti_e4_g4,\
                                               imp_mppV4B_tlmulti_e5_g1, imp_mppV4B_tlmulti_e5_g2, imp_mppV4B_tlmulti_e5_g3, imp_mppV4B_tlmulti_e5_g4)))

imp_mppV4B_lassosum2_all = np.mean(np.concatenate((imp_mppV4B_lassosum2_e1_g1, imp_mppV4B_lassosum2_e1_g2, imp_mppV4B_lassosum2_e1_g3, imp_mppV4B_lassosum2_e1_g4,\
                                               imp_mppV4B_lassosum2_e2_g1, imp_mppV4B_lassosum2_e2_g2, imp_mppV4B_lassosum2_e2_g3, imp_mppV4B_lassosum2_e2_g4,\
                                               imp_mppV4B_lassosum2_e3_g1, imp_mppV4B_lassosum2_e3_g2, imp_mppV4B_lassosum2_e3_g3, imp_mppV4B_lassosum2_e3_g4,\
                                               imp_mppV4B_lassosum2_e4_g1, imp_mppV4B_lassosum2_e4_g2, imp_mppV4B_lassosum2_e4_g3, imp_mppV4B_lassosum2_e4_g4,\
                                               imp_mppV4B_lassosum2_e5_g1, imp_mppV4B_lassosum2_e5_g2, imp_mppV4B_lassosum2_e5_g3, imp_mppV4B_lassosum2_e5_g4)))

imp_mppV4B_lassosumTLD_all = np.mean(np.concatenate((imp_mppV4B_lassosumTLD_e1_g1, imp_mppV4B_lassosumTLD_e1_g2, imp_mppV4B_lassosumTLD_e1_g3, imp_mppV4B_lassosumTLD_e1_g4,\
                                               imp_mppV4B_lassosumTLD_e2_g1, imp_mppV4B_lassosumTLD_e2_g2, imp_mppV4B_lassosumTLD_e2_g3, imp_mppV4B_lassosumTLD_e2_g4,\
                                               imp_mppV4B_lassosumTLD_e3_g1, imp_mppV4B_lassosumTLD_e3_g2, imp_mppV4B_lassosumTLD_e3_g3, imp_mppV4B_lassosumTLD_e3_g4,\
                                               imp_mppV4B_lassosumTLD_e4_g1, imp_mppV4B_lassosumTLD_e4_g2, imp_mppV4B_lassosumTLD_e4_g3, imp_mppV4B_lassosumTLD_e4_g4,\
                                               imp_mppV4B_lassosumTLD_e5_g1, imp_mppV4B_lassosumTLD_e5_g2, imp_mppV4B_lassosumTLD_e5_g3, imp_mppV4B_lassosumTLD_e5_g4)))

imp_mppV4B_baseline_all = np.mean(np.concatenate((imp_mppV4B_baseline_e1_g1, imp_mppV4B_baseline_e1_g2, imp_mppV4B_baseline_e1_g3, imp_mppV4B_baseline_e1_g4,\
                                               imp_mppV4B_baseline_e2_g1, imp_mppV4B_baseline_e2_g2, imp_mppV4B_baseline_e2_g3, imp_mppV4B_baseline_e2_g4,\
                                               imp_mppV4B_baseline_e3_g1, imp_mppV4B_baseline_e3_g2, imp_mppV4B_baseline_e3_g3, imp_mppV4B_baseline_e3_g4,\
                                               imp_mppV4B_baseline_e4_g1, imp_mppV4B_baseline_e4_g2, imp_mppV4B_baseline_e4_g3, imp_mppV4B_baseline_e4_g4,\
                                               imp_mppV4B_baseline_e5_g1, imp_mppV4B_baseline_e5_g2, imp_mppV4B_baseline_e5_g3, imp_mppV4B_baseline_e5_g4)))

print("mppV4B vs. sbrcM "+str(imp_mppV4B_sbrcM_all*100))
print("mppV4B vs. sbrc "+str(imp_mppV4B_sbrc_all*100))
print("mppV4B vs. prosper "+str(imp_mppV4B_prosper_all*100))
print("mppV4B vs. prscsx "+str(imp_mppV4B_prscsx_all*100))
print("mppV4B vs. tlmulti "+str(imp_mppV4B_tlmulti_all*100))
print("mppV4B vs. lassosum2 "+str(imp_mppV4B_lassosum2_all*100))
print("mppV4B vs. lassosumTLD "+str(imp_mppV4B_lassosumTLD_all*100))
print("mppV4B vs. baseline "+str(imp_mppV4B_baseline_all*100))
# Out:
# mppV4B vs. sbrcM 33.00513114298752
# mppV4B vs. sbrc 52.92791136688915
# mppV4B vs. prosper 29.828497632292844
# mppV4B vs. prscsx 56.693020869334084
# mppV4B vs. tlmulti 81.54817107700129
# mppV4B vs. lassosum2 45.24767583009905
# mppV4B vs. lassosumTLD 7.8919268506168025
# mppV4B vs. baseline 38.79066415820043

# %%
imp_mppV4_sbrcM_all = np.mean(np.concatenate((imp_mppV4_sbrcM_e1_g1, imp_mppV4_sbrcM_e1_g2, imp_mppV4_sbrcM_e1_g3, imp_mppV4_sbrcM_e1_g4,\
                                               imp_mppV4_sbrcM_e2_g1, imp_mppV4_sbrcM_e2_g2, imp_mppV4_sbrcM_e2_g3, imp_mppV4_sbrcM_e2_g4,\
                                               imp_mppV4_sbrcM_e3_g1, imp_mppV4_sbrcM_e3_g2, imp_mppV4_sbrcM_e3_g3, imp_mppV4_sbrcM_e3_g4,\
                                               imp_mppV4_sbrcM_e4_g1, imp_mppV4_sbrcM_e4_g2, imp_mppV4_sbrcM_e4_g3, imp_mppV4_sbrcM_e4_g4,\
                                               imp_mppV4_sbrcM_e5_g1, imp_mppV4_sbrcM_e5_g2, imp_mppV4_sbrcM_e5_g3, imp_mppV4_sbrcM_e5_g4)))

imp_mppV4_sbrc_all = np.mean(np.concatenate((imp_mppV4_sbrc_e1_g1, imp_mppV4_sbrc_e1_g2, imp_mppV4_sbrc_e1_g3, imp_mppV4_sbrc_e1_g4,\
                                               imp_mppV4_sbrc_e2_g1, imp_mppV4_sbrc_e2_g2, imp_mppV4_sbrc_e2_g3, imp_mppV4_sbrc_e2_g4,\
                                               imp_mppV4_sbrc_e3_g1, imp_mppV4_sbrc_e3_g2, imp_mppV4_sbrc_e3_g3, imp_mppV4_sbrc_e3_g4,\
                                               imp_mppV4_sbrc_e4_g1, imp_mppV4_sbrc_e4_g2, imp_mppV4_sbrc_e4_g3, imp_mppV4_sbrc_e4_g4,\
                                               imp_mppV4_sbrc_e5_g1, imp_mppV4_sbrc_e5_g2, imp_mppV4_sbrc_e5_g3, imp_mppV4_sbrc_e5_g4)))

imp_mppV4_prosper_all = np.mean(np.concatenate((imp_mppV4_prosper_e1_g1, imp_mppV4_prosper_e1_g2, imp_mppV4_prosper_e1_g3, imp_mppV4_prosper_e1_g4,\
                                               imp_mppV4_prosper_e2_g1, imp_mppV4_prosper_e2_g2, imp_mppV4_prosper_e2_g3, imp_mppV4_prosper_e2_g4,\
                                               imp_mppV4_prosper_e3_g1, imp_mppV4_prosper_e3_g2, imp_mppV4_prosper_e3_g3, imp_mppV4_prosper_e3_g4,\
                                               imp_mppV4_prosper_e4_g1, imp_mppV4_prosper_e4_g2, imp_mppV4_prosper_e4_g3, imp_mppV4_prosper_e4_g4,\
                                               imp_mppV4_prosper_e5_g1, imp_mppV4_prosper_e5_g2, imp_mppV4_prosper_e5_g3, imp_mppV4_prosper_e5_g4)))

imp_mppV4_prscsx_all = np.mean(np.concatenate((imp_mppV4_prscsx_e1_g1, imp_mppV4_prscsx_e1_g2, imp_mppV4_prscsx_e1_g3, imp_mppV4_prscsx_e1_g4,\
                                               imp_mppV4_prscsx_e2_g1, imp_mppV4_prscsx_e2_g2, imp_mppV4_prscsx_e2_g3, imp_mppV4_prscsx_e2_g4,\
                                               imp_mppV4_prscsx_e3_g1, imp_mppV4_prscsx_e3_g2, imp_mppV4_prscsx_e3_g3, imp_mppV4_prscsx_e3_g4,\
                                               imp_mppV4_prscsx_e4_g1, imp_mppV4_prscsx_e4_g2, imp_mppV4_prscsx_e4_g3, imp_mppV4_prscsx_e4_g4,\
                                               imp_mppV4_prscsx_e5_g1, imp_mppV4_prscsx_e5_g2, imp_mppV4_prscsx_e5_g3, imp_mppV4_prscsx_e5_g4)))

imp_mppV4_tlmulti_all = np.mean(np.concatenate((imp_mppV4_tlmulti_e1_g1, imp_mppV4_tlmulti_e1_g2, imp_mppV4_tlmulti_e1_g3, imp_mppV4_tlmulti_e1_g4,\
                                               imp_mppV4_tlmulti_e2_g1, imp_mppV4_tlmulti_e2_g2, imp_mppV4_tlmulti_e2_g3, imp_mppV4_tlmulti_e2_g4,\
                                               imp_mppV4_tlmulti_e3_g1, imp_mppV4_tlmulti_e3_g2, imp_mppV4_tlmulti_e3_g3, imp_mppV4_tlmulti_e3_g4,\
                                               imp_mppV4_tlmulti_e4_g1, imp_mppV4_tlmulti_e4_g2, imp_mppV4_tlmulti_e4_g3, imp_mppV4_tlmulti_e4_g4,\
                                               imp_mppV4_tlmulti_e5_g1, imp_mppV4_tlmulti_e5_g2, imp_mppV4_tlmulti_e5_g3, imp_mppV4_tlmulti_e5_g4)))

imp_mppV4_lassosum2_all = np.mean(np.concatenate((imp_mppV4_lassosum2_e1_g1, imp_mppV4_lassosum2_e1_g2, imp_mppV4_lassosum2_e1_g3, imp_mppV4_lassosum2_e1_g4,\
                                               imp_mppV4_lassosum2_e2_g1, imp_mppV4_lassosum2_e2_g2, imp_mppV4_lassosum2_e2_g3, imp_mppV4_lassosum2_e2_g4,\
                                               imp_mppV4_lassosum2_e3_g1, imp_mppV4_lassosum2_e3_g2, imp_mppV4_lassosum2_e3_g3, imp_mppV4_lassosum2_e3_g4,\
                                               imp_mppV4_lassosum2_e4_g1, imp_mppV4_lassosum2_e4_g2, imp_mppV4_lassosum2_e4_g3, imp_mppV4_lassosum2_e4_g4,\
                                               imp_mppV4_lassosum2_e5_g1, imp_mppV4_lassosum2_e5_g2, imp_mppV4_lassosum2_e5_g3, imp_mppV4_lassosum2_e5_g4)))

imp_mppV4_lassosumTLD_all = np.mean(np.concatenate((imp_mppV4_lassosumTLD_e1_g1, imp_mppV4_lassosumTLD_e1_g2, imp_mppV4_lassosumTLD_e1_g3, imp_mppV4_lassosumTLD_e1_g4,\
                                               imp_mppV4_lassosumTLD_e2_g1, imp_mppV4_lassosumTLD_e2_g2, imp_mppV4_lassosumTLD_e2_g3, imp_mppV4_lassosumTLD_e2_g4,\
                                               imp_mppV4_lassosumTLD_e3_g1, imp_mppV4_lassosumTLD_e3_g2, imp_mppV4_lassosumTLD_e3_g3, imp_mppV4_lassosumTLD_e3_g4,\
                                               imp_mppV4_lassosumTLD_e4_g1, imp_mppV4_lassosumTLD_e4_g2, imp_mppV4_lassosumTLD_e4_g3, imp_mppV4_lassosumTLD_e4_g4,\
                                               imp_mppV4_lassosumTLD_e5_g1, imp_mppV4_lassosumTLD_e5_g2, imp_mppV4_lassosumTLD_e5_g3, imp_mppV4_lassosumTLD_e5_g4)))

imp_mppV4_baseline_all = np.mean(np.concatenate((imp_mppV4_baseline_e1_g1, imp_mppV4_baseline_e1_g2, imp_mppV4_baseline_e1_g3, imp_mppV4_baseline_e1_g4,\
                                               imp_mppV4_baseline_e2_g1, imp_mppV4_baseline_e2_g2, imp_mppV4_baseline_e2_g3, imp_mppV4_baseline_e2_g4,\
                                               imp_mppV4_baseline_e3_g1, imp_mppV4_baseline_e3_g2, imp_mppV4_baseline_e3_g3, imp_mppV4_baseline_e3_g4,\
                                               imp_mppV4_baseline_e4_g1, imp_mppV4_baseline_e4_g2, imp_mppV4_baseline_e4_g3, imp_mppV4_baseline_e4_g4,\
                                               imp_mppV4_baseline_e5_g1, imp_mppV4_baseline_e5_g2, imp_mppV4_baseline_e5_g3, imp_mppV4_baseline_e5_g4)))

print("mppV4 vs. sbrcM "+str(imp_mppV4_sbrcM_all*100))
print("mppV4 vs. sbrc "+str(imp_mppV4_sbrc_all*100))
print("mppV4 vs. prosper "+str(imp_mppV4_prosper_all*100))
print("mppV4 vs. prscsx "+str(imp_mppV4_prscsx_all*100))
print("mppV4 vs. tlmulti "+str(imp_mppV4_tlmulti_all*100))
print("mppV4 vs. lassosum2 "+str(imp_mppV4_lassosum2_all*100))
print("mppV4 vs. lassosumTLD "+str(imp_mppV4_lassosumTLD_all*100))
print("mppV4 vs. baseline "+str(imp_mppV4_baseline_all*100))
# Out:
# mppV4 vs. sbrcM 11.064761711744017
# mppV4 vs. sbrc 25.10350003488262
# mppV4 vs. prosper 7.389417281913061
# mppV4 vs. prscsx 29.79125688305229
# mppV4 vs. tlmulti 51.923612503983726
# mppV4 vs. lassosum2 19.667584902521245
# mppV4 vs. lassosumTLD -10.253735686988156
# mppV4 vs. baseline 14.904590898818668

# %%
imp_mppV1_sbrcM_all = np.mean(np.concatenate((imp_mppV1_sbrcM_e1_g1, imp_mppV1_sbrcM_e1_g2, imp_mppV1_sbrcM_e1_g3, imp_mppV1_sbrcM_e1_g4,\
                                               imp_mppV1_sbrcM_e2_g1, imp_mppV1_sbrcM_e2_g2, imp_mppV1_sbrcM_e2_g3, imp_mppV1_sbrcM_e2_g4,\
                                               imp_mppV1_sbrcM_e3_g1, imp_mppV1_sbrcM_e3_g2, imp_mppV1_sbrcM_e3_g3, imp_mppV1_sbrcM_e3_g4,\
                                               imp_mppV1_sbrcM_e4_g1, imp_mppV1_sbrcM_e4_g2, imp_mppV1_sbrcM_e4_g3, imp_mppV1_sbrcM_e4_g4,\
                                               imp_mppV1_sbrcM_e5_g1, imp_mppV1_sbrcM_e5_g2, imp_mppV1_sbrcM_e5_g3, imp_mppV1_sbrcM_e5_g4)))

imp_mppV1_sbrc_all = np.mean(np.concatenate((imp_mppV1_sbrc_e1_g1, imp_mppV1_sbrc_e1_g2, imp_mppV1_sbrc_e1_g3, imp_mppV1_sbrc_e1_g4,\
                                               imp_mppV1_sbrc_e2_g1, imp_mppV1_sbrc_e2_g2, imp_mppV1_sbrc_e2_g3, imp_mppV1_sbrc_e2_g4,\
                                               imp_mppV1_sbrc_e3_g1, imp_mppV1_sbrc_e3_g2, imp_mppV1_sbrc_e3_g3, imp_mppV1_sbrc_e3_g4,\
                                               imp_mppV1_sbrc_e4_g1, imp_mppV1_sbrc_e4_g2, imp_mppV1_sbrc_e4_g3, imp_mppV1_sbrc_e4_g4,\
                                               imp_mppV1_sbrc_e5_g1, imp_mppV1_sbrc_e5_g2, imp_mppV1_sbrc_e5_g3, imp_mppV1_sbrc_e5_g4)))

imp_mppV1_prosper_all = np.mean(np.concatenate((imp_mppV1_prosper_e1_g1, imp_mppV1_prosper_e1_g2, imp_mppV1_prosper_e1_g3, imp_mppV1_prosper_e1_g4,\
                                               imp_mppV1_prosper_e2_g1, imp_mppV1_prosper_e2_g2, imp_mppV1_prosper_e2_g3, imp_mppV1_prosper_e2_g4,\
                                               imp_mppV1_prosper_e3_g1, imp_mppV1_prosper_e3_g2, imp_mppV1_prosper_e3_g3, imp_mppV1_prosper_e3_g4,\
                                               imp_mppV1_prosper_e4_g1, imp_mppV1_prosper_e4_g2, imp_mppV1_prosper_e4_g3, imp_mppV1_prosper_e4_g4,\
                                               imp_mppV1_prosper_e5_g1, imp_mppV1_prosper_e5_g2, imp_mppV1_prosper_e5_g3, imp_mppV1_prosper_e5_g4)))

imp_mppV1_prscsx_all = np.mean(np.concatenate((imp_mppV1_prscsx_e1_g1, imp_mppV1_prscsx_e1_g2, imp_mppV1_prscsx_e1_g3, imp_mppV1_prscsx_e1_g4,\
                                               imp_mppV1_prscsx_e2_g1, imp_mppV1_prscsx_e2_g2, imp_mppV1_prscsx_e2_g3, imp_mppV1_prscsx_e2_g4,\
                                               imp_mppV1_prscsx_e3_g1, imp_mppV1_prscsx_e3_g2, imp_mppV1_prscsx_e3_g3, imp_mppV1_prscsx_e3_g4,\
                                               imp_mppV1_prscsx_e4_g1, imp_mppV1_prscsx_e4_g2, imp_mppV1_prscsx_e4_g3, imp_mppV1_prscsx_e4_g4,\
                                               imp_mppV1_prscsx_e5_g1, imp_mppV1_prscsx_e5_g2, imp_mppV1_prscsx_e5_g3, imp_mppV1_prscsx_e5_g4)))

imp_mppV1_tlmulti_all = np.mean(np.concatenate((imp_mppV1_tlmulti_e1_g1, imp_mppV1_tlmulti_e1_g2, imp_mppV1_tlmulti_e1_g3, imp_mppV1_tlmulti_e1_g4,\
                                               imp_mppV1_tlmulti_e2_g1, imp_mppV1_tlmulti_e2_g2, imp_mppV1_tlmulti_e2_g3, imp_mppV1_tlmulti_e2_g4,\
                                               imp_mppV1_tlmulti_e3_g1, imp_mppV1_tlmulti_e3_g2, imp_mppV1_tlmulti_e3_g3, imp_mppV1_tlmulti_e3_g4,\
                                               imp_mppV1_tlmulti_e4_g1, imp_mppV1_tlmulti_e4_g2, imp_mppV1_tlmulti_e4_g3, imp_mppV1_tlmulti_e4_g4,\
                                               imp_mppV1_tlmulti_e5_g1, imp_mppV1_tlmulti_e5_g2, imp_mppV1_tlmulti_e5_g3, imp_mppV1_tlmulti_e5_g4)))

imp_mppV1_lassosum2_all = np.mean(np.concatenate((imp_mppV1_lassosum2_e1_g1, imp_mppV1_lassosum2_e1_g2, imp_mppV1_lassosum2_e1_g3, imp_mppV1_lassosum2_e1_g4,\
                                               imp_mppV1_lassosum2_e2_g1, imp_mppV1_lassosum2_e2_g2, imp_mppV1_lassosum2_e2_g3, imp_mppV1_lassosum2_e2_g4,\
                                               imp_mppV1_lassosum2_e3_g1, imp_mppV1_lassosum2_e3_g2, imp_mppV1_lassosum2_e3_g3, imp_mppV1_lassosum2_e3_g4,\
                                               imp_mppV1_lassosum2_e4_g1, imp_mppV1_lassosum2_e4_g2, imp_mppV1_lassosum2_e4_g3, imp_mppV1_lassosum2_e4_g4,\
                                               imp_mppV1_lassosum2_e5_g1, imp_mppV1_lassosum2_e5_g2, imp_mppV1_lassosum2_e5_g3, imp_mppV1_lassosum2_e5_g4)))

imp_mppV1_lassosumTLD_all = np.mean(np.concatenate((imp_mppV1_lassosumTLD_e1_g1, imp_mppV1_lassosumTLD_e1_g2, imp_mppV1_lassosumTLD_e1_g3, imp_mppV1_lassosumTLD_e1_g4,\
                                               imp_mppV1_lassosumTLD_e2_g1, imp_mppV1_lassosumTLD_e2_g2, imp_mppV1_lassosumTLD_e2_g3, imp_mppV1_lassosumTLD_e2_g4,\
                                               imp_mppV1_lassosumTLD_e3_g1, imp_mppV1_lassosumTLD_e3_g2, imp_mppV1_lassosumTLD_e3_g3, imp_mppV1_lassosumTLD_e3_g4,\
                                               imp_mppV1_lassosumTLD_e4_g1, imp_mppV1_lassosumTLD_e4_g2, imp_mppV1_lassosumTLD_e4_g3, imp_mppV1_lassosumTLD_e4_g4,\
                                               imp_mppV1_lassosumTLD_e5_g1, imp_mppV1_lassosumTLD_e5_g2, imp_mppV1_lassosumTLD_e5_g3, imp_mppV1_lassosumTLD_e5_g4)))

imp_mppV1_baseline_all = np.mean(np.concatenate((imp_mppV1_baseline_e1_g1, imp_mppV1_baseline_e1_g2, imp_mppV1_baseline_e1_g3, imp_mppV1_baseline_e1_g4,\
                                               imp_mppV1_baseline_e2_g1, imp_mppV1_baseline_e2_g2, imp_mppV1_baseline_e2_g3, imp_mppV1_baseline_e2_g4,\
                                               imp_mppV1_baseline_e3_g1, imp_mppV1_baseline_e3_g2, imp_mppV1_baseline_e3_g3, imp_mppV1_baseline_e3_g4,\
                                               imp_mppV1_baseline_e4_g1, imp_mppV1_baseline_e4_g2, imp_mppV1_baseline_e4_g3, imp_mppV1_baseline_e4_g4,\
                                               imp_mppV1_baseline_e5_g1, imp_mppV1_baseline_e5_g2, imp_mppV1_baseline_e5_g3, imp_mppV1_baseline_e5_g4)))

print("mppV1 vs. sbrcM "+str(imp_mppV1_sbrcM_all*100))
print("mppV1 vs. sbrc "+str(imp_mppV1_sbrc_all*100))
print("mppV1 vs. prosper "+str(imp_mppV1_prosper_all*100))
print("mppV1 vs. prscsx "+str(imp_mppV1_prscsx_all*100))
print("mppV1 vs. tlmulti "+str(imp_mppV1_tlmulti_all*100))
print("mppV1 vs. lassosum2 "+str(imp_mppV1_lassosum2_all*100))
print("mppV1 vs. lassosumTLD "+str(imp_mppV1_lassosumTLD_all*100))
print("mppV1 vs. baseline "+str(imp_mppV1_baseline_all*100))
# Out:
# mppV1 vs. sbrcM 10.993777104785837
# mppV1 vs. sbrc 28.70962080141818
# mppV1 vs. prosper 9.174346155102418
# mppV1 vs. prscsx 31.647056762016508
# mppV1 vs. tlmulti 52.13774217234456
# mppV1 vs. lassosum2 22.442248697818542
# mppV1 vs. lassosumTLD -9.750471910662009
# mppV1 vs. baseline 16.940617247181958

# %%
imp_mppV3_sbrcM_all = np.mean(np.concatenate((imp_mppV3_sbrcM_e1_g1, imp_mppV3_sbrcM_e1_g2, imp_mppV3_sbrcM_e1_g3, imp_mppV3_sbrcM_e1_g4,\
                                               imp_mppV3_sbrcM_e2_g1, imp_mppV3_sbrcM_e2_g2, imp_mppV3_sbrcM_e2_g3, imp_mppV3_sbrcM_e2_g4,\
                                               imp_mppV3_sbrcM_e3_g1, imp_mppV3_sbrcM_e3_g2, imp_mppV3_sbrcM_e3_g3, imp_mppV3_sbrcM_e3_g4,\
                                               imp_mppV3_sbrcM_e4_g1, imp_mppV3_sbrcM_e4_g2, imp_mppV3_sbrcM_e4_g3, imp_mppV3_sbrcM_e4_g4,\
                                               imp_mppV3_sbrcM_e5_g1, imp_mppV3_sbrcM_e5_g2, imp_mppV3_sbrcM_e5_g3, imp_mppV3_sbrcM_e5_g4)))

imp_mppV3_sbrc_all = np.mean(np.concatenate((imp_mppV3_sbrc_e1_g1, imp_mppV3_sbrc_e1_g2, imp_mppV3_sbrc_e1_g3, imp_mppV3_sbrc_e1_g4,\
                                               imp_mppV3_sbrc_e2_g1, imp_mppV3_sbrc_e2_g2, imp_mppV3_sbrc_e2_g3, imp_mppV3_sbrc_e2_g4,\
                                               imp_mppV3_sbrc_e3_g1, imp_mppV3_sbrc_e3_g2, imp_mppV3_sbrc_e3_g3, imp_mppV3_sbrc_e3_g4,\
                                               imp_mppV3_sbrc_e4_g1, imp_mppV3_sbrc_e4_g2, imp_mppV3_sbrc_e4_g3, imp_mppV3_sbrc_e4_g4,\
                                               imp_mppV3_sbrc_e5_g1, imp_mppV3_sbrc_e5_g2, imp_mppV3_sbrc_e5_g3, imp_mppV3_sbrc_e5_g4)))

imp_mppV3_prosper_all = np.mean(np.concatenate((imp_mppV3_prosper_e1_g1, imp_mppV3_prosper_e1_g2, imp_mppV3_prosper_e1_g3, imp_mppV3_prosper_e1_g4,\
                                               imp_mppV3_prosper_e2_g1, imp_mppV3_prosper_e2_g2, imp_mppV3_prosper_e2_g3, imp_mppV3_prosper_e2_g4,\
                                               imp_mppV3_prosper_e3_g1, imp_mppV3_prosper_e3_g2, imp_mppV3_prosper_e3_g3, imp_mppV3_prosper_e3_g4,\
                                               imp_mppV3_prosper_e4_g1, imp_mppV3_prosper_e4_g2, imp_mppV3_prosper_e4_g3, imp_mppV3_prosper_e4_g4,\
                                               imp_mppV3_prosper_e5_g1, imp_mppV3_prosper_e5_g2, imp_mppV3_prosper_e5_g3, imp_mppV3_prosper_e5_g4)))

imp_mppV3_prscsx_all = np.mean(np.concatenate((imp_mppV3_prscsx_e1_g1, imp_mppV3_prscsx_e1_g2, imp_mppV3_prscsx_e1_g3, imp_mppV3_prscsx_e1_g4,\
                                               imp_mppV3_prscsx_e2_g1, imp_mppV3_prscsx_e2_g2, imp_mppV3_prscsx_e2_g3, imp_mppV3_prscsx_e2_g4,\
                                               imp_mppV3_prscsx_e3_g1, imp_mppV3_prscsx_e3_g2, imp_mppV3_prscsx_e3_g3, imp_mppV3_prscsx_e3_g4,\
                                               imp_mppV3_prscsx_e4_g1, imp_mppV3_prscsx_e4_g2, imp_mppV3_prscsx_e4_g3, imp_mppV3_prscsx_e4_g4,\
                                               imp_mppV3_prscsx_e5_g1, imp_mppV3_prscsx_e5_g2, imp_mppV3_prscsx_e5_g3, imp_mppV3_prscsx_e5_g4)))

imp_mppV3_tlmulti_all = np.mean(np.concatenate((imp_mppV3_tlmulti_e1_g1, imp_mppV3_tlmulti_e1_g2, imp_mppV3_tlmulti_e1_g3, imp_mppV3_tlmulti_e1_g4,\
                                               imp_mppV3_tlmulti_e2_g1, imp_mppV3_tlmulti_e2_g2, imp_mppV3_tlmulti_e2_g3, imp_mppV3_tlmulti_e2_g4,\
                                               imp_mppV3_tlmulti_e3_g1, imp_mppV3_tlmulti_e3_g2, imp_mppV3_tlmulti_e3_g3, imp_mppV3_tlmulti_e3_g4,\
                                               imp_mppV3_tlmulti_e4_g1, imp_mppV3_tlmulti_e4_g2, imp_mppV3_tlmulti_e4_g3, imp_mppV3_tlmulti_e4_g4,\
                                               imp_mppV3_tlmulti_e5_g1, imp_mppV3_tlmulti_e5_g2, imp_mppV3_tlmulti_e5_g3, imp_mppV3_tlmulti_e5_g4)))

imp_mppV3_lassosum2_all = np.mean(np.concatenate((imp_mppV3_lassosum2_e1_g1, imp_mppV3_lassosum2_e1_g2, imp_mppV3_lassosum2_e1_g3, imp_mppV3_lassosum2_e1_g4,\
                                               imp_mppV3_lassosum2_e2_g1, imp_mppV3_lassosum2_e2_g2, imp_mppV3_lassosum2_e2_g3, imp_mppV3_lassosum2_e2_g4,\
                                               imp_mppV3_lassosum2_e3_g1, imp_mppV3_lassosum2_e3_g2, imp_mppV3_lassosum2_e3_g3, imp_mppV3_lassosum2_e3_g4,\
                                               imp_mppV3_lassosum2_e4_g1, imp_mppV3_lassosum2_e4_g2, imp_mppV3_lassosum2_e4_g3, imp_mppV3_lassosum2_e4_g4,\
                                               imp_mppV3_lassosum2_e5_g1, imp_mppV3_lassosum2_e5_g2, imp_mppV3_lassosum2_e5_g3, imp_mppV3_lassosum2_e5_g4)))

imp_mppV3_lassosumTLD_all = np.mean(np.concatenate((imp_mppV3_lassosumTLD_e1_g1, imp_mppV3_lassosumTLD_e1_g2, imp_mppV3_lassosumTLD_e1_g3, imp_mppV3_lassosumTLD_e1_g4,\
                                               imp_mppV3_lassosumTLD_e2_g1, imp_mppV3_lassosumTLD_e2_g2, imp_mppV3_lassosumTLD_e2_g3, imp_mppV3_lassosumTLD_e2_g4,\
                                               imp_mppV3_lassosumTLD_e3_g1, imp_mppV3_lassosumTLD_e3_g2, imp_mppV3_lassosumTLD_e3_g3, imp_mppV3_lassosumTLD_e3_g4,\
                                               imp_mppV3_lassosumTLD_e4_g1, imp_mppV3_lassosumTLD_e4_g2, imp_mppV3_lassosumTLD_e4_g3, imp_mppV3_lassosumTLD_e4_g4,\
                                               imp_mppV3_lassosumTLD_e5_g1, imp_mppV3_lassosumTLD_e5_g2, imp_mppV3_lassosumTLD_e5_g3, imp_mppV3_lassosumTLD_e5_g4)))

imp_mppV3_baseline_all = np.mean(np.concatenate((imp_mppV3_baseline_e1_g1, imp_mppV3_baseline_e1_g2, imp_mppV3_baseline_e1_g3, imp_mppV3_baseline_e1_g4,\
                                               imp_mppV3_baseline_e2_g1, imp_mppV3_baseline_e2_g2, imp_mppV3_baseline_e2_g3, imp_mppV3_baseline_e2_g4,\
                                               imp_mppV3_baseline_e3_g1, imp_mppV3_baseline_e3_g2, imp_mppV3_baseline_e3_g3, imp_mppV3_baseline_e3_g4,\
                                               imp_mppV3_baseline_e4_g1, imp_mppV3_baseline_e4_g2, imp_mppV3_baseline_e4_g3, imp_mppV3_baseline_e4_g4,\
                                               imp_mppV3_baseline_e5_g1, imp_mppV3_baseline_e5_g2, imp_mppV3_baseline_e5_g3, imp_mppV3_baseline_e5_g4)))

print("mppV3 vs. sbrcM "+str(imp_mppV3_sbrcM_all*100))
print("mppV3 vs. sbrc "+str(imp_mppV3_sbrc_all*100))
print("mppV3 vs. prosper "+str(imp_mppV3_prosper_all*100))
print("mppV3 vs. prscsx "+str(imp_mppV3_prscsx_all*100))
print("mppV3 vs. tlmulti "+str(imp_mppV3_tlmulti_all*100))
print("mppV3 vs. lassosum2 "+str(imp_mppV3_lassosum2_all*100))
print("mppV3 vs. lassosumTLD "+str(imp_mppV3_lassosumTLD_all*100))
print("mppV3 vs. baseline "+str(imp_mppV3_baseline_all*100))
# Out:
# mppV3 vs. sbrcM 13.626186081189678
# mppV3 vs. sbrc 31.514521481223984
# mppV3 vs. prosper 11.752025637440658
# mppV3 vs. prscsx 34.5368401000869
# mppV3 vs. tlmulti 55.45195717559075
# mppV3 vs. lassosum2 25.16457681306987
# mppV3 vs. lassosumTLD -7.693046677232123
# mppV3 vs. baseline 19.55949053488348
